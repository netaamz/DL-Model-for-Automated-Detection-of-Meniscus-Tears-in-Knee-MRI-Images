# %% [markdown]
# <a href="https://colab.research.google.com/github/netaamz/DL-Model-for-Automated-Detection-of-Meniscus-Tears-in-Knee-MRI-Images/blob/main/batch_size_3_planes_concatenate_DenseNet_transfer_learning_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone: Development of an algorithm for automatic detection of meniscus tears in radiographic images of the knee.

# %%
import warnings
warnings.filterwarnings("ignore")

#!pip install pyyaml

# %%
# !pip install tensorflow
# !pip install keras
# !pip install h5py
# !pip install sklearn
# !pip install opencv-python
# !pip install seaborn
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.26.4)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)

# %%
# Import libraries here
import os
import tempfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from glob import glob
from IPython.display import Image, display
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix, accuracy_score

import random as random
import imageio
import imgaug as ia
import tensorflow as tf
from tensorflow import keras
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Data import

# %% [markdown]
# **import data and get labels**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The dataset contains *s* x 256 x 256 images. Since middle images are the most useful, only 3 middle slides in the series are retained.

# %% [markdown]
# ## **data generation for meniscus**

# %%
def data_gen(dataset_type, plane, diagnosis):
    '''this function gets the data from the extracted datset'''
    # for eg, (train, sagittal, mensicus)
    if dataset_type == 'train':
        go = '/content/drive/My Drive/miniscus data set/MRNet-v1.0/train_transformf' # if we want without filter then:  /content/drive/My Drive/miniscus data set/MRNet-v1.0/train_transform
    else:
        go = '/content/drive/My Drive/miniscus data set/MRNet-v1.0/valid_transformf' # if we want without filter then: /content/drive/My Drive/miniscus data set/MRNet-v1.0/valid_transform

    plane_dir = f'{go}/{plane}.npy'

    data = np.load(plane_dir)
    label_path = f'/content/drive/My Drive/miniscus data set/MRNet-v1.0/{dataset_type}-{diagnosis}.csv'
#     label_path = f'data/{dataset_type}-{diagnosis}.csv'
    label_df = pd.read_csv(label_path, names=['nr', diagnosis])
    label_data = list(label_df[diagnosis])

    return(data, label_data)

# %%
# generate training input
coronal_mensicus, coronal_mensicus_label = data_gen('train', 'coronal/extracted_images', 'meniscus')
axial_mensicus, axial_mensicus_label = data_gen('train', 'axial/extracted_images', 'meniscus')
sagittal_mensicus, sagittal_mensicus_label = data_gen('train', 'sagittal/extracted_images', 'meniscus')
print(sagittal_mensicus.shape)
# generate validation
coronal_mensicus_val, coronal_mensicus_label_val  = data_gen('valid', 'coronal/extracted_images', 'meniscus')
axial_mensicus_val, axial_mensicus_label_val  = data_gen('valid', 'axial/extracted_images', 'meniscus')
sagittal_mensicus_val, sagittal_mensicus_label_val  = data_gen('valid', 'sagittal/extracted_images', 'meniscus')
# Out:
# (1130, 256, 256, 3)

# %%
from keras.utils import to_categorical  # Import to_categorical
base_path = "/content/drive/My Drive/miniscus data set/MRNet-v1.0/"

num_classes =2

sagittal_mensicus_label = to_categorical(sagittal_mensicus_label, num_classes)
sagittal_mensicus_label_val = to_categorical(sagittal_mensicus_label_val, num_classes)

coronal_mensicus_label = to_categorical(coronal_mensicus_label, num_classes)
coronal_mensicus_label_val = to_categorical(coronal_mensicus_label_val, num_classes)

axial_mensicus_label = to_categorical(axial_mensicus_label, num_classes)
axial_mensicus_label_val = to_categorical(axial_mensicus_label_val, num_classes)

# %%
from sklearn.metrics import log_loss
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ##  Hyperparameters

# %%
    img_rows, img_cols = 256, 256  # Adjust based on your actual image dimensions
    channel = 3
    num_classes = 2  # Binary classification
    batch_size1 = 16
    batch_size2 = 32
    nb_epoch= 100
    dropout = 0.4
    lr = 5e-4  # Learning rat

# %% [markdown]
# ## Model Creation and training

# %%
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, BatchNormalization, Dropout, Concatenate, MaxPooling1D, Reshape, Flatten
from tensorflow.keras.optimizers import SGD, schedules
from tensorflow.keras.callbacks import ModelCheckpoint
def create_model2(input_shape, num_classes, dropout):
    # Base DenseNet model for each plane (axial, coronal, sagittal)
    base_model = DenseNet121(weights='imagenet', include_top=False, pooling=None, input_shape=input_shape)

    # Define input for each plane
    input_axial = Input(shape=input_shape, name='input_axial')
    input_coronal = Input(shape=input_shape, name='input_coronal')
    input_sagittal = Input(shape=input_shape, name='input_sagittal')

    # Process each plane using the same base DenseNet model
    axial_output = base_model(input_axial)
    coronal_output = base_model(input_coronal)
    sagittal_output = base_model(input_sagittal)

    # Global Average Pooling for each plane
    axial_output = GlobalAveragePooling2D()(axial_output)
    coronal_output = GlobalAveragePooling2D()(coronal_output)
    sagittal_output = GlobalAveragePooling2D()(sagittal_output)

    # Concatenate the outputs from all planes
    concatenated = Concatenate()([ axial_output, coronal_output, sagittal_output])

    # Dense and Dropout layers after concatenation
    x = BatchNormalization()(concatenated)
    x = Dropout(dropout)(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(dropout)(x)
    x = Dense(512, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)

    # Create the final model
    model = Model(inputs=[input_axial, input_coronal, input_sagittal], outputs=output)

    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = False

    return model

# %%
if __name__ == '__main__':
    input_shape = (img_rows, img_cols, channel)  # Update this with actual dimensions

    # Create the model with three inputs (for axial, coronal, and sagittal planes)
    model1 = create_model2(input_shape, num_classes, dropout)
    model2 = create_model2(input_shape, num_classes, dropout)

    # Compile the model
    model1.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    model2.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])


    # Set up the checkpoint
    filepath = "bestmodel.keras"
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]

    # Training run 1
    history1 = model1.fit([axial_mensicus, coronal_mensicus, sagittal_mensicus],
                         axial_mensicus_label,
                         batch_size=batch_size1,
                         epochs=nb_epoch,
                         shuffle=True,
                         verbose=1,
                         validation_data=([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], axial_mensicus_label_val),
                         callbacks=callbacks_list)

    # Training run 2
    history2 = model2.fit([axial_mensicus, coronal_mensicus, sagittal_mensicus],
                         axial_mensicus_label,
                         batch_size=batch_size2,
                         epochs=nb_epoch,
                         shuffle=True,
                         verbose=1,
                         validation_data=([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], axial_mensicus_label_val),
                         callbacks=callbacks_list)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.5555 - loss: 0.7500
# Epoch 1: val_accuracy improved from -inf to 0.56667, saving model to bestmodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 119s 908ms/step - accuracy: 0.5562 - loss: 0.7498 - val_accuracy: 0.5667 - val_loss: 0.8535
# Epoch 2/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6113 - loss: 0.7275
# Epoch 2: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.6114 - loss: 0.7272 - val_accuracy: 0.5667 - val_loss: 0.7899
# Epoch 3/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.6054 - loss: 0.7309
# Epoch 3: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.6057 - loss: 0.7304 - val_accuracy: 0.5667 - val_loss: 0.7901
# Epoch 4/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6245 - loss: 0.6906
# Epoch 4: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 142ms/step - accuracy: 0.6247 - loss: 0.6905 - val_accuracy: 0.5583 - val_loss: 0.7724
# Epoch 5/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.6378 - loss: 0.6662
# Epoch 5: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 144ms/step - accuracy: 0.6377 - loss: 0.6663 - val_accuracy: 0.5667 - val_loss: 0.8053
# Epoch 6/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6755 - loss: 0.6291
# Epoch 6: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 145ms/step - accuracy: 0.6752 - loss: 0.6294 - val_accuracy: 0.5583 - val_loss: 0.8087
# Epoch 7/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6403 - loss: 0.6663
# Epoch 7: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 146ms/step - accuracy: 0.6404 - loss: 0.6661 - val_accuracy: 0.5667 - val_loss: 0.8338
# Epoch 8/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6609 - loss: 0.6368
# Epoch 8: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6610 - loss: 0.6367 - val_accuracy: 0.5500 - val_loss: 0.8504
# Epoch 9/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.6764 - loss: 0.6288
# Epoch 9: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 11s 148ms/step - accuracy: 0.6765 - loss: 0.6287 - val_accuracy: 0.5667 - val_loss: 0.8611
# Epoch 10/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6677 - loss: 0.6321
# Epoch 10: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.6678 - loss: 0.6320 - val_accuracy: 0.5667 - val_loss: 0.9056
# Epoch 11/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6736 - loss: 0.6032
# Epoch 11: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.6736 - loss: 0.6033 - val_accuracy: 0.5667 - val_loss: 0.8761
# Epoch 12/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.6757 - loss: 0.6019
# Epoch 12: val_accuracy did not improve from 0.56667
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.6759 - loss: 0.6019 - val_accuracy: 0.5667 - val_loss: 0.8730
# Epoch 13/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6878 - loss: 0.6071
# Epoch 13: val_accuracy improved from 0.56667 to 0.57500, saving model to bestmodel.keras
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 11s 161ms/step - accuracy: 0.6879 - loss: 0.6071 - val_accuracy: 0.5750 - val_loss: 0.8983
# Epoch 14/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7005 - loss: 0.5860
# Epoch 14: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7003 - loss: 0.5863 - val_accuracy: 0.5667 - val_loss: 0.8694
# Epoch 15/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7243 - loss: 0.5723
# Epoch 15: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7240 - loss: 0.5725 - val_accuracy: 0.5667 - val_loss: 0.8985
# Epoch 16/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7320 - loss: 0.5480
# Epoch 16: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.7316 - loss: 0.5484 - val_accuracy: 0.5750 - val_loss: 0.8936
# Epoch 17/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7048 - loss: 0.5587
# Epoch 17: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.7049 - loss: 0.5587 - val_accuracy: 0.5667 - val_loss: 0.9481
# Epoch 18/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.6922 - loss: 0.5747
# Epoch 18: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.6924 - loss: 0.5746 - val_accuracy: 0.5667 - val_loss: 0.9428
# Epoch 19/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7367 - loss: 0.5469
# Epoch 19: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7366 - loss: 0.5470 - val_accuracy: 0.5667 - val_loss: 0.9350
# Epoch 20/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7227 - loss: 0.5502
# Epoch 20: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7227 - loss: 0.5502 - val_accuracy: 0.5583 - val_loss: 0.9355
# Epoch 21/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7359 - loss: 0.5376
# Epoch 21: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7358 - loss: 0.5376 - val_accuracy: 0.5500 - val_loss: 0.9144
# Epoch 22/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7524 - loss: 0.5368
# Epoch 22: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7523 - loss: 0.5368 - val_accuracy: 0.5667 - val_loss: 0.9787
# Epoch 23/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7492 - loss: 0.5098
# Epoch 23: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7491 - loss: 0.5099 - val_accuracy: 0.5500 - val_loss: 0.9370
# Epoch 24/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7423 - loss: 0.5225
# Epoch 24: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7422 - loss: 0.5225 - val_accuracy: 0.5750 - val_loss: 1.0185
# Epoch 25/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7756 - loss: 0.4977
# Epoch 25: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7754 - loss: 0.4980 - val_accuracy: 0.5667 - val_loss: 1.0126
# Epoch 26/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7795 - loss: 0.4830
# Epoch 26: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7792 - loss: 0.4833 - val_accuracy: 0.5667 - val_loss: 1.0263
# Epoch 27/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7827 - loss: 0.4935
# Epoch 27: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7826 - loss: 0.4934 - val_accuracy: 0.5500 - val_loss: 1.1034
# Epoch 28/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7404 - loss: 0.5094
# Epoch 28: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7406 - loss: 0.5093 - val_accuracy: 0.5333 - val_loss: 0.9854
# Epoch 29/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7758 - loss: 0.4769
# Epoch 29: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7758 - loss: 0.4770 - val_accuracy: 0.5583 - val_loss: 1.0392
# Epoch 30/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7550 - loss: 0.5073
# Epoch 30: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7551 - loss: 0.5072 - val_accuracy: 0.5333 - val_loss: 1.0048
# Epoch 31/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7593 - loss: 0.4826
# Epoch 31: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7593 - loss: 0.4827 - val_accuracy: 0.5583 - val_loss: 1.0646
# Epoch 32/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8032 - loss: 0.4549
# Epoch 32: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8029 - loss: 0.4551 - val_accuracy: 0.5167 - val_loss: 0.9887
# Epoch 33/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8038 - loss: 0.4721
# Epoch 33: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8037 - loss: 0.4721 - val_accuracy: 0.5500 - val_loss: 1.0866
# Epoch 34/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8056 - loss: 0.4479
# Epoch 34: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8054 - loss: 0.4480 - val_accuracy: 0.5167 - val_loss: 1.0210
# Epoch 35/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7920 - loss: 0.4428
# Epoch 35: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7919 - loss: 0.4429 - val_accuracy: 0.5250 - val_loss: 0.9899
# Epoch 36/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7918 - loss: 0.4487
# Epoch 36: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7917 - loss: 0.4488 - val_accuracy: 0.5250 - val_loss: 1.0120
# Epoch 37/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7966 - loss: 0.4345
# Epoch 37: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7966 - loss: 0.4346 - val_accuracy: 0.5250 - val_loss: 0.9875
# Epoch 38/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7879 - loss: 0.4395
# Epoch 38: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7878 - loss: 0.4397 - val_accuracy: 0.5250 - val_loss: 1.0454
# Epoch 39/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8252 - loss: 0.4056
# Epoch 39: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8251 - loss: 0.4059 - val_accuracy: 0.5333 - val_loss: 1.0990
# Epoch 40/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7990 - loss: 0.4487
# Epoch 40: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7991 - loss: 0.4485 - val_accuracy: 0.5083 - val_loss: 1.0260
# Epoch 41/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8008 - loss: 0.4250
# Epoch 41: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8010 - loss: 0.4247 - val_accuracy: 0.5250 - val_loss: 1.0523
# Epoch 42/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8317 - loss: 0.3912
# Epoch 42: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8316 - loss: 0.3912 - val_accuracy: 0.5167 - val_loss: 1.1156
# Epoch 43/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8158 - loss: 0.4045
# Epoch 43: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8158 - loss: 0.4047 - val_accuracy: 0.5167 - val_loss: 1.0736
# Epoch 44/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8414 - loss: 0.3781
# Epoch 44: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8413 - loss: 0.3783 - val_accuracy: 0.5167 - val_loss: 1.0804
# Epoch 45/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7995 - loss: 0.4024
# Epoch 45: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.7998 - loss: 0.4023 - val_accuracy: 0.5083 - val_loss: 1.0840
# Epoch 46/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8225 - loss: 0.3942
# Epoch 46: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8227 - loss: 0.3940 - val_accuracy: 0.5500 - val_loss: 1.1324
# Epoch 47/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8125 - loss: 0.4046
# Epoch 47: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8127 - loss: 0.4042 - val_accuracy: 0.5167 - val_loss: 1.1321
# Epoch 48/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8574 - loss: 0.3650
# Epoch 48: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8572 - loss: 0.3652 - val_accuracy: 0.5250 - val_loss: 1.0404
# Epoch 49/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8243 - loss: 0.3948
# Epoch 49: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8244 - loss: 0.3948 - val_accuracy: 0.5333 - val_loss: 1.0857
# Epoch 50/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8503 - loss: 0.3422
# Epoch 50: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8502 - loss: 0.3425 - val_accuracy: 0.5083 - val_loss: 1.1226
# Epoch 51/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8341 - loss: 0.3586
# Epoch 51: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8340 - loss: 0.3589 - val_accuracy: 0.5333 - val_loss: 1.0897
# Epoch 52/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8475 - loss: 0.3463
# Epoch 52: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8474 - loss: 0.3465 - val_accuracy: 0.5000 - val_loss: 1.1017
# Epoch 53/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8418 - loss: 0.3479
# Epoch 53: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8419 - loss: 0.3477 - val_accuracy: 0.5083 - val_loss: 1.0640
# Epoch 54/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8731 - loss: 0.3192
# Epoch 54: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8730 - loss: 0.3195 - val_accuracy: 0.5000 - val_loss: 1.1439
# Epoch 55/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8353 - loss: 0.3829
# Epoch 55: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8353 - loss: 0.3827 - val_accuracy: 0.5083 - val_loss: 1.0870
# Epoch 56/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8474 - loss: 0.3411
# Epoch 56: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8473 - loss: 0.3414 - val_accuracy: 0.5000 - val_loss: 1.0721
# Epoch 57/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8792 - loss: 0.3209
# Epoch 57: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8790 - loss: 0.3210 - val_accuracy: 0.4917 - val_loss: 1.1124
# Epoch 58/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8649 - loss: 0.3368
# Epoch 58: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8651 - loss: 0.3367 - val_accuracy: 0.5083 - val_loss: 1.1164
# Epoch 59/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8434 - loss: 0.3624
# Epoch 59: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8436 - loss: 0.3619 - val_accuracy: 0.5083 - val_loss: 1.1659
# Epoch 60/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8808 - loss: 0.2938
# Epoch 60: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8807 - loss: 0.2938 - val_accuracy: 0.5083 - val_loss: 1.0989
# Epoch 61/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8478 - loss: 0.3373
# Epoch 61: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8480 - loss: 0.3372 - val_accuracy: 0.5083 - val_loss: 1.1148
# Epoch 62/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8749 - loss: 0.3222
# Epoch 62: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8750 - loss: 0.3219 - val_accuracy: 0.5250 - val_loss: 1.2204
# Epoch 63/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8623 - loss: 0.2904
# Epoch 63: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8623 - loss: 0.2905 - val_accuracy: 0.5417 - val_loss: 1.2628
# Epoch 64/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8697 - loss: 0.3075
# Epoch 64: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8697 - loss: 0.3073 - val_accuracy: 0.5167 - val_loss: 1.1918
# Epoch 65/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8801 - loss: 0.2820
# Epoch 65: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8801 - loss: 0.2821 - val_accuracy: 0.5333 - val_loss: 1.2419
# Epoch 66/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8813 - loss: 0.2739
# Epoch 66: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8812 - loss: 0.2742 - val_accuracy: 0.5167 - val_loss: 1.2166
# Epoch 67/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8741 - loss: 0.2941
# Epoch 67: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8742 - loss: 0.2941 - val_accuracy: 0.5250 - val_loss: 1.3083
# Epoch 68/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8974 - loss: 0.2567
# Epoch 68: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8972 - loss: 0.2571 - val_accuracy: 0.5333 - val_loss: 1.2280
# Epoch 69/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8784 - loss: 0.2896
# Epoch 69: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8785 - loss: 0.2894 - val_accuracy: 0.5000 - val_loss: 1.2911
# Epoch 70/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8724 - loss: 0.2846
# Epoch 70: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8726 - loss: 0.2844 - val_accuracy: 0.5167 - val_loss: 1.2983
# Epoch 71/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8729 - loss: 0.2771
# Epoch 71: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8729 - loss: 0.2772 - val_accuracy: 0.5250 - val_loss: 1.2476
# Epoch 72/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8858 - loss: 0.3036
# Epoch 72: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8859 - loss: 0.3032 - val_accuracy: 0.5167 - val_loss: 1.3801
# Epoch 73/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9048 - loss: 0.2663
# Epoch 73: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9046 - loss: 0.2667 - val_accuracy: 0.5417 - val_loss: 1.3263
# Epoch 74/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9000 - loss: 0.2630
# Epoch 74: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.9000 - loss: 0.2630 - val_accuracy: 0.5333 - val_loss: 1.2327
# Epoch 75/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8765 - loss: 0.2874
# Epoch 75: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8766 - loss: 0.2873 - val_accuracy: 0.5167 - val_loss: 1.2681
# Epoch 76/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8949 - loss: 0.2325
# Epoch 76: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8947 - loss: 0.2327 - val_accuracy: 0.5167 - val_loss: 1.3200
# Epoch 77/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9051 - loss: 0.2429
# Epoch 77: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9052 - loss: 0.2428 - val_accuracy: 0.5333 - val_loss: 1.4177
# Epoch 78/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9056 - loss: 0.2452
# Epoch 78: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9054 - loss: 0.2453 - val_accuracy: 0.5000 - val_loss: 1.3183
# Epoch 79/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9129 - loss: 0.2465
# Epoch 79: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9127 - loss: 0.2468 - val_accuracy: 0.5250 - val_loss: 1.3146
# Epoch 80/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9174 - loss: 0.2220
# Epoch 80: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9171 - loss: 0.2223 - val_accuracy: 0.5083 - val_loss: 1.2948
# Epoch 81/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8947 - loss: 0.2463
# Epoch 81: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8948 - loss: 0.2462 - val_accuracy: 0.5000 - val_loss: 1.3629
# Epoch 82/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9015 - loss: 0.2315
# Epoch 82: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9015 - loss: 0.2317 - val_accuracy: 0.5167 - val_loss: 1.3542
# Epoch 83/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8871 - loss: 0.2575
# Epoch 83: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 148ms/step - accuracy: 0.8871 - loss: 0.2575 - val_accuracy: 0.5250 - val_loss: 1.3473
# Epoch 84/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8871 - loss: 0.2634
# Epoch 84: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.8871 - loss: 0.2635 - val_accuracy: 0.5333 - val_loss: 1.4077
# Epoch 85/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9083 - loss: 0.2161
# Epoch 85: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9082 - loss: 0.2162 - val_accuracy: 0.5083 - val_loss: 1.3825
# Epoch 86/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9187 - loss: 0.2236
# Epoch 86: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9185 - loss: 0.2238 - val_accuracy: 0.5250 - val_loss: 1.4147
# Epoch 87/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9170 - loss: 0.2186
# Epoch 87: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9168 - loss: 0.2189 - val_accuracy: 0.5333 - val_loss: 1.4278
# Epoch 88/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9222 - loss: 0.2188
# Epoch 88: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9220 - loss: 0.2189 - val_accuracy: 0.5083 - val_loss: 1.4335
# Epoch 89/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9262 - loss: 0.2038
# Epoch 89: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9260 - loss: 0.2039 - val_accuracy: 0.5417 - val_loss: 1.4826
# Epoch 90/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9308 - loss: 0.1846
# Epoch 90: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.9307 - loss: 0.1849 - val_accuracy: 0.5417 - val_loss: 1.4676
# Epoch 91/100
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9273 - loss: 0.1997
# Epoch 91: val_accuracy did not improve from 0.57500
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 10s 147ms/step - accuracy: 0.
val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.8592 - loss: 0.3370 - val_accuracy: 0.5250 - val_loss: 0.9099
# Epoch 88/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8752 - loss: 0.3215
# Epoch 88: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8749 - loss: 0.3218 - val_accuracy: 0.5167 - val_loss: 0.9517
# Epoch 89/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8661 - loss: 0.3408
# Epoch 89: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8663 - loss: 0.3404 - val_accuracy: 0.5333 - val_loss: 0.9305
# Epoch 90/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8810 - loss: 0.3041
# Epoch 90: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8809 - loss: 0.3044 - val_accuracy: 0.5167 - val_loss: 0.9258
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8587 - loss: 0.3321
# Epoch 91: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8586 - loss: 0.3321 - val_accuracy: 0.5333 - val_loss: 0.9448
# Epoch 92/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8624 - loss: 0.3303
# Epoch 92: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8622 - loss: 0.3304 - val_accuracy: 0.5250 - val_loss: 0.9588
# Epoch 93/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8929 - loss: 0.2884
# Epoch 93: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8922 - loss: 0.2893 - val_accuracy: 0.5250 - val_loss: 0.9510
# Epoch 94/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8554 - loss: 0.3143
# Epoch 94: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.8556 - loss: 0.3144 - val_accuracy: 0.5167 - val_loss: 0.9453
# Epoch 95/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8591 - loss: 0.3319
# Epoch 95: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.8590 - loss: 0.3324 - val_accuracy: 0.5250 - val_loss: 0.9536
# Epoch 96/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8894 - loss: 0.2961
# Epoch 96: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8891 - loss: 0.2963 - val_accuracy: 0.5167 - val_loss: 0.9515
# Epoch 97/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8595 - loss: 0.3440
# Epoch 97: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8595 - loss: 0.3437 - val_accuracy: 0.5500 - val_loss: 0.9949
# Epoch 98/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8736 - loss: 0.3055
# Epoch 98: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8739 - loss: 0.3052 - val_accuracy: 0.5500 - val_loss: 1.0011
# Epoch 99/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8718 - loss: 0.3267
# Epoch 99: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8716 - loss: 0.3265 - val_accuracy: 0.5500 - val_loss: 0.9850
# Epoch 100/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8691 - loss: 0.3081
# Epoch 100: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8691 - loss: 0.3079 - val_accuracy: 0.5083 - val_loss: 0.9573

# %%
batch_size3=64

# %%
    model3 = create_model2(input_shape, num_classes, dropout)

    # Compile the model
    model3.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
        # Training run 2
    history3 = model3.fit([axial_mensicus, coronal_mensicus, sagittal_mensicus],
                         axial_mensicus_label,
                         batch_size=batch_size2,
                         epochs=batch_size3,
                         shuffle=True,
                         verbose=1,
                         validation_data=([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], axial_mensicus_label_val),
                         callbacks=callbacks_list)
# Out:
# Epoch 1/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 626ms/step - accuracy: 0.6098 - loss: 0.7514
# Epoch 1: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 97s 1s/step - accuracy: 0.6095 - loss: 0.7515 - val_accuracy: 0.5667 - val_loss: 0.8138
# Epoch 2/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.6365 - loss: 0.7025
# Epoch 2: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 267ms/step - accuracy: 0.6363 - loss: 0.7027 - val_accuracy: 0.5583 - val_loss: 0.7441
# Epoch 3/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.6184 - loss: 0.7085
# Epoch 3: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 270ms/step - accuracy: 0.6186 - loss: 0.7082 - val_accuracy: 0.5583 - val_loss: 0.7326
# Epoch 4/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6538 - loss: 0.6741
# Epoch 4: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.6534 - loss: 0.6747 - val_accuracy: 0.5750 - val_loss: 0.7228
# Epoch 5/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.6375 - loss: 0.6892
# Epoch 5: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 276ms/step - accuracy: 0.6374 - loss: 0.6893 - val_accuracy: 0.5417 - val_loss: 0.7386
# Epoch 6/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.6325 - loss: 0.6883
# Epoch 6: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step - accuracy: 0.6328 - loss: 0.6880 - val_accuracy: 0.5583 - val_loss: 0.7481
# Epoch 7/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.6680 - loss: 0.6611
# Epoch 7: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step - accuracy: 0.6673 - loss: 0.6615 - val_accuracy: 0.5667 - val_loss: 0.7407
# Epoch 8/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6524 - loss: 0.6654
# Epoch 8: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.6525 - loss: 0.6653 - val_accuracy: 0.5667 - val_loss: 0.7480
# Epoch 9/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6747 - loss: 0.6381
# Epoch 9: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.6740 - loss: 0.6388 - val_accuracy: 0.5583 - val_loss: 0.7472
# Epoch 10/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6550 - loss: 0.6493
# Epoch 10: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 271ms/step - accuracy: 0.6550 - loss: 0.6495 - val_accuracy: 0.5583 - val_loss: 0.7447
# Epoch 11/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6665 - loss: 0.6490
# Epoch 11: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 272ms/step - accuracy: 0.6664 - loss: 0.6490 - val_accuracy: 0.5667 - val_loss: 0.7520
# Epoch 12/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6699 - loss: 0.6345
# Epoch 12: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.6696 - loss: 0.6348 - val_accuracy: 0.5667 - val_loss: 0.7519
# Epoch 13/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6558 - loss: 0.6445
# Epoch 13: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.6563 - loss: 0.6443 - val_accuracy: 0.5583 - val_loss: 0.7593
# Epoch 14/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6609 - loss: 0.6445
# Epoch 14: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 275ms/step - accuracy: 0.6613 - loss: 0.6443 - val_accuracy: 0.5667 - val_loss: 0.7732
# Epoch 15/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6664 - loss: 0.6474
# Epoch 15: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.6665 - loss: 0.6472 - val_accuracy: 0.5667 - val_loss: 0.7787
# Epoch 16/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6812 - loss: 0.6341
# Epoch 16: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.6812 - loss: 0.6340 - val_accuracy: 0.5667 - val_loss: 0.7614
# Epoch 17/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6763 - loss: 0.6346
# Epoch 17: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.6764 - loss: 0.6343 - val_accuracy: 0.5667 - val_loss: 0.7763
# Epoch 18/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7050 - loss: 0.6135
# Epoch 18: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.7044 - loss: 0.6137 - val_accuracy: 0.5500 - val_loss: 0.7584
# Epoch 19/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6815 - loss: 0.6087
# Epoch 19: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.6818 - loss: 0.6088 - val_accuracy: 0.5667 - val_loss: 0.7758
# Epoch 20/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6964 - loss: 0.6161
# Epoch 20: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.6963 - loss: 0.6160 - val_accuracy: 0.5667 - val_loss: 0.7810
# Epoch 21/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6761 - loss: 0.6090
# Epoch 21: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.6760 - loss: 0.6093 - val_accuracy: 0.5583 - val_loss: 0.7692
# Epoch 22/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.6889 - loss: 0.6062
# Epoch 22: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.6888 - loss: 0.6061 - val_accuracy: 0.5750 - val_loss: 0.7869
# Epoch 23/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7082 - loss: 0.5993
# Epoch 23: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7081 - loss: 0.5993 - val_accuracy: 0.5667 - val_loss: 0.7799
# Epoch 24/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6712 - loss: 0.6230
# Epoch 24: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.6716 - loss: 0.6226 - val_accuracy: 0.5667 - val_loss: 0.7845
# Epoch 25/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6842 - loss: 0.6369
# Epoch 25: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.6847 - loss: 0.6360 - val_accuracy: 0.5667 - val_loss: 0.7800
# Epoch 26/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7079 - loss: 0.5782
# Epoch 26: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7081 - loss: 0.5784 - val_accuracy: 0.5667 - val_loss: 0.7903
# Epoch 27/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7142 - loss: 0.5685
# Epoch 27: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7141 - loss: 0.5689 - val_accuracy: 0.5667 - val_loss: 0.7831
# Epoch 28/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7010 - loss: 0.5839
# Epoch 28: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7011 - loss: 0.5839 - val_accuracy: 0.5667 - val_loss: 0.7933
# Epoch 29/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6879 - loss: 0.6067
# Epoch 29: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.6885 - loss: 0.6062 - val_accuracy: 0.5750 - val_loss: 0.7728
# Epoch 30/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7008 - loss: 0.5719
# Epoch 30: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7010 - loss: 0.5718 - val_accuracy: 0.5750 - val_loss: 0.7877
# Epoch 31/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7153 - loss: 0.5785
# Epoch 31: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.7155 - loss: 0.5781 - val_accuracy: 0.5750 - val_loss: 0.8013
# Epoch 32/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7236 - loss: 0.5666
# Epoch 32: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7235 - loss: 0.5667 - val_accuracy: 0.5583 - val_loss: 0.7859
# Epoch 33/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7200 - loss: 0.5560
# Epoch 33: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7198 - loss: 0.5562 - val_accuracy: 0.5583 - val_loss: 0.7746
# Epoch 34/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7336 - loss: 0.5525
# Epoch 34: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7339 - loss: 0.5523 - val_accuracy: 0.5667 - val_loss: 0.7959
# Epoch 35/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7430 - loss: 0.5486
# Epoch 35: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7427 - loss: 0.5487 - val_accuracy: 0.5583 - val_loss: 0.7810
# Epoch 36/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7394 - loss: 0.5346
# Epoch 36: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.7395 - loss: 0.5345 - val_accuracy: 0.5750 - val_loss: 0.8018
# Epoch 37/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7404 - loss: 0.5363
# Epoch 37: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7400 - loss: 0.5366 - val_accuracy: 0.5583 - val_loss: 0.8017
# Epoch 38/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7620 - loss: 0.5220
# Epoch 38: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.7612 - loss: 0.5224 - val_accuracy: 0.5583 - val_loss: 0.7944
# Epoch 39/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7407 - loss: 0.5366
# Epoch 39: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7407 - loss: 0.5367 - val_accuracy: 0.5583 - val_loss: 0.7797
# Epoch 40/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7470 - loss: 0.5244
# Epoch 40: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7468 - loss: 0.5247 - val_accuracy: 0.5500 - val_loss: 0.7847
# Epoch 41/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7294 - loss: 0.5434
# Epoch 41: val_accuracy improved from 0.57500 to 0.58333, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 302ms/step - accuracy: 0.7296 - loss: 0.5431 - val_accuracy: 0.5833 - val_loss: 0.8376
# Epoch 42/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7372 - loss: 0.5356
# Epoch 42: val_accuracy improved from 0.58333 to 0.59167, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 303ms/step - accuracy: 0.7375 - loss: 0.5354 - val_accuracy: 0.5917 - val_loss: 0.8225
# Epoch 43/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7393 - loss: 0.5119
# Epoch 43: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7394 - loss: 0.5122 - val_accuracy: 0.5917 - val_loss: 0.8295
# Epoch 44/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7766 - loss: 0.5186
# Epoch 44: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7760 - loss: 0.5187 - val_accuracy: 0.5833 - val_loss: 0.8532
# Epoch 45/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7709 - loss: 0.4909
# Epoch 45: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7708 - loss: 0.4911 - val_accuracy: 0.5667 - val_loss: 0.8390
# Epoch 46/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.7769 - loss: 0.4905
# Epoch 46: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 275ms/step - accuracy: 0.7764 - loss: 0.4908 - val_accuracy: 0.5417 - val_loss: 0.8333
# Epoch 47/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7692 - loss: 0.4893
# Epoch 47: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7691 - loss: 0.4897 - val_accuracy: 0.5417 - val_loss: 0.8425
# Epoch 48/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7796 - loss: 0.4892
# Epoch 48: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7792 - loss: 0.4896 - val_accuracy: 0.5583 - val_loss: 0.8504
# Epoch 49/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7819 - loss: 0.4828
# Epoch 49: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.7819 - loss: 0.4828 - val_accuracy: 0.5583 - val_loss: 0.8663
# Epoch 50/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7902 - loss: 0.4683
# Epoch 50: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.7901 - loss: 0.4685 - val_accuracy: 0.5417 - val_loss: 0.8418
# Epoch 51/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8003 - loss: 0.4534
# Epoch 51: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.8001 - loss: 0.4539 - val_accuracy: 0.5417 - val_loss: 0.8550
# Epoch 52/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7677 - loss: 0.4846
# Epoch 52: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.7676 - loss: 0.4847 - val_accuracy: 0.5417 - val_loss: 0.8595
# Epoch 53/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7864 - loss: 0.4874
# Epoch 53: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7866 - loss: 0.4869 - val_accuracy: 0.5417 - val_loss: 0.8860
# Epoch 54/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7785 - loss: 0.4837
# Epoch 54: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.7785 - loss: 0.4838 - val_accuracy: 0.5417 - val_loss: 0.8836
# Epoch 55/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7714 - loss: 0.4902
# Epoch 55: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 273ms/step - accuracy: 0.7719 - loss: 0.4897 - val_accuracy: 0.5417 - val_loss: 0.8960
# Epoch 56/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7762 - loss: 0.4603
# Epoch 56: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7761 - loss: 0.4608 - val_accuracy: 0.5417 - val_loss: 0.8612
# Epoch 57/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7947 - loss: 0.4486
# Epoch 57: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7945 - loss: 0.4491 - val_accuracy: 0.5417 - val_loss: 0.8784
# Epoch 58/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7982 - loss: 0.4601
# Epoch 58: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7981 - loss: 0.4601 - val_accuracy: 0.5333 - val_loss: 0.9001
# Epoch 59/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8100 - loss: 0.4338
# Epoch 59: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.8099 - loss: 0.4341 - val_accuracy: 0.5333 - val_loss: 0.9004
# Epoch 60/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.7902 - loss: 0.4617
# Epoch 60: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.7902 - loss: 0.4614 - val_accuracy: 0.5250 - val_loss: 0.9190
# Epoch 61/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8051 - loss: 0.4238
# Epoch 61: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.8046 - loss: 0.4246 - val_accuracy: 0.5417 - val_loss: 0.8869
# Epoch 62/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8027 - loss: 0.4377
# Epoch 62: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.8026 - loss: 0.4376 - val_accuracy: 0.5333 - val_loss: 0.9181
# Epoch 63/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8028 - loss: 0.4559
# Epoch 63: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.8029 - loss: 0.4556 - val_accuracy: 0.5250 - val_loss: 0.9138
# Epoch 64/64
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8117 - loss: 0.4412
# Epoch 64: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 274ms/step - accuracy: 0.8115 - loss: 0.4414 - val_accuracy: 0.5500 - val_loss: 0.9463

# %%
    # Evaluate the model
    predictions_valid1 = model1.predict([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], batch_size=batch_size1, verbose=1)
    score1 = log_loss(axial_mensicus_label_val, predictions_valid1)

    print(f"Log Loss batch_size-{batch_size1}: {score1}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step
# Log Loss batch_size-16: 2.7127500429789904

# %%
    predictions_valid2 = model2.predict([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], batch_size=batch_size2, verbose=1)
    score2 = log_loss(axial_mensicus_label_val, predictions_valid2)

    print(f"Log Loss batch_size -{batch_size2}: {score2}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step
# Log Loss batch_size -32: 1.4944360236704337

# %%
    predictions_valid3 = model3.predict([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], batch_size=batch_size3, verbose=1)
    score3 = log_loss(axial_mensicus_label_val, predictions_valid3)

    print(f"Log Loss batch_size -{batch_size3}: {score3}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 493ms/step
# Log Loss batch_size -64: 1.5207240027152202

# %%
import matplotlib.pyplot as plt

# Assuming you have `history1`, `history2`, and `history3` from different training runs

# Data from first run
acc1 = history1.history['accuracy']
val_acc1 = history1.history['val_accuracy']


# Data from second run
acc2 = history2.history['accuracy']
val_acc2 = history2.history['val_accuracy']


epochs=range(len(acc1)) #No. of epochs

# Set a wider figure size
plt.figure(figsize=(10, 6))  # Adjust width and height accordingly

# Plot training and validation accuracy for all runs
plt.plot(epochs, acc1, color='blue', label=f"Training Accuracy - {batch_size1}", alpha=0.8)
plt.plot(epochs, val_acc1, color='blue', linestyle='--', label=f'Validation Accuracy - {batch_size1}', alpha=0.8)

plt.plot(epochs, acc2, color='green', label=f'Training Accuracy - {batch_size2}', alpha=0.8)
plt.plot(epochs, val_acc2, color='green', linestyle='--', label=f'Validation Accuracy - {batch_size2}', alpha=0.8)



# Adjust title and labels
plt.title(f'Training and Validation Accuracy - Batchsize')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

# Add grid for better readability
plt.grid(True)


plt.legend()

plt.savefig(f'Train_val_acc_multiple_runs.png')
plt.show()

# %% [markdown]
# ## Model evaluation

# %%
# Data from first run
loss1 = history1.history['loss']
val_loss1 = history1.history['val_loss']
# Data from second run
loss2 = history2.history['loss']
val_loss2 = history2.history['val_loss']


plt.figure(figsize=(10, 6))


plt.plot(epochs, loss1, color='blue', label=f"Training Loss - {batch_size1}", alpha=0.8)
plt.plot(epochs, val_loss1, color='blue', linestyle='--', label=f'Validation Loss - {batch_size1}', alpha=0.8)

plt.plot(epochs, loss2, color='green', label=f'Training Loss - {batch_size2}', alpha=0.8)
plt.plot(epochs, val_loss2, color='green', linestyle='--', label=f'Validation Loss - {batch_size2}', alpha=0.8)



# Adjust title and labels
plt.title(f'Training and Validation Loss - Batchsize')
plt.xlabel('Epochs')
plt.ylabel('Loss')


plt.grid(True)

# Position legend outside the plot (to the right)
plt.legend()

# Save and display the plot
plt.tight_layout()
plt.savefig(f'Train_val_loss_multiple_runs.png')
plt.show()

# %%
# Function to calculate accuracy and misclassification
def calculate_accuracy(ypred, ytest):
    total = 0
    accurate = 0
    accurateindex = []
    wrongindex = []

    for i in range(len(ypred)):
        if np.argmax(ypred[i]) == np.argmax(ytest[i]):
            accurate += 1
            accurateindex.append(i)
        else:
            wrongindex.append(i)
        total += 1

    accuracy = round(accurate / total * 100, 3)
    return total, accurate, total - accurate, accuracy, accurateindex, wrongindex

# %%
total1, accurate1, wrong_1, accuracy_1, accurateindex_axial, wrongindex_axial = calculate_accuracy(predictions_valid1, axial_mensicus_label_val)
print(' - Total test data:', total1, '\tAccurately predicted data:', accurate1, '\tWrongly predicted data:', wrong_1)
print(f'{batch_size1} learning batch_size:', accuracy_1, '%')


total2, accurate2, wrong_2, accuracy_2, accurateindex_axial, wrongindex_axial = calculate_accuracy(predictions_valid2, axial_mensicus_label_val)
print(' - Total test data:', total2, '\tAccurately predicted data:', accurate2, '\tWrongly predicted data:', wrong_2)
print(f'{batch_size2} Dropout batch_size:', accuracy_2, '%')
# Out:
#  - Total test data: 120 	Accurately predicted data: 64 	Wrongly predicted data: 56
# 16 learning batch_size: 53.333 %
#  - Total test data: 120 	Accurately predicted data: 61 	Wrongly predicted data: 59
# 32 Dropout batch_size: 50.833 %
