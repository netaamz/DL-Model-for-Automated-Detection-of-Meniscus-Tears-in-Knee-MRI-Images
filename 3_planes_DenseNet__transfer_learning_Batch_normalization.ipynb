# %% [markdown]
# <a href="https://colab.research.google.com/github/netaamz/DL-Model-for-Automated-Detection-of-Meniscus-Tears-in-Knee-MRI-Images/blob/main/3_planes_DenseNet__transfer_learning_Batch_normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone: Development of an algorithm for automatic detection of meniscus tears in radiographic images of the knee.

# %% [markdown]
# Important note: a pre processing is required, avilable notebook via github

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install tensorflow
# !pip install keras
# !pip install sklearn
# !pip install opencv-python
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)

# %% [markdown]
# ## Data import

# %% [markdown]
# **Data from [MRNet](https://stanfordmlgroup.github.io/competitions/mrnet/):**
# * Images of 1370 knee MRI exams performed at Stanford University Medical Center. The dataset contains 1,104 (80.6%) abnormal exams,  with 319 (23.3%) ACL tears and 508 (37.1%) meniscal tears; labels were obtained through manual extraction from clinical reports.
# * train set: consists of 1130 MRI images from coronal, sagittal and transverse planes
# * validation set: consists of 120 MRI images from coronal, sagittal and transverse planes

# %% [markdown]
# Connect google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Data generation for meniscus
# The dataset contains *s* x 256 x 256 images. Since middle images are the most useful, only 3 middle slides in the series are retained.

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
def data_gen(dataset_type, plane, diagnosis):
    '''this function gets the data from the extracted datset'''
    # for eg, (train, sagittal, mensicus)
    if dataset_type == 'train':
        go = '/content/drive/My Drive/miniscus data set/MRNet-v1.0/train_transformf' # if we want without filter then:  /content/drive/My Drive/miniscus data set/MRNet-v1.0/train_transform
    else:
        go = '/content/drive/My Drive/miniscus data set/MRNet-v1.0/valid_transformf' # if we want without filter then: /content/drive/My Drive/miniscus data set/MRNet-v1.0/valid_transform

    plane_dir = f'{go}/{plane}.npy'

    data = np.load(plane_dir)
    label_path = f'/content/drive/My Drive/miniscus data set/MRNet-v1.0/{dataset_type}-{diagnosis}.csv'
#     label_path = f'data/{dataset_type}-{diagnosis}.csv'
    label_df = pd.read_csv(label_path, names=['nr', diagnosis])
    label_data = list(label_df[diagnosis])

    return(data, label_data)

# %% [markdown]
# Note that training data for all planes are the same. Only labels are different.

# %%
# generate training input
coronal_mensicus, coronal_mensicus_label = data_gen('train', 'coronal/extracted_images', 'meniscus')
axial_mensicus, axial_mensicus_label = data_gen('train', 'axial/extracted_images', 'meniscus')
sagittal_mensicus, sagittal_mensicus_label = data_gen('train', 'sagittal/extracted_images', 'meniscus')
print(sagittal_mensicus.shape)
# generate validation
coronal_mensicus_val, coronal_mensicus_label_val  = data_gen('valid', 'coronal/extracted_images', 'meniscus')
axial_mensicus_val, axial_mensicus_label_val  = data_gen('valid', 'axial/extracted_images', 'meniscus')
sagittal_mensicus_val, sagittal_mensicus_label_val  = data_gen('valid', 'sagittal/extracted_images', 'meniscus')
# Out:
# (1130, 256, 256, 3)

# %%
sagittal_mensicus_val.view
# Out:
# <function ndarray.view>

# %%
from keras.utils import to_categorical  # Import to_categorical
base_path = "/content/drive/My Drive/miniscus data set/MRNet-v1.0/"

num_classes =2

sagittal_mensicus_label = to_categorical(sagittal_mensicus_label, num_classes)
sagittal_mensicus_label_val = to_categorical(sagittal_mensicus_label_val, num_classes)

coronal_mensicus_label = to_categorical(coronal_mensicus_label, num_classes)
coronal_mensicus_label_val = to_categorical(coronal_mensicus_label_val, num_classes)

axial_mensicus_label = to_categorical(axial_mensicus_label, num_classes)
axial_mensicus_label_val = to_categorical(axial_mensicus_label_val, num_classes)

# %% [markdown]
# ## Model Architecture

# %% [markdown]
# The model is designed to classify grayscale MRI images for detecting normal menisci or meniscus tears. The input images, resized to 256x256x3, undergo preprocessing steps, including splicing and applying a White Top Hat filter to enhance features.
# * The preprocessed images are then fed into a pre-trained DenseNet121
# architecture, which has been modified to exclude its top classification layers.
# * The DenseNet121 model processes the input and outputs feature maps, which are subsequently passed through a Global Average Pooling layer, reducing the spatial dimensions into a 1D vector.
# * A Batch Normalization layer is applied to stabilize the network and improve learning performance.
# * The feature vector is then fed into a Dense Layer with 1024 units and ReLU activation to extract high-level features, followed by a Dropout Layer to mitigate overfitting.
# A second Dense Layer, also with 1024 units and ReLU activation, further refines the feature space.
# * Finally, the model outputs predictions through a Dense Layer with 2 units and sigmoid activation, representing the probabilities of the two classes (normal or meniscus tear).

# %% [markdown]
# ![Model Architecture -separated planes.drawio - Copy.png](data:image/png;base64,...)

# %%
import tensorflow as tf
import keras
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Lambda, BatchNormalization, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint


def create_model(input_shape, num_classes, dropout):
    # Load the pre-trained DenseNet121 model
    base_model = DenseNet121(weights='imagenet', include_top=False, pooling=None,input_shape=input_shape)
    input_tensor = Input(shape=input_shape)

    x = base_model(input_tensor)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)  # Batch Normalization
    x = Dense(1024, activation='relu')(x)
    x = Dropout(dropout)(x)
    x = Dense(1024, activation='relu')(x)
    output = Dense(num_classes, activation='sigmoid')(x)
    # Create the final model
    model = Model(inputs=input_tensor, outputs=output)

    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = False

    return model

# %% [markdown]
# ##  Hyperparameters
# define hyper parameters for training

# %%
    # Define your parameters
    img_rows, img_cols = 256, 256
    channel = 3
    batch_size = 32
    nb_epoch = 100
    dropout = 0.4
    lr = 5e-4  # Learning rate

# %% [markdown]
# ## Train

# %%
import tensorflow as tf
import keras

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint


if __name__ == '__main__':
    # Create the model
    input_shape = (img_rows, img_cols, channel)
    model_axial = create_model(input_shape, num_classes, dropout)
    model_coronal = create_model(input_shape, num_classes, dropout)
    model_sagittal = create_model(input_shape, num_classes, dropout)

    # Compile the model

    model_axial.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    model_coronal.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    model_sagittal.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Set up the checkpoint
    filepath = "bestmodel.keras"
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]


    # Train the model - axial
    history_axial = model_axial.fit(axial_mensicus, axial_mensicus_label,
                        batch_size=batch_size,
                        epochs=nb_epoch,
                        shuffle=True,
                        verbose=1,
                        validation_data=(axial_mensicus_val, axial_mensicus_label_val),
                        callbacks=callbacks_list)

    # Train the model - coronal
    history_coronal = model_coronal.fit(coronal_mensicus, coronal_mensicus_label,
                        batch_size=batch_size,
                        epochs=nb_epoch,
                        shuffle=True,
                        verbose=1,
                        validation_data=(coronal_mensicus_val, coronal_mensicus_label_val),
                        callbacks=callbacks_list)

    # Train the model- sagittal
    history_sagittal = model_sagittal.fit(sagittal_mensicus, sagittal_mensicus_label,
                        batch_size=batch_size,
                        epochs=nb_epoch,
                        shuffle=True,
                        verbose=1,
                        validation_data=(sagittal_mensicus_val, sagittal_mensicus_label_val),
                        callbacks=callbacks_list)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.6216 - loss: 0.6855
# Epoch 1: val_accuracy improved from -inf to 0.56667, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 56s 860ms/step - accuracy: 0.6216 - loss: 0.6854 - val_accuracy: 0.5667 - val_loss: 0.8322
# Epoch 2/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6495 - loss: 0.6781
# Epoch 2: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.6498 - loss: 0.6778 - val_accuracy: 0.5667 - val_loss: 0.7506
# Epoch 3/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6372 - loss: 0.6753
# Epoch 3: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.6371 - loss: 0.6752 - val_accuracy: 0.5667 - val_loss: 0.7292
# Epoch 4/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6736 - loss: 0.6349
# Epoch 4: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - accuracy: 0.6720 - loss: 0.6362 - val_accuracy: 0.5667 - val_loss: 0.7246
# Epoch 5/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6194 - loss: 0.6778
# Epoch 5: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.6203 - loss: 0.6767 - val_accuracy: 0.5667 - val_loss: 0.7398
# Epoch 6/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6497 - loss: 0.6632
# Epoch 6: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.6497 - loss: 0.6630 - val_accuracy: 0.5667 - val_loss: 0.7370
# Epoch 7/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6548 - loss: 0.6351
# Epoch 7: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.6545 - loss: 0.6358 - val_accuracy: 0.5667 - val_loss: 0.7467
# Epoch 8/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6416 - loss: 0.6553
# Epoch 8: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.6422 - loss: 0.6550 - val_accuracy: 0.5667 - val_loss: 0.7436
# Epoch 9/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6837 - loss: 0.6213
# Epoch 9: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.6824 - loss: 0.6222 - val_accuracy: 0.5583 - val_loss: 0.7311
# Epoch 10/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6425 - loss: 0.6408
# Epoch 10: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.6426 - loss: 0.6408 - val_accuracy: 0.5583 - val_loss: 0.7440
# Epoch 11/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6446 - loss: 0.6442
# Epoch 11: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6453 - loss: 0.6439 - val_accuracy: 0.5583 - val_loss: 0.7398
# Epoch 12/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6592 - loss: 0.6298
# Epoch 12: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6589 - loss: 0.6299 - val_accuracy: 0.5667 - val_loss: 0.7563
# Epoch 13/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6588 - loss: 0.6275
# Epoch 13: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6588 - loss: 0.6275 - val_accuracy: 0.5583 - val_loss: 0.7433
# Epoch 14/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6364 - loss: 0.6511
# Epoch 14: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6380 - loss: 0.6501 - val_accuracy: 0.5583 - val_loss: 0.7486
# Epoch 15/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6748 - loss: 0.6101
# Epoch 15: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6738 - loss: 0.6107 - val_accuracy: 0.5583 - val_loss: 0.7353
# Epoch 16/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6633 - loss: 0.6218
# Epoch 16: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6634 - loss: 0.6217 - val_accuracy: 0.5500 - val_loss: 0.7323
# Epoch 17/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6619 - loss: 0.6093
# Epoch 17: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6618 - loss: 0.6097 - val_accuracy: 0.5500 - val_loss: 0.7413
# Epoch 18/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6736 - loss: 0.6086
# Epoch 18: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6730 - loss: 0.6091 - val_accuracy: 0.5500 - val_loss: 0.7278
# Epoch 19/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6655 - loss: 0.6239
# Epoch 19: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6659 - loss: 0.6235 - val_accuracy: 0.5417 - val_loss: 0.7410
# Epoch 20/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6544 - loss: 0.6082
# Epoch 20: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6552 - loss: 0.6083 - val_accuracy: 0.5417 - val_loss: 0.7445
# Epoch 21/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6753 - loss: 0.5960
# Epoch 21: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6746 - loss: 0.5967 - val_accuracy: 0.5500 - val_loss: 0.7401
# Epoch 22/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6722 - loss: 0.6132
# Epoch 22: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6724 - loss: 0.6130 - val_accuracy: 0.5500 - val_loss: 0.7437
# Epoch 23/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6698 - loss: 0.6174
# Epoch 23: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6708 - loss: 0.6165 - val_accuracy: 0.5583 - val_loss: 0.7558
# Epoch 24/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6921 - loss: 0.5825
# Epoch 24: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6917 - loss: 0.5831 - val_accuracy: 0.5500 - val_loss: 0.7436
# Epoch 25/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6771 - loss: 0.6024
# Epoch 25: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6775 - loss: 0.6024 - val_accuracy: 0.5500 - val_loss: 0.7462
# Epoch 26/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6790 - loss: 0.5846
# Epoch 26: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6799 - loss: 0.5848 - val_accuracy: 0.5500 - val_loss: 0.7393
# Epoch 27/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6599 - loss: 0.5903
# Epoch 27: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6606 - loss: 0.5904 - val_accuracy: 0.5500 - val_loss: 0.7577
# Epoch 28/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6790 - loss: 0.5982
# Epoch 28: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6795 - loss: 0.5976 - val_accuracy: 0.5500 - val_loss: 0.7537
# Epoch 29/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6867 - loss: 0.5864
# Epoch 29: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6876 - loss: 0.5861 - val_accuracy: 0.5500 - val_loss: 0.7480
# Epoch 30/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6904 - loss: 0.5953
# Epoch 30: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6910 - loss: 0.5948 - val_accuracy: 0.5500 - val_loss: 0.7589
# Epoch 31/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7126 - loss: 0.5691
# Epoch 31: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7118 - loss: 0.5696 - val_accuracy: 0.5417 - val_loss: 0.7406
# Epoch 32/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7207 - loss: 0.5741
# Epoch 32: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7204 - loss: 0.5741 - val_accuracy: 0.5500 - val_loss: 0.7523
# Epoch 33/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6791 - loss: 0.5924
# Epoch 33: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6799 - loss: 0.5918 - val_accuracy: 0.5417 - val_loss: 0.7526
# Epoch 34/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7001 - loss: 0.5678
# Epoch 34: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6997 - loss: 0.5682 - val_accuracy: 0.5417 - val_loss: 0.7493
# Epoch 35/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7182 - loss: 0.5541
# Epoch 35: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7178 - loss: 0.5548 - val_accuracy: 0.5333 - val_loss: 0.7453
# Epoch 36/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7168 - loss: 0.5712
# Epoch 36: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7169 - loss: 0.5709 - val_accuracy: 0.5417 - val_loss: 0.7514
# Epoch 37/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7062 - loss: 0.5594
# Epoch 37: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7057 - loss: 0.5600 - val_accuracy: 0.5417 - val_loss: 0.7407
# Epoch 38/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7211 - loss: 0.5658
# Epoch 38: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7206 - loss: 0.5659 - val_accuracy: 0.5417 - val_loss: 0.7448
# Epoch 39/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7248 - loss: 0.5463
# Epoch 39: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7238 - loss: 0.5470 - val_accuracy: 0.5333 - val_loss: 0.7474
# Epoch 40/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7294 - loss: 0.5647
# Epoch 40: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7304 - loss: 0.5640 - val_accuracy: 0.5250 - val_loss: 0.7560
# Epoch 41/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7093 - loss: 0.5656
# Epoch 41: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7098 - loss: 0.5650 - val_accuracy: 0.5417 - val_loss: 0.7695
# Epoch 42/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7508 - loss: 0.5172
# Epoch 42: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7499 - loss: 0.5185 - val_accuracy: 0.5417 - val_loss: 0.7499
# Epoch 43/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7339 - loss: 0.5531
# Epoch 43: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7340 - loss: 0.5530 - val_accuracy: 0.5417 - val_loss: 0.7504
# Epoch 44/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7458 - loss: 0.5403
# Epoch 44: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7454 - loss: 0.5404 - val_accuracy: 0.5333 - val_loss: 0.7577
# Epoch 45/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7519 - loss: 0.5226
# Epoch 45: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7510 - loss: 0.5235 - val_accuracy: 0.5667 - val_loss: 0.7494
# Epoch 46/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7579 - loss: 0.5313
# Epoch 46: val_accuracy improved from 0.56667 to 0.57500, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - accuracy: 0.7578 - loss: 0.5312 - val_accuracy: 0.5750 - val_loss: 0.7543
# Epoch 47/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7554 - loss: 0.5218
# Epoch 47: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7553 - loss: 0.5223 - val_accuracy: 0.5667 - val_loss: 0.7588
# Epoch 48/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7594 - loss: 0.5311
# Epoch 48: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7592 - loss: 0.5309 - val_accuracy: 0.5333 - val_loss: 0.7711
# Epoch 49/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7436 - loss: 0.5356
# Epoch 49: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7437 - loss: 0.5357 - val_accuracy: 0.5667 - val_loss: 0.7630
# Epoch 50/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7359 - loss: 0.5274
# Epoch 50: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7367 - loss: 0.5270 - val_accuracy: 0.5333 - val_loss: 0.7714
# Epoch 51/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7365 - loss: 0.5265
# Epoch 51: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7373 - loss: 0.5262 - val_accuracy: 0.5500 - val_loss: 0.7839
# Epoch 52/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7369 - loss: 0.5221
# Epoch 52: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7376 - loss: 0.5216 - val_accuracy: 0.5667 - val_loss: 0.7748
# Epoch 53/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7694 - loss: 0.5071
# Epoch 53: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7685 - loss: 0.5073 - val_accuracy: 0.5250 - val_loss: 0.7679
# Epoch 54/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7525 - loss: 0.5340
# Epoch 54: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7530 - loss: 0.5326 - val_accuracy: 0.5583 - val_loss: 0.7758
# Epoch 55/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7676 - loss: 0.4965
# Epoch 55: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7671 - loss: 0.4968 - val_accuracy: 0.5250 - val_loss: 0.7781
# Epoch 56/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7522 - loss: 0.5184
# Epoch 56: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7531 - loss: 0.5178 - val_accuracy: 0.5250 - val_loss: 0.7831
# Epoch 57/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7583 - loss: 0.5086
# Epoch 57: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7585 - loss: 0.5080 - val_accuracy: 0.5333 - val_loss: 0.7955
# Epoch 58/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7850 - loss: 0.4879
# Epoch 58: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.7847 - loss: 0.4879 - val_accuracy: 0.5167 - val_loss: 0.7901
# Epoch 59/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7869 - loss: 0.4789
# Epoch 59: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7863 - loss: 0.4796 - val_accuracy: 0.5333 - val_loss: 0.7977
# Epoch 60/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7998 - loss: 0.4649
# Epoch 60: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7995 - loss: 0.4655 - val_accuracy: 0.5167 - val_loss: 0.7965
# Epoch 61/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7677 - loss: 0.4947
# Epoch 61: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7685 - loss: 0.4939 - val_accuracy: 0.5250 - val_loss: 0.8091
# Epoch 62/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7802 - loss: 0.4690
# Epoch 62: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7799 - loss: 0.4697 - val_accuracy: 0.5167 - val_loss: 0.8052
# Epoch 63/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7799 - loss: 0.4921
# Epoch 63: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7805 - loss: 0.4911 - val_accuracy: 0.5333 - val_loss: 0.8170
# Epoch 64/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8118 - loss: 0.4547
# Epoch 64: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8106 - loss: 0.4559 - val_accuracy: 0.4917 - val_loss: 0.8072
# Epoch 65/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7853 - loss: 0.4772
# Epoch 65: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7860 - loss: 0.4769 - val_accuracy: 0.5250 - val_loss: 0.8118
# Epoch 66/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8086 - loss: 0.4483
# Epoch 66: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8069 - loss: 0.4495 - val_accuracy: 0.4833 - val_loss: 0.8112
# Epoch 67/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7956 - loss: 0.4867
# Epoch 67: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7962 - loss: 0.4858 - val_accuracy: 0.5417 - val_loss: 0.8240
# Epoch 68/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7948 - loss: 0.4581
# Epoch 68: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7945 - loss: 0.4582 - val_accuracy: 0.5250 - val_loss: 0.8155
# Epoch 69/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7910 - loss: 0.4647
# Epoch 69: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7914 - loss: 0.4645 - val_accuracy: 0.5000 - val_loss: 0.8201
# Epoch 70/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8223 - loss: 0.4224
# Epoch 70: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8214 - loss: 0.4237 - val_accuracy: 0.4917 - val_loss: 0.8204
# Epoch 71/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8291 - loss: 0.4347
# Epoch 71: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8288 - loss: 0.4352 - val_accuracy: 0.4833 - val_loss: 0.8255
# Epoch 72/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8152 - loss: 0.4303
# Epoch 72: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8148 - loss: 0.4308 - val_accuracy: 0.4833 - val_loss: 0.8315
# Epoch 73/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8259 - loss: 0.4327
# Epoch 73: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8255 - loss: 0.4327 - val_accuracy: 0.4750 - val_loss: 0.8354
# Epoch 74/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8243 - loss: 0.4358
# Epoch 74: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8238 - loss: 0.4358 - val_accuracy: 0.4917 - val_loss: 0.8385
# Epoch 75/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8028 - loss: 0.4336
# Epoch 75: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8030 - loss: 0.4334 - val_accuracy: 0.5000 - val_loss: 0.8462
# Epoch 76/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8025 - loss: 0.4342
# Epoch 76: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8037 - loss: 0.4334 - val_accuracy: 0.4833 - val_loss: 0.8520
# Epoch 77/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8306 - loss: 0.4192
# Epoch 77: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8304 - loss: 0.4193 - val_accuracy: 0.5250 - val_loss: 0.8596
# Epoch 78/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8208 - loss: 0.4303
# Epoch 78: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.8219 - loss: 0.4293 - val_accuracy: 0.5083 - val_loss: 0.8655
# Epoch 79/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8233 - loss: 0.4110
# Epoch 79: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8236 - loss: 0.4111 - val_accuracy: 0.5000 - val_loss: 0.8643
# Epoch 80/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8240 - loss: 0.4256
# Epoch 80: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8240 - loss: 0.4254 - val_accuracy: 0.5083 - val_loss: 0.8702
# Epoch 81/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8626 - loss: 0.3770
# Epoch 81: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8617 - loss: 0.3779 - val_accuracy: 0.5083 - val_loss: 0.8673
# Epoch 82/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8368 - loss: 0.3988
# Epoch 82: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8369 - loss: 0.3989 - val_accuracy: 0.5333 - val_loss: 0.8909
# Epoch 83/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8156 - loss: 0.4181
# Epoch 83: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8163 - loss: 0.4177 - val_accuracy: 0.5250 - val_loss: 0.8867
# Epoch 84/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8470 - loss: 0.3887
# Epoch 84: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8464 - loss: 0.3896 - val_accuracy: 0.5083 - val_loss: 0.8852
# Epoch 85/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8513 - loss: 0.3893
# Epoch 85: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8503 - loss: 0.3898 - val_accuracy: 0.5167 - val_loss: 0.8888
# Epoch 86/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8563 - loss: 0.3824
# Epoch 86: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8558 - loss: 0.3827 - val_accuracy: 0.4917 - val_loss: 0.8986
# Epoch 87/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8639 - loss: 0.3717
# Epoch 87: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8624 - loss: 0.3724 - val_accuracy: 0.5167 - val_loss: 0.9165
# Epoch 88/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8327 - loss: 0.3907
# Epoch 88: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8331 - loss: 0.3904 - val_accuracy: 0.4917 - val_loss: 0.9159
# Epoch 89/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8475 - loss: 0.3904
# Epoch 89: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8478 - loss: 0.3899 - val_accuracy: 0.4917 - val_loss: 0.9251
# Epoch 90/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8542 - loss: 0.3611
# Epoch 90: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8542 - loss: 0.3612 - val_accuracy: 0.4917 - val_loss: 0.9306
# Epoch 91/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8585 - loss: 0.3761
# Epoch 91: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8576 - loss: 0.3765 - val_accuracy: 0.5083 - val_loss: 0.9321
# Epoch 92/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8547 - loss: 0.3581
# Epoch 92: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8548 - loss: 0.3585 - val_accuracy: 0.4917 - val_loss: 0.9377
# Epoch 93/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8627 - loss: 0.3594
# Epoch 93: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8625 - loss: 0.3601 - val_accuracy: 0.4917 - val_loss: 0.9411
# Epoch 94/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8458 - loss: 0.3749
# Epoch 94: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8462 - loss: 0.3744 - val_accuracy: 0.5083 - val_loss: 0.9501
# Epoch 95/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8519 - loss: 0.3605
# Epoch 95: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8524 - loss: 0.3598 - val_accuracy: 0.4833 - val_loss: 0.9618
# Epoch 96/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8542 - loss: 0.3617
# Epoch 96: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8542 - loss: 0.3617 - val_accuracy: 0.4917 - val_loss: 0.9589
# Epoch 97/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8696 - loss: 0.3300
# Epoch 97: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8697 - loss: 0.3303 - val_accuracy: 0.4833 - val_loss: 0.9660
# Epoch 98/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8757 - loss: 0.3392
# Epoch 98: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8759 - loss: 0.3391 - val_accuracy: 0.4833 - val_loss: 0.9758
# Epoch 99/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8547 - loss: 0.3379
# Epoch 99: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8552 - loss: 0.3377 - val_accuracy: 0.4750 - val_loss: 0.9925
# Epoch 100/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8483 - loss: 0.3658
# Epoch 100: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8489 - loss: 0.3648 - val_accuracy: 0.4833 - val_loss: 0.9850
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.5221 - loss: 0.7268
# Epoch 1: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 34s 500ms/step - accuracy: 0.5236 - loss: 0.7261 - val_accuracy: 0.5667 - val_loss: 0.7759
# Epoch 2/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6368 - loss: 0.6737
# Epoch 2: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6370 - loss: 0.6734 - val_accuracy: 0.5583 - val_loss: 0.7062
# Epoch 3/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6313 - loss: 0.6692
# Epoch 3: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6316 - loss: 0.6690 - val_accuracy: 0.5667 - val_loss: 0.6918
# Epoch 4/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6303 - loss: 0.6700
# Epoch 4: val_accuracy did not improve from 0.57500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6310 - loss: 0.6696 - val_accuracy: 0.5750 - val_loss: 0.6861
# Epoch 5/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6438 - loss: 0.6593
# Epoch 5: val_accuracy improved from 0.57500 to 0.59167, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 120ms/step - accuracy: 0.6442 - loss: 0.6589 - val_accuracy: 0.5917 - val_loss: 0.6802
# Epoch 6/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6227 - loss: 0.6688
# Epoch 6: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6239 - loss: 0.6678 - val_accuracy: 0.5917 - val_loss: 0.6785
# Epoch 7/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6507 - loss: 0.6479
# Epoch 7: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.6508 - loss: 0.6477 - val_accuracy: 0.5917 - val_loss: 0.6748
# Epoch 8/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6620 - loss: 0.6439
# Epoch 8: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.6615 - loss: 0.6440 - val_accuracy: 0.5917 - val_loss: 0.6727
# Epoch 9/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6448 - loss: 0.6410
# Epoch 9: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.6451 - loss: 0.6411 - val_accuracy: 0.5750 - val_loss: 0.6817
# Epoch 10/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.6443 - loss: 0.6394
# Epoch 10: val_accuracy improved from 0.59167 to 0.60000, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.6446 - loss: 0.6394 - val_accuracy: 0.6000 - val_loss: 0.6737
# Epoch 11/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6641 - loss: 0.6187
# Epoch 11: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6638 - loss: 0.6190 - val_accuracy: 0.5917 - val_loss: 0.6763
# Epoch 12/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6553 - loss: 0.6399
# Epoch 12: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6553 - loss: 0.6396 - val_accuracy: 0.5917 - val_loss: 0.6781
# Epoch 13/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6558 - loss: 0.6348
# Epoch 13: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6560 - loss: 0.6343 - val_accuracy: 0.6000 - val_loss: 0.6738
# Epoch 14/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6415 - loss: 0.6484
# Epoch 14: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6427 - loss: 0.6472 - val_accuracy: 0.5750 - val_loss: 0.6796
# Epoch 15/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6594 - loss: 0.6303
# Epoch 15: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6595 - loss: 0.6298 - val_accuracy: 0.5833 - val_loss: 0.6799
# Epoch 16/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6802 - loss: 0.6125
# Epoch 16: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6797 - loss: 0.6128 - val_accuracy: 0.5917 - val_loss: 0.6779
# Epoch 17/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6765 - loss: 0.6011
# Epoch 17: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6755 - loss: 0.6018 - val_accuracy: 0.5917 - val_loss: 0.6788
# Epoch 18/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6701 - loss: 0.6290
# Epoch 18: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6703 - loss: 0.6287 - val_accuracy: 0.5917 - val_loss: 0.6836
# Epoch 19/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6723 - loss: 0.6106
# Epoch 19: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6721 - loss: 0.6111 - val_accuracy: 0.5917 - val_loss: 0.6843
# Epoch 20/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6753 - loss: 0.6114
# Epoch 20: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6750 - loss: 0.6114 - val_accuracy: 0.5917 - val_loss: 0.6846
# Epoch 21/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6713 - loss: 0.6027
# Epoch 21: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6713 - loss: 0.6029 - val_accuracy: 0.5917 - val_loss: 0.6846
# Epoch 22/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6909 - loss: 0.5948
# Epoch 22: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6903 - loss: 0.5954 - val_accuracy: 0.5917 - val_loss: 0.6863
# Epoch 23/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6772 - loss: 0.6105
# Epoch 23: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6773 - loss: 0.6106 - val_accuracy: 0.5750 - val_loss: 0.6937
# Epoch 24/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6752 - loss: 0.6050
# Epoch 24: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6757 - loss: 0.6047 - val_accuracy: 0.6000 - val_loss: 0.6932
# Epoch 25/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6961 - loss: 0.5889
# Epoch 25: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6953 - loss: 0.5895 - val_accuracy: 0.5750 - val_loss: 0.6851
# Epoch 26/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6986 - loss: 0.5931
# Epoch 26: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6980 - loss: 0.5932 - val_accuracy: 0.5917 - val_loss: 0.6921
# Epoch 27/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6614 - loss: 0.6029
# Epoch 27: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6628 - loss: 0.6023 - val_accuracy: 0.5750 - val_loss: 0.6935
# Epoch 28/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6990 - loss: 0.5796
# Epoch 28: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6988 - loss: 0.5802 - val_accuracy: 0.6000 - val_loss: 0.6929
# Epoch 29/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7074 - loss: 0.5815
# Epoch 29: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7070 - loss: 0.5816 - val_accuracy: 0.5750 - val_loss: 0.6883
# Epoch 30/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7139 - loss: 0.5740
# Epoch 30: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7138 - loss: 0.5739 - val_accuracy: 0.5833 - val_loss: 0.6956
# Epoch 31/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7174 - loss: 0.5887
# Epoch 31: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7165 - loss: 0.5888 - val_accuracy: 0.5667 - val_loss: 0.6939
# Epoch 32/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6988 - loss: 0.5774
# Epoch 32: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6989 - loss: 0.5771 - val_accuracy: 0.5750 - val_loss: 0.6979
# Epoch 33/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6982 - loss: 0.5895
# Epoch 33: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6987 - loss: 0.5889 - val_accuracy: 0.5750 - val_loss: 0.6977
# Epoch 34/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7332 - loss: 0.5567
# Epoch 34: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7319 - loss: 0.5577 - val_accuracy: 0.5750 - val_loss: 0.6960
# Epoch 35/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6987 - loss: 0.5645
# Epoch 35: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6992 - loss: 0.5647 - val_accuracy: 0.5667 - val_loss: 0.6999
# Epoch 36/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6910 - loss: 0.5703
# Epoch 36: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6925 - loss: 0.5701 - val_accuracy: 0.5667 - val_loss: 0.6954
# Epoch 37/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7194 - loss: 0.5712
# Epoch 37: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7192 - loss: 0.5712 - val_accuracy: 0.5667 - val_loss: 0.7044
# Epoch 38/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6922 - loss: 0.5883
# Epoch 38: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6935 - loss: 0.5873 - val_accuracy: 0.5667 - val_loss: 0.7041
# Epoch 39/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7501 - loss: 0.5431
# Epoch 39: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7482 - loss: 0.5442 - val_accuracy: 0.5833 - val_loss: 0.6972
# Epoch 40/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6925 - loss: 0.5835
# Epoch 40: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6936 - loss: 0.5825 - val_accuracy: 0.5750 - val_loss: 0.7129
# Epoch 41/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7348 - loss: 0.5510
# Epoch 41: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7343 - loss: 0.5512 - val_accuracy: 0.5833 - val_loss: 0.6966
# Epoch 42/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7448 - loss: 0.5570
# Epoch 42: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7448 - loss: 0.5567 - val_accuracy: 0.5667 - val_loss: 0.7093
# Epoch 43/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7276 - loss: 0.5404
# Epoch 43: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7270 - loss: 0.5410 - val_accuracy: 0.5667 - val_loss: 0.7026
# Epoch 44/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7153 - loss: 0.5596
# Epoch 44: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7161 - loss: 0.5592 - val_accuracy: 0.5833 - val_loss: 0.7040
# Epoch 45/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7191 - loss: 0.5511
# Epoch 45: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7195 - loss: 0.5509 - val_accuracy: 0.5917 - val_loss: 0.7047
# Epoch 46/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7136 - loss: 0.5564
# Epoch 46: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7140 - loss: 0.5560 - val_accuracy: 0.5833 - val_loss: 0.7050
# Epoch 47/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7266 - loss: 0.5388
# Epoch 47: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7267 - loss: 0.5391 - val_accuracy: 0.5833 - val_loss: 0.7048
# Epoch 48/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7295 - loss: 0.5612
# Epoch 48: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7303 - loss: 0.5603 - val_accuracy: 0.5750 - val_loss: 0.7089
# Epoch 49/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7357 - loss: 0.5327
# Epoch 49: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7353 - loss: 0.5329 - val_accuracy: 0.6000 - val_loss: 0.7081
# Epoch 50/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7522 - loss: 0.5415
# Epoch 50: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7527 - loss: 0.5413 - val_accuracy: 0.5917 - val_loss: 0.7125
# Epoch 51/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7245 - loss: 0.5570
# Epoch 51: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7253 - loss: 0.5559 - val_accuracy: 0.5833 - val_loss: 0.7148
# Epoch 52/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7757 - loss: 0.5035
# Epoch 52: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7752 - loss: 0.5043 - val_accuracy: 0.5667 - val_loss: 0.7084
# Epoch 53/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7355 - loss: 0.5248
# Epoch 53: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.7360 - loss: 0.5247 - val_accuracy: 0.5750 - val_loss: 0.7144
# Epoch 54/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7587 - loss: 0.5137
# Epoch 54: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7578 - loss: 0.5141 - val_accuracy: 0.5833 - val_loss: 0.7044
# Epoch 55/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7558 - loss: 0.5236
# Epoch 55: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7561 - loss: 0.5236 - val_accuracy: 0.6000 - val_loss: 0.7188
# Epoch 56/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7641 - loss: 0.5050
# Epoch 56: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7636 - loss: 0.5054 - val_accuracy: 0.5750 - val_loss: 0.7138
# Epoch 57/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7762 - loss: 0.5074
# Epoch 57: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7764 - loss: 0.5073 - val_accuracy: 0.5583 - val_loss: 0.7245
# Epoch 58/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7532 - loss: 0.5112
# Epoch 58: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.7531 - loss: 0.5113 - val_accuracy: 0.5833 - val_loss: 0.7156
# Epoch 59/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7763 - loss: 0.5083
# Epoch 59: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.7763 - loss: 0.5080 - val_accuracy: 0.5750 - val_loss: 0.7179
# Epoch 60/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7639 - loss: 0.5060
# Epoch 60: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.7641 - loss: 0.5060 - val_accuracy: 0.5833 - val_loss: 0.7179
# Epoch 61/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7739 - loss: 0.4977
# Epoch 61: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step - accuracy: 0.7738 - loss: 0.4977 - val_accuracy: 0.5833 - val_loss: 0.7202
# Epoch 62/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7535 - loss: 0.5093
# Epoch 62: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7544 - loss: 0.5081 - val_accuracy: 0.5750 - val_loss: 0.7312
# Epoch 63/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7573 - loss: 0.4944
# Epoch 63: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7584 - loss: 0.4942 - val_accuracy: 0.5750 - val_loss: 0.7254
# Epoch 64/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7878 - loss: 0.4897
# Epoch 64: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7876 - loss: 0.4896 - val_accuracy: 0.5917 - val_loss: 0.7199
# Epoch 65/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7961 - loss: 0.5002
# Epoch 65: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7964 - loss: 0.4996 - val_accuracy: 0.5833 - val_loss: 0.7304
# Epoch 66/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7912 - loss: 0.4790
# Epoch 66: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7912 - loss: 0.4791 - val_accuracy: 0.5917 - val_loss: 0.7227
# Epoch 67/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7857 - loss: 0.4905
# Epoch 67: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7865 - loss: 0.4898 - val_accuracy: 0.5833 - val_loss: 0.7265
# Epoch 68/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7866 - loss: 0.4801
# Epoch 68: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7870 - loss: 0.4798 - val_accuracy: 0.5917 - val_loss: 0.7294
# Epoch 69/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7698 - loss: 0.4878
# Epoch 69: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7709 - loss: 0.4870 - val_accuracy: 0.5833 - val_loss: 0.7357
# Epoch 70/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7844 - loss: 0.4730
# Epoch 70: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7848 - loss: 0.4725 - val_accuracy: 0.5667 - val_loss: 0.7437
# Epoch 71/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7973 - loss: 0.4674
# Epoch 71: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7980 - loss: 0.4670 - val_accuracy: 0.5750 - val_loss: 0.7403
# Epoch 72/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7931 - loss: 0.4760
# Epoch 72: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7937 - loss: 0.4749 - val_accuracy: 0.5750 - val_loss: 0.7445
# Epoch 73/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8036 - loss: 0.4581
# Epoch 73: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8035 - loss: 0.4581 - val_accuracy: 0.5750 - val_loss: 0.7392
# Epoch 74/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8221 - loss: 0.4465
# Epoch 74: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8214 - loss: 0.4469 - val_accuracy: 0.5667 - val_loss: 0.7450
# Epoch 75/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7986 - loss: 0.4494
# Epoch 75: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7987 - loss: 0.4496 - val_accuracy: 0.5500 - val_loss: 0.7543
# Epoch 76/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8188 - loss: 0.4382
# Epoch 76: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8187 - loss: 0.4385 - val_accuracy: 0.5667 - val_loss: 0.7523
# Epoch 77/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8291 - loss: 0.4310
# Epoch 77: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8287 - loss: 0.4317 - val_accuracy: 0.5583 - val_loss: 0.7525
# Epoch 78/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8005 - loss: 0.4451
# Epoch 78: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8012 - loss: 0.4448 - val_accuracy: 0.5500 - val_loss: 0.7609
# Epoch 79/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8085 - loss: 0.4556
# Epoch 79: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8089 - loss: 0.4552 - val_accuracy: 0.5500 - val_loss: 0.7634
# Epoch 80/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7855 - loss: 0.4433
# Epoch 80: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7872 - loss: 0.4425 - val_accuracy: 0.5583 - val_loss: 0.7616
# Epoch 81/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8173 - loss: 0.4320
# Epoch 81: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8166 - loss: 0.4322 - val_accuracy: 0.5667 - val_loss: 0.7493
# Epoch 82/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8325 - loss: 0.4147
# Epoch 82: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8322 - loss: 0.4154 - val_accuracy: 0.5500 - val_loss: 0.7550
# Epoch 83/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8179 - loss: 0.4419
# Epoch 83: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8187 - loss: 0.4408 - val_accuracy: 0.5667 - val_loss: 0.7630
# Epoch 84/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7970 - loss: 0.4442
# Epoch 84: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7981 - loss: 0.4433 - val_accuracy: 0.5500 - val_loss: 0.7709
# Epoch 85/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8444 - loss: 0.4026
# Epoch 85: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8437 - loss: 0.4035 - val_accuracy: 0.5750 - val_loss: 0.7659
# Epoch 86/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8151 - loss: 0.4270
# Epoch 86: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8158 - loss: 0.4264 - val_accuracy: 0.5583 - val_loss: 0.7717
# Epoch 87/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8202 - loss: 0.4152
# Epoch 87: val_accuracy did not improve from 0.60000
# ...
# Epoch 38: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7243 - loss: 0.5377 - val_accuracy: 0.6000 - val_loss: 0.7267
# Epoch 39/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7143 - loss: 0.5592
# Epoch 39: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7148 - loss: 0.5589 - val_accuracy: 0.5583 - val_loss: 0.7431
# Epoch 40/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7143 - loss: 0.5363
# Epoch 40: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7142 - loss: 0.5370 - val_accuracy: 0.5917 - val_loss: 0.7295
# Epoch 41/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7336 - loss: 0.5352
# Epoch 41: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7333 - loss: 0.5357 - val_accuracy: 0.6000 - val_loss: 0.7270
# Epoch 42/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7341 - loss: 0.5354
# Epoch 42: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7337 - loss: 0.5356 - val_accuracy: 0.5917 - val_loss: 0.7346
# Epoch 43/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7298 - loss: 0.5309
# Epoch 43: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7300 - loss: 0.5309 - val_accuracy: 0.5917 - val_loss: 0.7473
# Epoch 44/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7331 - loss: 0.5379
# Epoch 44: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7329 - loss: 0.5378 - val_accuracy: 0.5917 - val_loss: 0.7373
# Epoch 45/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7402 - loss: 0.5371
# Epoch 45: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7407 - loss: 0.5365 - val_accuracy: 0.5917 - val_loss: 0.7472
# Epoch 46/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7483 - loss: 0.5130
# Epoch 46: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7478 - loss: 0.5138 - val_accuracy: 0.5917 - val_loss: 0.7395
# Epoch 47/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7539 - loss: 0.5298
# Epoch 47: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7535 - loss: 0.5297 - val_accuracy: 0.5750 - val_loss: 0.7432
# Epoch 48/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7352 - loss: 0.5367
# Epoch 48: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7364 - loss: 0.5358 - val_accuracy: 0.5917 - val_loss: 0.7530
# Epoch 49/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7471 - loss: 0.5074
# Epoch 49: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7471 - loss: 0.5076 - val_accuracy: 0.5917 - val_loss: 0.7537
# Epoch 50/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7491 - loss: 0.5283
# Epoch 50: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7498 - loss: 0.5275 - val_accuracy: 0.5833 - val_loss: 0.7602
# Epoch 51/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7807 - loss: 0.4867
# Epoch 51: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7799 - loss: 0.4874 - val_accuracy: 0.5750 - val_loss: 0.7492
# Epoch 52/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7565 - loss: 0.5135
# Epoch 52: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7570 - loss: 0.5131 - val_accuracy: 0.5750 - val_loss: 0.7573
# Epoch 53/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7470 - loss: 0.5152
# Epoch 53: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7479 - loss: 0.5145 - val_accuracy: 0.5833 - val_loss: 0.7572
# Epoch 54/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7616 - loss: 0.5006
# Epoch 54: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7618 - loss: 0.5004 - val_accuracy: 0.5750 - val_loss: 0.7674
# Epoch 55/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7870 - loss: 0.4890
# Epoch 55: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7868 - loss: 0.4889 - val_accuracy: 0.5750 - val_loss: 0.7574
# Epoch 56/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7664 - loss: 0.4955
# Epoch 56: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7669 - loss: 0.4952 - val_accuracy: 0.5667 - val_loss: 0.7744
# Epoch 57/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7824 - loss: 0.5013
# Epoch 57: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7828 - loss: 0.5007 - val_accuracy: 0.5833 - val_loss: 0.7689
# Epoch 58/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8054 - loss: 0.4639
# Epoch 58: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8044 - loss: 0.4648 - val_accuracy: 0.5833 - val_loss: 0.7797
# Epoch 59/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7940 - loss: 0.4772
# Epoch 59: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7935 - loss: 0.4774 - val_accuracy: 0.5750 - val_loss: 0.7827
# Epoch 60/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7889 - loss: 0.4792
# Epoch 60: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7886 - loss: 0.4791 - val_accuracy: 0.5750 - val_loss: 0.7859
# Epoch 61/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7971 - loss: 0.4692
# Epoch 61: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7972 - loss: 0.4692 - val_accuracy: 0.5750 - val_loss: 0.7841
# Epoch 62/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8153 - loss: 0.4489
# Epoch 62: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8145 - loss: 0.4494 - val_accuracy: 0.5583 - val_loss: 0.7929
# Epoch 63/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7788 - loss: 0.4712
# Epoch 63: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7798 - loss: 0.4707 - val_accuracy: 0.5667 - val_loss: 0.8001
# Epoch 64/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7767 - loss: 0.4700
# Epoch 64: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7773 - loss: 0.4695 - val_accuracy: 0.5667 - val_loss: 0.8065
# Epoch 65/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8027 - loss: 0.4416
# Epoch 65: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8023 - loss: 0.4421 - val_accuracy: 0.5667 - val_loss: 0.7985
# Epoch 66/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8010 - loss: 0.4580
# Epoch 66: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8011 - loss: 0.4574 - val_accuracy: 0.5667 - val_loss: 0.8224
# Epoch 67/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7940 - loss: 0.4599
# Epoch 67: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7940 - loss: 0.4597 - val_accuracy: 0.5500 - val_loss: 0.8050
# Epoch 68/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8291 - loss: 0.4298
# Epoch 68: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8280 - loss: 0.4304 - val_accuracy: 0.5500 - val_loss: 0.8078
# Epoch 69/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8114 - loss: 0.4465
# Epoch 69: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8117 - loss: 0.4467 - val_accuracy: 0.5583 - val_loss: 0.8118
# Epoch 70/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8267 - loss: 0.4305
# Epoch 70: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8274 - loss: 0.4302 - val_accuracy: 0.5583 - val_loss: 0.8286
# Epoch 71/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8116 - loss: 0.4315
# Epoch 71: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8115 - loss: 0.4316 - val_accuracy: 0.5750 - val_loss: 0.8213
# Epoch 72/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8443 - loss: 0.4080
# Epoch 72: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8440 - loss: 0.4085 - val_accuracy: 0.5417 - val_loss: 0.8371
# Epoch 73/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8048 - loss: 0.4383
# Epoch 73: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8053 - loss: 0.4377 - val_accuracy: 0.5583 - val_loss: 0.8321
# Epoch 74/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8311 - loss: 0.4068
# Epoch 74: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8304 - loss: 0.4073 - val_accuracy: 0.5500 - val_loss: 0.8340
# Epoch 75/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8528 - loss: 0.4069
# Epoch 75: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8521 - loss: 0.4074 - val_accuracy: 0.5667 - val_loss: 0.8236
# Epoch 76/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8236 - loss: 0.4226
# Epoch 76: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8241 - loss: 0.4225 - val_accuracy: 0.5417 - val_loss: 0.8526
# Epoch 77/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8396 - loss: 0.4074
# Epoch 77: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8394 - loss: 0.4072 - val_accuracy: 0.5500 - val_loss: 0.8415
# Epoch 78/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8322 - loss: 0.4263
# Epoch 78: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8316 - loss: 0.4263 - val_accuracy: 0.5583 - val_loss: 0.8479
# Epoch 79/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8405 - loss: 0.4031
# Epoch 79: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8407 - loss: 0.4031 - val_accuracy: 0.5583 - val_loss: 0.8707
# Epoch 80/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8311 - loss: 0.4033
# Epoch 80: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8315 - loss: 0.4027 - val_accuracy: 0.5667 - val_loss: 0.8500
# Epoch 81/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8458 - loss: 0.3972
# Epoch 81: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8452 - loss: 0.3975 - val_accuracy: 0.5750 - val_loss: 0.8614
# Epoch 82/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8354 - loss: 0.4026
# Epoch 82: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8358 - loss: 0.4022 - val_accuracy: 0.5583 - val_loss: 0.8718
# Epoch 83/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8581 - loss: 0.3899
# Epoch 83: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8578 - loss: 0.3900 - val_accuracy: 0.5500 - val_loss: 0.8695
# Epoch 84/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8713 - loss: 0.3712
# Epoch 84: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8708 - loss: 0.3718 - val_accuracy: 0.5500 - val_loss: 0.8826
# Epoch 85/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8643 - loss: 0.3756
# Epoch 85: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8647 - loss: 0.3749 - val_accuracy: 0.5500 - val_loss: 0.8904
# Epoch 86/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8663 - loss: 0.3504
# Epoch 86: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8659 - loss: 0.3512 - val_accuracy: 0.5583 - val_loss: 0.8931
# Epoch 87/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8490 - loss: 0.3743
# Epoch 87: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8494 - loss: 0.3740 - val_accuracy: 0.5500 - val_loss: 0.8934
# Epoch 88/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8585 - loss: 0.3630
# Epoch 88: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8581 - loss: 0.3630 - val_accuracy: 0.5417 - val_loss: 0.9044
# Epoch 89/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8270 - loss: 0.3889
# Epoch 89: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8281 - loss: 0.3879 - val_accuracy: 0.5500 - val_loss: 0.9271
# Epoch 90/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8602 - loss: 0.3543
# Epoch 90: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8602 - loss: 0.3542 - val_accuracy: 0.5750 - val_loss: 0.9048
# Epoch 91/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8694 - loss: 0.3479
# Epoch 91: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8693 - loss: 0.3482 - val_accuracy: 0.5833 - val_loss: 0.9275
# Epoch 92/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8582 - loss: 0.3436
# Epoch 92: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8580 - loss: 0.3442 - val_accuracy: 0.5500 - val_loss: 0.9170
# Epoch 93/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8909 - loss: 0.3138
# Epoch 93: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8902 - loss: 0.3150 - val_accuracy: 0.5500 - val_loss: 0.9147
# Epoch 94/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8648 - loss: 0.3436
# Epoch 94: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8647 - loss: 0.3437 - val_accuracy: 0.5500 - val_loss: 0.9179
# Epoch 95/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8653 - loss: 0.3498
# Epoch 95: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8654 - loss: 0.3496 - val_accuracy: 0.5500 - val_loss: 0.9332
# Epoch 96/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8871 - loss: 0.3333
# Epoch 96: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8871 - loss: 0.3332 - val_accuracy: 0.5417 - val_loss: 0.9497
# Epoch 97/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8982 - loss: 0.3240
# Epoch 97: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8974 - loss: 0.3245 - val_accuracy: 0.5500 - val_loss: 0.9510
# Epoch 98/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8894 - loss: 0.3250
# Epoch 98: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8892 - loss: 0.3252 - val_accuracy: 0.5583 - val_loss: 0.9400
# Epoch 99/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8511 - loss: 0.3499
# Epoch 99: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.8524 - loss: 0.3485 - val_accuracy: 0.5583 - val_loss: 0.9593
# Epoch 100/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8860 - loss: 0.3066
# Epoch 100: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.8855 - loss: 0.3070 - val_accuracy: 0.5417 - val_loss: 0.9620

# %% [markdown]
# ## Predict

# %%
# Make predictions for each plane
predictions_valid_axial = model_axial.predict(axial_mensicus_val, batch_size=batch_size, verbose=1)
predictions_valid_coronal = model_coronal.predict(coronal_mensicus_val, batch_size=batch_size, verbose=1)
predictions_valid_sagittal = model_sagittal.predict(sagittal_mensicus_val, batch_size=batch_size, verbose=1)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step

# %% [markdown]
# ## Evaluate

# %%
import numpy as np
def calculate_accuracy(ypred, ytest):
    '''calculate accuracy and misclassification'''
    total = 0
    accurate = 0
    accurateindex = []
    wrongindex = []

    for i in range(len(ypred)):
        if np.argmax(ypred[i]) == np.argmax(ytest[i]):
            accurate += 1
            accurateindex.append(i)
        else:
            wrongindex.append(i)
        total += 1

    accuracy = round(accurate / total * 100, 3)
    return total, accurate, total - accurate, accuracy, accurateindex, wrongindex

# %%
from sklearn.metrics import log_loss

score_axial = log_loss(axial_mensicus_label_val, predictions_valid_axial)
score_coronal = log_loss(coronal_mensicus_label_val, predictions_valid_coronal)
score_sagittal = log_loss(sagittal_mensicus_label_val, predictions_valid_sagittal)

print(f"Log Loss: {score_axial}")
print(f"Log Loss: {score_coronal}")
print(f"Log Loss: {score_sagittal}")

# Axial plane accuracy
total_axial, accurate_axial, wrong_axial, accuracy_axial, accurateindex_axial, wrongindex_axial = calculate_accuracy(predictions_valid_axial, axial_mensicus_label_val)
print('Axial - Total test data:', total_axial, '\tAccurately predicted data:', accurate_axial, '\tWrongly predicted data:', wrong_axial)
print('Axial Accuracy:', accuracy_axial, '%')

# Coronal plane accuracy
total_coronal, accurate_coronal, wrong_coronal, accuracy_coronal, accurateindex_coronal, wrongindex_coronal = calculate_accuracy(predictions_valid_coronal, coronal_mensicus_label_val)
print('Coronal - Total test data:', total_coronal, '\tAccurately predicted data:', accurate_coronal, '\tWrongly predicted data:', wrong_coronal)
print('Coronal Accuracy:', accuracy_coronal, '%')

# Sagittal plane accuracy
total_sagittal, accurate_sagittal, wrong_sagittal, accuracy_sagittal, accurateindex_sagittal, wrongindex_sagittal = calculate_accuracy(predictions_valid_sagittal, sagittal_mensicus_label_val)
print('Sagittal - Total test data:', total_sagittal, '\tAccurately predicted data:', accurate_sagittal, '\tWrongly predicted data:', wrong_sagittal)
print('Sagittal Accuracy:', accuracy_sagittal, '%')
# Out:
# Log Loss: 0.9969245025414443
# Log Loss: 0.7978706887417137
# Log Loss: 0.9632339684343837
# Axial - Total test data: 120 	Accurately predicted data: 58 	Wrongly predicted data: 62
# Axial Accuracy: 48.333 %
# Coronal - Total test data: 120 	Accurately predicted data: 67 	Wrongly predicted data: 53
# Coronal Accuracy: 55.833 %
# Sagittal - Total test data: 120 	Accurately predicted data: 65 	Wrongly predicted data: 55
# Sagittal Accuracy: 54.167 %

# %%
# Evaluating Accuracy and Loss for the three planes: axial, coronal, and sagittal
# %matplotlib inline
import matplotlib.pyplot as plt

# Axial metrics
acc_axial = history_axial.history['accuracy']
val_acc_axial = history_axial.history['val_accuracy']
loss_axial = history_axial.history['loss']
val_loss_axial = history_axial.history['val_loss']

# Coronal metrics
acc_coronal = history_coronal.history['accuracy']
val_acc_coronal = history_coronal.history['val_accuracy']
loss_coronal = history_coronal.history['loss']
val_loss_coronal = history_coronal.history['val_loss']

# Sagittal metrics
acc_sagittal = history_sagittal.history['accuracy']
val_acc_sagittal = history_sagittal.history['val_accuracy']
loss_sagittal = history_sagittal.history['loss']
val_loss_sagittal = history_sagittal.history['val_loss']
epochs = range(1, len(acc_axial) + 1)
# Plot training and validation accuracy for each plane
plt.figure(figsize=(12, 6))
plt.plot(epochs, acc_axial, 'b', label='Training Accuracy - Axial')
plt.plot(epochs, val_acc_axial, 'b--', label='Validation Accuracy - Axial')
plt.plot(epochs, acc_coronal, 'g', label='Training Accuracy - Coronal')
plt.plot(epochs, val_acc_coronal, 'g--', label='Validation Accuracy - Coronal')
plt.plot(epochs, acc_sagittal, 'r', label='Training Accuracy - Sagittal')
plt.plot(epochs, val_acc_sagittal, 'r--', label='Validation Accuracy - Sagittal')

plt.title(f'Training and Validation Accuracy (Epochs={nb_epoch}, Dropout={dropout}, Learning Rate={lr}, Batch Size={batch_size})')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.savefig(f'Train_val_acc_all_planes_Ep={nb_epoch}_Do={dropout}_Lr={lr}_Bs={batch_size}.png')

plt.figure()

# Plot training and validation loss for each plane
plt.figure(figsize=(12, 6))
plt.plot(epochs, loss_axial, 'b', label='Training Loss - Axial')
plt.plot(epochs, val_loss_axial, 'b--', label='Validation Loss - Axial')
plt.plot(epochs, loss_coronal, 'g', label='Training Loss - Coronal')
plt.plot(epochs, val_loss_coronal, 'g--', label='Validation Loss - Coronal')
plt.plot(epochs, loss_sagittal, 'r', label='Training Loss - Sagittal')
plt.plot(epochs, val_loss_sagittal, 'r--', label='Validation Loss - Sagittal')

plt.title(f'Training and Validation Loss (Epochs={nb_epoch}, Dropout={dropout}, Learning Rate={lr}, Batch Size={batch_size})')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig(f'Train_val_loss_all_planes_Ep={nb_epoch}_Do={dropout}_Lr={lr}_Bs={batch_size}.png')

plt.show()

# %% [markdown]
# save the models in a keras file

# %%
model_axial.save("model_axial_BN.keras")
model_coronal.save("model_coronal_BN.keras")
model_sagittal.save("model_sagittal_BN.keras")

# %%
from google.colab import files
files.download('model_coronal_BN.keras')
files.download("model_sagittal_BN.keras")
files.download("model_axial_BN.keras")

# %%
files.download("Train_val_acc_all_planes_Ep=100_Do=0.4_Lr=0.0005_Bs=32.png")
files.download("Train_val_loss_all_planes_Ep=100_Do=0.4_Lr=0.0005_Bs=32.png")
