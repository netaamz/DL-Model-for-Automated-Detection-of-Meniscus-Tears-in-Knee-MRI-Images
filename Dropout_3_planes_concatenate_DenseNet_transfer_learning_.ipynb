# %% [markdown]
# <a href="https://colab.research.google.com/github/netaamz/DL-Model-for-Automated-Detection-of-Meniscus-Tears-in-Knee-MRI-Images/blob/main/Dropout_3_planes_concatenate_DenseNet_transfer_learning_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone: Development of an algorithm for automatic detection of meniscus tears in radiographic images of the knee.

# %%
import warnings
warnings.filterwarnings("ignore")

#!pip install pyyaml

# %%
# !pip install tensorflow
# !pip install keras
# !pip install h5py
# !pip install sklearn
# !pip install opencv-python
# !pip install seaborn
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.11.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.26.4)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)

# %%
# Import libraries here
import os
import tempfile
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from glob import glob
from IPython.display import Image, display
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix, accuracy_score

import random as random
import imageio
import imgaug as ia
import tensorflow as tf
from tensorflow import keras
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Data import

# %% [markdown]
# **import data and get labels**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# The dataset contains *s* x 256 x 256 images. Since middle images are the most useful, only 3 middle slides in the series are retained.

# %% [markdown]
# ## **data generation for meniscus**

# %%
def data_gen(dataset_type, plane, diagnosis):
    '''this function gets the data from the extracted datset'''
    # for eg, (train, sagittal, mensicus)
    if dataset_type == 'train':
        go = '/content/drive/My Drive/miniscus data set/MRNet-v1.0/train_transformf' # if we want without filter then:  /content/drive/My Drive/miniscus data set/MRNet-v1.0/train_transform
    else:
        go = '/content/drive/My Drive/miniscus data set/MRNet-v1.0/valid_transformf' # if we want without filter then: /content/drive/My Drive/miniscus data set/MRNet-v1.0/valid_transform

    plane_dir = f'{go}/{plane}.npy'

    data = np.load(plane_dir)
    label_path = f'/content/drive/My Drive/miniscus data set/MRNet-v1.0/{dataset_type}-{diagnosis}.csv'
#     label_path = f'data/{dataset_type}-{diagnosis}.csv'
    label_df = pd.read_csv(label_path, names=['nr', diagnosis])
    label_data = list(label_df[diagnosis])

    return(data, label_data)

# %%
# generate training input
coronal_mensicus, coronal_mensicus_label = data_gen('train', 'coronal/extracted_images', 'meniscus')
axial_mensicus, axial_mensicus_label = data_gen('train', 'axial/extracted_images', 'meniscus')
sagittal_mensicus, sagittal_mensicus_label = data_gen('train', 'sagittal/extracted_images', 'meniscus')
print(sagittal_mensicus.shape)
# generate validation
coronal_mensicus_val, coronal_mensicus_label_val  = data_gen('valid', 'coronal/extracted_images', 'meniscus')
axial_mensicus_val, axial_mensicus_label_val  = data_gen('valid', 'axial/extracted_images', 'meniscus')
sagittal_mensicus_val, sagittal_mensicus_label_val  = data_gen('valid', 'sagittal/extracted_images', 'meniscus')
# Out:
# (1130, 256, 256, 3)

# %%
from keras.utils import to_categorical  # Import to_categorical
base_path = "/content/drive/My Drive/miniscus data set/MRNet-v1.0/"

num_classes =2

sagittal_mensicus_label = to_categorical(sagittal_mensicus_label, num_classes)
sagittal_mensicus_label_val = to_categorical(sagittal_mensicus_label_val, num_classes)

coronal_mensicus_label = to_categorical(coronal_mensicus_label, num_classes)
coronal_mensicus_label_val = to_categorical(coronal_mensicus_label_val, num_classes)

axial_mensicus_label = to_categorical(axial_mensicus_label, num_classes)
axial_mensicus_label_val = to_categorical(axial_mensicus_label_val, num_classes)

# %%
from sklearn.metrics import log_loss
import numpy as np
import os
import keras
import random
import cv2
import math
import seaborn as sns

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Transfer Learning

# %% [markdown]
# ##  Hyperparameters

# %%
    img_rows, img_cols = 256, 256  # Adjust based on your actual image dimensions
    channel = 3
    num_classes = 2  # Binary classification
    batch_size = 32
    nb_epoch= 100
    dropout1 = 0.2
    dropout2 = 0.4
    dropout3 = 0.5
    lr = 5e-4  # Learning rat

# %% [markdown]
# ## Model Creation and training

# %%
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, BatchNormalization, Dropout, Concatenate, MaxPooling1D, Reshape, Flatten
from tensorflow.keras.optimizers import SGD, schedules
from tensorflow.keras.callbacks import ModelCheckpoint
def create_model2(input_shape, num_classes, dropout):
    # Base DenseNet model for each plane (axial, coronal, sagittal)
    base_model = DenseNet121(weights='imagenet', include_top=False, pooling=None, input_shape=input_shape)

    # Define input for each plane
    input_axial = Input(shape=input_shape, name='input_axial')
    input_coronal = Input(shape=input_shape, name='input_coronal')
    input_sagittal = Input(shape=input_shape, name='input_sagittal')

    # Process each plane using the same base DenseNet model
    axial_output = base_model(input_axial)
    coronal_output = base_model(input_coronal)
    sagittal_output = base_model(input_sagittal)

    # Global Average Pooling for each plane
    axial_output = GlobalAveragePooling2D()(axial_output)
    coronal_output = GlobalAveragePooling2D()(coronal_output)
    sagittal_output = GlobalAveragePooling2D()(sagittal_output)

    # Concatenate the outputs from all planes
    concatenated = Concatenate()([ axial_output, coronal_output, sagittal_output])

    # Dense and Dropout layers after concatenation
    x = BatchNormalization()(concatenated)
    x = Dropout(dropout)(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(dropout)(x)
    x = Dense(512, activation='relu')(x)
    output = Dense(num_classes, activation='softmax')(x)

    # Create the final model
    model = Model(inputs=[input_axial, input_coronal, input_sagittal], outputs=output)

    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = False

    return model

# %%
if __name__ == '__main__':
    input_shape = (img_rows, img_cols, channel)  # Update this with actual dimensions

    # Create the model with three inputs (for axial, coronal, and sagittal planes)
    model1 = create_model2(input_shape, num_classes, dropout1)
    model2 = create_model2(input_shape, num_classes, dropout2)
    model3 = create_model2(input_shape, num_classes, dropout3)
    # Compile the model
    model1.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    model2.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    model3.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Set up the checkpoint
    filepath = "bestmodel.keras"
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]

    # Training run 1
    history1 = model1.fit([axial_mensicus, coronal_mensicus, sagittal_mensicus],
                         axial_mensicus_label,
                         batch_size=batch_size,
                         epochs=nb_epoch,
                         shuffle=True,
                         verbose=1,
                         validation_data=([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], axial_mensicus_label_val),
                         callbacks=callbacks_list)

    # Training run 2
    history2 = model2.fit([axial_mensicus, coronal_mensicus, sagittal_mensicus],
                         axial_mensicus_label,
                         batch_size=batch_size,
                         epochs=nb_epoch,
                         shuffle=True,
                         verbose=1,
                         validation_data=([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], axial_mensicus_label_val),
                         callbacks=callbacks_list)

    # Training run 3
    history3 = model3.fit([axial_mensicus, coronal_mensicus, sagittal_mensicus],
                         axial_mensicus_label,
                         batch_size=batch_size,
                         epochs=nb_epoch,
                         shuffle=True,
                         verbose=1,
                         validation_data=([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], axial_mensicus_label_val),
                         callbacks=callbacks_list)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.5744 - loss: 0.7031
# Epoch 1: val_accuracy improved from -inf to 0.56667, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - accuracy: 0.5752 - loss: 0.7029 - val_accuracy: 0.5667 - val_loss: 0.8336
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.6403 - loss: 0.6763
# Epoch 2: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - accuracy: 0.6404 - loss: 0.6762 - val_accuracy: 0.5667 - val_loss: 0.7352
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.6381 - loss: 0.6633
# Epoch 3: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 297ms/step - accuracy: 0.6384 - loss: 0.6632 - val_accuracy: 0.5667 - val_loss: 0.7498
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.6818 - loss: 0.6286
# Epoch 4: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - accuracy: 0.6812 - loss: 0.6291 - val_accuracy: 0.5667 - val_loss: 0.7401
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6633 - loss: 0.6440
# Epoch 5: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.6632 - loss: 0.6441 - val_accuracy: 0.5667 - val_loss: 0.7571
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.6933 - loss: 0.6230
# Epoch 6: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step - accuracy: 0.6929 - loss: 0.6231 - val_accuracy: 0.5667 - val_loss: 0.7543
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.6991 - loss: 0.6196
# Epoch 7: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 277ms/step - accuracy: 0.6988 - loss: 0.6196 - val_accuracy: 0.5667 - val_loss: 0.7708
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.6735 - loss: 0.6128
# Epoch 8: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 278ms/step - accuracy: 0.6735 - loss: 0.6131 - val_accuracy: 0.5667 - val_loss: 0.7866
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.6791 - loss: 0.6131
# Epoch 9: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.6791 - loss: 0.6132 - val_accuracy: 0.5667 - val_loss: 0.7840
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6718 - loss: 0.6155
# Epoch 10: val_accuracy did not improve from 0.56667
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.6723 - loss: 0.6153 - val_accuracy: 0.5667 - val_loss: 0.8071
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.6861 - loss: 0.5968
# Epoch 11: val_accuracy improved from 0.56667 to 0.58333, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.6862 - loss: 0.5968 - val_accuracy: 0.5833 - val_loss: 0.8018
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.6901 - loss: 0.5748
# Epoch 12: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 284ms/step - accuracy: 0.6902 - loss: 0.5752 - val_accuracy: 0.5750 - val_loss: 0.8205
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6888 - loss: 0.5939
# Epoch 13: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.6895 - loss: 0.5935 - val_accuracy: 0.5750 - val_loss: 0.8456
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7087 - loss: 0.5737
# Epoch 14: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7084 - loss: 0.5738 - val_accuracy: 0.5833 - val_loss: 0.8277
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7469 - loss: 0.5568
# Epoch 15: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7465 - loss: 0.5569 - val_accuracy: 0.5833 - val_loss: 0.8446
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7265 - loss: 0.5480
# Epoch 16: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7264 - loss: 0.5481 - val_accuracy: 0.5833 - val_loss: 0.8567
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7315 - loss: 0.5451
# Epoch 17: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7311 - loss: 0.5456 - val_accuracy: 0.5833 - val_loss: 0.8435
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7368 - loss: 0.5470
# Epoch 18: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7374 - loss: 0.5468 - val_accuracy: 0.5833 - val_loss: 0.8773
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.7457 - loss: 0.5299
# Epoch 19: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7453 - loss: 0.5301 - val_accuracy: 0.5833 - val_loss: 0.8552
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7940 - loss: 0.4993
# Epoch 20: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7931 - loss: 0.5000 - val_accuracy: 0.5833 - val_loss: 0.8730
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7678 - loss: 0.5155
# Epoch 21: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7675 - loss: 0.5157 - val_accuracy: 0.5833 - val_loss: 0.8896
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7644 - loss: 0.5107
# Epoch 22: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7646 - loss: 0.5108 - val_accuracy: 0.5750 - val_loss: 0.8984
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7642 - loss: 0.4874
# Epoch 23: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7639 - loss: 0.4878 - val_accuracy: 0.5833 - val_loss: 0.8690
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7837 - loss: 0.4953
# Epoch 24: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7838 - loss: 0.4953 - val_accuracy: 0.5833 - val_loss: 0.8819
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7620 - loss: 0.4958
# Epoch 25: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7625 - loss: 0.4955 - val_accuracy: 0.5833 - val_loss: 0.8827
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8012 - loss: 0.4784
# Epoch 26: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8008 - loss: 0.4786 - val_accuracy: 0.5750 - val_loss: 0.8846
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8240 - loss: 0.4524
# Epoch 27: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8235 - loss: 0.4527 - val_accuracy: 0.5750 - val_loss: 0.8854
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8145 - loss: 0.4605
# Epoch 28: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8142 - loss: 0.4605 - val_accuracy: 0.5833 - val_loss: 0.9016
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8145 - loss: 0.4422
# Epoch 29: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8143 - loss: 0.4425 - val_accuracy: 0.5750 - val_loss: 0.9038
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8052 - loss: 0.4385
# Epoch 30: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8053 - loss: 0.4385 - val_accuracy: 0.5750 - val_loss: 0.9090
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8290 - loss: 0.4297
# Epoch 31: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8289 - loss: 0.4297 - val_accuracy: 0.5750 - val_loss: 0.9089
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8230 - loss: 0.4265
# Epoch 32: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8232 - loss: 0.4265 - val_accuracy: 0.5750 - val_loss: 0.9219
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8558 - loss: 0.3997
# Epoch 33: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8552 - loss: 0.4001 - val_accuracy: 0.5750 - val_loss: 0.9220
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8346 - loss: 0.4192
# Epoch 34: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8348 - loss: 0.4190 - val_accuracy: 0.5667 - val_loss: 0.9457
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8388 - loss: 0.4108
# Epoch 35: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8389 - loss: 0.4106 - val_accuracy: 0.5667 - val_loss: 0.9362
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8466 - loss: 0.3940
# Epoch 36: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8469 - loss: 0.3938 - val_accuracy: 0.5750 - val_loss: 0.9581
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8517 - loss: 0.3919
# Epoch 37: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8517 - loss: 0.3917 - val_accuracy: 0.5750 - val_loss: 0.9735
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8758 - loss: 0.3622
# Epoch 38: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8757 - loss: 0.3626 - val_accuracy: 0.5417 - val_loss: 0.9353
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8638 - loss: 0.3697
# Epoch 39: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8637 - loss: 0.3699 - val_accuracy: 0.5500 - val_loss: 0.9604
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8792 - loss: 0.3447
# Epoch 40: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8791 - loss: 0.3450 - val_accuracy: 0.5333 - val_loss: 0.9482
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8962 - loss: 0.3353
# Epoch 41: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8960 - loss: 0.3357 - val_accuracy: 0.5417 - val_loss: 0.9839
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8837 - loss: 0.3495
# Epoch 42: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8835 - loss: 0.3494 - val_accuracy: 0.5500 - val_loss: 1.0173
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9050 - loss: 0.3175
# Epoch 43: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9048 - loss: 0.3177 - val_accuracy: 0.5583 - val_loss: 0.9879
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8990 - loss: 0.3151
# Epoch 44: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8991 - loss: 0.3151 - val_accuracy: 0.5333 - val_loss: 0.9834
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9083 - loss: 0.3126
# Epoch 45: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9082 - loss: 0.3124 - val_accuracy: 0.5500 - val_loss: 1.0017
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9198 - loss: 0.2940
# Epoch 46: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9198 - loss: 0.2941 - val_accuracy: 0.5500 - val_loss: 1.0113
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9031 - loss: 0.2959
# Epoch 47: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9031 - loss: 0.2959 - val_accuracy: 0.5500 - val_loss: 1.0283
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9299 - loss: 0.2881
# Epoch 48: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9296 - loss: 0.2879 - val_accuracy: 0.5417 - val_loss: 1.0231
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9225 - loss: 0.2725
# Epoch 49: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9225 - loss: 0.2726 - val_accuracy: 0.5417 - val_loss: 1.0133
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9411 - loss: 0.2566
# Epoch 50: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9411 - loss: 0.2566 - val_accuracy: 0.5500 - val_loss: 1.0417
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9248 - loss: 0.2642
# Epoch 51: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9249 - loss: 0.2641 - val_accuracy: 0.5333 - val_loss: 1.0463
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9493 - loss: 0.2421
# Epoch 52: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9491 - loss: 0.2420 - val_accuracy: 0.5500 - val_loss: 1.0670
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9223 - loss: 0.2551
# Epoch 53: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9223 - loss: 0.2552 - val_accuracy: 0.5500 - val_loss: 1.0659
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9170 - loss: 0.2574
# Epoch 54: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9170 - loss: 0.2575 - val_accuracy: 0.5417 - val_loss: 1.0830
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9458 - loss: 0.2242
# Epoch 55: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9455 - loss: 0.2245 - val_accuracy: 0.5333 - val_loss: 1.1085
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9213 - loss: 0.2299
# Epoch 56: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9213 - loss: 0.2301 - val_accuracy: 0.5500 - val_loss: 1.0716
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9350 - loss: 0.2300
# Epoch 57: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9349 - loss: 0.2301 - val_accuracy: 0.5417 - val_loss: 1.1085
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9200 - loss: 0.2360
# Epoch 58: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9205 - loss: 0.2356 - val_accuracy: 0.5500 - val_loss: 1.1042
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9314 - loss: 0.2207
# Epoch 59: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9314 - loss: 0.2207 - val_accuracy: 0.5500 - val_loss: 1.0977
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9393 - loss: 0.2086
# Epoch 60: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9393 - loss: 0.2087 - val_accuracy: 0.5417 - val_loss: 1.1229
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9289 - loss: 0.2273
# Epoch 61: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9289 - loss: 0.2270 - val_accuracy: 0.5583 - val_loss: 1.1690
# Epoch 62/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9393 - loss: 0.2103
# Epoch 62: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9394 - loss: 0.2102 - val_accuracy: 0.5417 - val_loss: 1.1200
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9562 - loss: 0.1916
# Epoch 63: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9562 - loss: 0.1915 - val_accuracy: 0.5417 - val_loss: 1.1339
# Epoch 64/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9468 - loss: 0.2038
# Epoch 64: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9466 - loss: 0.2037 - val_accuracy: 0.5500 - val_loss: 1.1686
# Epoch 65/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9387 - loss: 0.1955
# Epoch 65: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9387 - loss: 0.1955 - val_accuracy: 0.5417 - val_loss: 1.1618
# Epoch 66/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9600 - loss: 0.1796
# Epoch 66: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9597 - loss: 0.1796 - val_accuracy: 0.5500 - val_loss: 1.1971
# Epoch 67/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9551 - loss: 0.1766
# Epoch 67: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9550 - loss: 0.1768 - val_accuracy: 0.5250 - val_loss: 1.1840
# Epoch 68/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9598 - loss: 0.1652
# Epoch 68: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9595 - loss: 0.1655 - val_accuracy: 0.5500 - val_loss: 1.1950
# Epoch 69/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9382 - loss: 0.1821
# Epoch 69: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9384 - loss: 0.1820 - val_accuracy: 0.5333 - val_loss: 1.1969
# Epoch 70/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9743 - loss: 0.1543
# Epoch 70: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9742 - loss: 0.1543 - val_accuracy: 0.5333 - val_loss: 1.2112
# Epoch 71/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9660 - loss: 0.1565
# Epoch 71: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9656 - loss: 0.1568 - val_accuracy: 0.5583 - val_loss: 1.2510
# Epoch 72/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9630 - loss: 0.1476
# Epoch 72: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9629 - loss: 0.1477 - val_accuracy: 0.5417 - val_loss: 1.2464
# Epoch 73/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9541 - loss: 0.1697
# Epoch 73: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9543 - loss: 0.1694 - val_accuracy: 0.5333 - val_loss: 1.2577
# Epoch 74/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9689 - loss: 0.1496
# Epoch 74: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.9688 - loss: 0.1496 - val_accuracy: 0.5333 - val_loss: 1.2868
# Epoch 75/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9645 - loss: 0.1387
# Epoch 75: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9644 - loss: 0.1388 - val_accuracy: 0.5250 - val_loss: 1.2652
# Epoch 76/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9658 - loss: 0.1337
# Epoch 76: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.9657 - loss: 0.1338 - val_accuracy: 0.5167 - val_loss: 1.2647
# Epoch 77/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9759 - loss: 0.1302
# Epoch 77: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9757 - loss: 0.1303 - val_accuracy: 0.5083 - val_loss: 1.3139
# Epoch 78/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9650 - loss: 0.1486
# Epoch 78: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9649 - loss: 0.1485 - val_accuracy: 0.5000 - val_loss: 1.3105
# Epoch 79/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9692 - loss: 0.1227
# Epoch 79: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9692 - loss: 0.1228 - val_accuracy: 0.5000 - val_loss: 1.2963
# Epoch 80/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9678 - loss: 0.1241
# Epoch 80: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9679 - loss: 0.1241 - val_accuracy: 0.5333 - val_loss: 1.2910
# Epoch 81/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9721 - loss: 0.1228
# Epoch 81: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9722 - loss: 0.1228 - val_accuracy: 0.5167 - val_loss: 1.2981
# Epoch 82/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9512 - loss: 0.1380
# Epoch 82: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9515 - loss: 0.1378 - val_accuracy: 0.5083 - val_loss: 1.3076
# Epoch 83/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9666 - loss: 0.1201
# Epoch 83: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9665 - loss: 0.1204 - val_accuracy: 0.4917 - val_loss: 1.3164
# Epoch 84/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9700 - loss: 0.1298
# Epoch 84: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.9700 - loss: 0.1298 - val_accuracy: 0.5500 - val_loss: 1.4184
# Epoch 85/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9756 - loss: 0.1165
# Epoch 85: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9756 - loss: 0.1166 - val_accuracy: 0.5333 - val_loss: 1.4125
# Epoch 86/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9784 - loss: 0.0991
# Epoch 86: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9784 - loss: 0.0993 - val_accuracy: 0.4917 - val_loss: 1.3681
# Epoch 87/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9794 - loss: 0.1006
# Epoch 87: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9792 - loss: 0.1009 - val_accuracy: 0.5083 - val_loss: 1.3719
# Epoch 88/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9646 - loss: 0.1192
# Epoch 88: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9646 - loss: 0.1193 - val_accuracy: 0.5167 - val_loss: 1.4142
# Epoch 89/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9711 - loss: 0.1057
# Epoch 89: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9712 - loss: 0.1059 - val_accuracy: 0.5333 - val_loss: 1.3963
# Epoch 90/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9775 - loss: 0.0976
# Epoch 90: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9774 - loss: 0.0977 - val_accuracy: 0.5250 - val_loss: 1.4497
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9862 - loss: 0.0897
# Epoch 91: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9861 - loss: 0.0899 - val_accuracy: 0.5333 - val_loss: 1.5025
# Epoch 92/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.9844 - loss: 0.0845
# Epoch 92: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.9844 - loss: 0.0847 - val_accuracy: 0.5333 - val_loss: 1.4587
# Epoch 93/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9687 - loss: 0.1096
# Epoch 93: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9687 - loss: 0.1095 - val_accuracy: 0.5333 - val_loss: 1.4800
# Epoch 94/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9794 - loss: 0.0985
# Epoch 94: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9792 - loss: 0.0987 - val_accuracy: 0.5333 - val_loss: 1.4558
# Epoch 95/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9856 - loss: 0.0823
# Epoch 95: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9854 - loss: 0.0826 - val_accuracy: 0.5000 - val_loss: 1.4313
# Epoch 96/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9859 - loss: 0.0917
# Epoch 96: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9857 - loss: 0.0917 - val_accuracy: 0.5167 - val_loss: 1.4620
# Epoch 97/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9772 - loss: 0.0963
# Epoch 97: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9771 - loss: 0.0963 - val_accuracy: 0.5333 - val_loss: 1.5130
# Epoch 98/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9803 - loss: 0.0857
# Epoch 98: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.9803 - loss: 0.0858 - val_accuracy: 0.5250 - val_loss: 1.5084
# Epoch 99/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9820 - loss: 0.0762
# Epoch 99: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9819 - loss: 0.0765 - val_accuracy: 0.5417 - val_loss: 1.5229
# Epoch 100/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.9847 - loss: 0.0768
# Epoch 100: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9848 - loss: 0.0768 - val_accuracy: 0.5250 - val_loss: 1.5850
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.5684 - loss: 0.7624
# Epoch 1: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.5692 - loss: 0.7622 - val_accuracy: 0.5583 - val_loss: 0.7812
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.5963 - loss: 0.7361
# Epoch 2: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 293ms/step - accuracy: 0.5964 - loss: 0.7360 - val_accuracy: 0.5667 - val_loss: 0.7421
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.6353 - loss: 0.7105
# Epoch 3: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 298ms/step - accuracy: 0.6357 - loss: 0.7100 - val_accuracy: 0.5583 - val_loss: 0.7206
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.6430 - loss: 0.6896
# Epoch 4: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 288ms/step - accuracy: 0.6426 - loss: 0.6899 - val_accuracy: 0.5667 - val_loss: 0.7123
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6040 - loss: 0.6863
# Epoch 5: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.6041 - loss: 0.6864 - val_accuracy: 0.5667 - val_loss: 0.7229
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.6419 - loss: 0.6868
# Epoch 6: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 277ms/step - accuracy: 0.6417 - loss: 0.6868 - val_accuracy: 0.5667 - val_loss: 0.7173
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.6500 - loss: 0.6789
# Epoch 7: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 276ms/step - accuracy: 0.6499 - loss: 0.6788 - val_accuracy: 0.5667 - val_loss: 0.7216
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.6621 - loss: 0.6733
# Epoch 8: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 279ms/step - accuracy: 0.6622 - loss: 0.6729 - val_accuracy: 0.5667 - val_loss: 0.7279
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6473 - loss: 0.6638
# Epoch 9: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.6475 - loss: 0.6637 - val_accuracy: 0.5667 - val_loss: 0.7379
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6617 - loss: 0.6546
# Epoch 10: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.6615 - loss: 0.6546 - val_accuracy: 0.5750 - val_loss: 0.7432
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.6785 - loss: 0.6284
# Epoch 11: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - accuracy: 0.6776 - loss: 0.6291 - val_accuracy: 0.5833 - val_loss: 0.7340
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6701 - loss: 0.6369
# Epoch 12: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.6699 - loss: 0.6369 - val_accuracy: 0.5667 - val_loss: 0.7590
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6698 - loss: 0.6198
# Epoch 13: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.6694 - loss: 0.6204 - val_accuracy: 0.5750 - val_loss: 0.7548
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6686 - loss: 0.6209
# Epoch 14: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.6686 - loss: 0.6211 - val_accuracy: 0.5750 - val_loss: 0.7616
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6537 - loss: 0.6342
# Epoch 15: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.6542 - loss: 0.6342 - val_accuracy: 0.5667 - val_loss: 0.7668
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6482 - loss: 0.6486
# Epoch 16: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.6487 - loss: 0.6484 - val_accuracy: 0.5750 - val_loss: 0.7872
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6864 - loss: 0.6167
# Epoch 17: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.6862 - loss: 0.6168 - val_accuracy: 0.5750 - val_loss: 0.7793
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7027 - loss: 0.5885
# Epoch 18: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7024 - loss: 0.5889 - val_accuracy: 0.5667 - val_loss: 0.7719
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7015 - loss: 0.6016
# Epoch 19: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7013 - loss: 0.6018 - val_accuracy: 0.5750 - val_loss: 0.7930
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.6623 - loss: 0.6208
# Epoch 20: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.6626 - loss: 0.6204 - val_accuracy: 0.5750 - val_loss: 0.8063
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7266 - loss: 0.5519
# Epoch 21: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7260 - loss: 0.5525 - val_accuracy: 0.5583 - val_loss: 0.7725
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7113 - loss: 0.6028
# Epoch 22: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7109 - loss: 0.6026 - val_accuracy: 0.5667 - val_loss: 0.8118
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7114 - loss: 0.5881
# Epoch 23: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7112 - loss: 0.5881 - val_accuracy: 0.5583 - val_loss: 0.7734
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7131 - loss: 0.5832
# Epoch 24: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.7130 - loss: 0.5835 - val_accuracy: 0.5667 - val_loss: 0.7843
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7369 - loss: 0.5685
# Epoch 25: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7363 - loss: 0.5689 - val_accuracy: 0.5667 - val_loss: 0.7860
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6913 - loss: 0.6023
# Epoch 26: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.6921 - loss: 0.6017 - val_accuracy: 0.5667 - val_loss: 0.7796
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6879 - loss: 0.5900
# Epoch 27: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.6883 - loss: 0.5896 - val_accuracy: 0.5667 - val_loss: 0.7938
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7518 - loss: 0.5323
# Epoch 28: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7512 - loss: 0.5330 - val_accuracy: 0.5667 - val_loss: 0.7706
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7054 - loss: 0.5759
# Epoch 29: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7053 - loss: 0.5758 - val_accuracy: 0.5667 - val_loss: 0.7836
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7227 - loss: 0.5589
# Epoch 30: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7227 - loss: 0.5591 - val_accuracy: 0.5583 - val_loss: 0.7780
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7382 - loss: 0.5404
# Epoch 31: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7379 - loss: 0.5405 - val_accuracy: 0.5583 - val_loss: 0.7857
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7155 - loss: 0.5622
# Epoch 32: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7153 - loss: 0.5624 - val_accuracy: 0.5583 - val_loss: 0.7854
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7292 - loss: 0.5421
# Epoch 33: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7292 - loss: 0.5420 - val_accuracy: 0.5667 - val_loss: 0.7924
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7285 - loss: 0.5498
# Epoch 34: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7286 - loss: 0.5498 - val_accuracy: 0.5667 - val_loss: 0.7941
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7611 - loss: 0.5177
# Epoch 35: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7605 - loss: 0.5181 - val_accuracy: 0.5750 - val_loss: 0.8006
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7440 - loss: 0.5315
# Epoch 36: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7433 - loss: 0.5325 - val_accuracy: 0.5750 - val_loss: 0.7940
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7494 - loss: 0.5262
# Epoch 37: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7492 - loss: 0.5265 - val_accuracy: 0.5667 - val_loss: 0.7890
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7486 - loss: 0.5107
# Epoch 38: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7484 - loss: 0.5110 - val_accuracy: 0.5750 - val_loss: 0.7868
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7650 - loss: 0.5218
# Epoch 39: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7648 - loss: 0.5219 - val_accuracy: 0.5750 - val_loss: 0.8160
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7424 - loss: 0.5426
# Epoch 40: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7426 - loss: 0.5420 - val_accuracy: 0.5667 - val_loss: 0.8021
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7829 - loss: 0.4880
# Epoch 41: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7826 - loss: 0.4884 - val_accuracy: 0.5833 - val_loss: 0.8006
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7869 - loss: 0.4943
# Epoch 42: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7865 - loss: 0.4945 - val_accuracy: 0.5833 - val_loss: 0.7815
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7959 - loss: 0.4758
# Epoch 43: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7948 - loss: 0.4768 - val_accuracy: 0.5833 - val_loss: 0.7900
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7759 - loss: 0.4841
# Epoch 44: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7759 - loss: 0.4844 - val_accuracy: 0.5833 - val_loss: 0.7998
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7750 - loss: 0.4973
# Epoch 45: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7747 - loss: 0.4973 - val_accuracy: 0.5833 - val_loss: 0.7983
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7544 - loss: 0.5196
# Epoch 46: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7549 - loss: 0.5191 - val_accuracy: 0.5833 - val_loss: 0.8047
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7626 - loss: 0.4936
# Epoch 47: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7626 - loss: 0.4936 - val_accuracy: 0.5750 - val_loss: 0.7700
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7518 - loss: 0.5013
# Epoch 48: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7520 - loss: 0.5013 - val_accuracy: 0.5833 - val_loss: 0.8178
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7870 - loss: 0.4933
# Epoch 49: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7872 - loss: 0.4929 - val_accuracy: 0.5833 - val_loss: 0.8383
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7784 - loss: 0.4858
# Epoch 50: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7788 - loss: 0.4854 - val_accuracy: 0.5750 - val_loss: 0.8330
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8007 - loss: 0.4656
# Epoch 51: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8001 - loss: 0.4661 - val_accuracy: 0.5750 - val_loss: 0.8540
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7825 - loss: 0.4874
# Epoch 52: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7826 - loss: 0.4872 - val_accuracy: 0.5750 - val_loss: 0.8662
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7894 - loss: 0.4618
# Epoch 53: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7891 - loss: 0.4623 - val_accuracy: 0.5750 - val_loss: 0.8656
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7969 - loss: 0.4527
# Epoch 54: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7967 - loss: 0.4530 - val_accuracy: 0.5750 - val_loss: 0.8690
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8058 - loss: 0.4362
# Epoch 55: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8055 - loss: 0.4366 - val_accuracy: 0.5750 - val_loss: 0.8555
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8177 - loss: 0.4438
# Epoch 56: val_accuracy improved from 0.58333 to 0.59167, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 311ms/step - accuracy: 0.8172 - loss: 0.4441 - val_accuracy: 0.5917 - val_loss: 0.8644
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8037 - loss: 0.4375
# Epoch 57: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8034 - loss: 0.4379 - val_accuracy: 0.5750 - val_loss: 0.8319
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8055 - loss: 0.4473
# Epoch 58: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8052 - loss: 0.4473 - val_accuracy: 0.5750 - val_loss: 0.8658
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8032 - loss: 0.4373
# Epoch 59: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8033 - loss: 0.4374 - val_accuracy: 0.5583 - val_loss: 0.8686
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8082 - loss: 0.4355
# Epoch 60: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8080 - loss: 0.4360 - val_accuracy: 0.5667 - val_loss: 0.8837
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.8150 - loss: 0.4118
# Epoch 61: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8154 - loss: 0.4120 - val_accuracy: 0.5667 - val_loss: 0.8528
# Epoch 62/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7907 - loss: 0.4369
# Epoch 62: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7908 - loss: 0.4367 - val_accuracy: 0.5833 - val_loss: 0.8926
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.8048 - loss: 0.4359
# Epoch 63: val_accuracy did not improve from 0.59167
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8048 - loss: 0.4359 - val_accuracy: 0.5833 - val_loss: 0.9028
# Epoch 64/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8101 - loss: 0.4116
# Epoch 64: val_accuracy improved from 0.59167 to 0.60000, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 11s 309ms/step - accuracy: 0.8103 - loss: 0.4116 - val_accuracy: 0.6000 - val_loss: 0.8767
# Epoch 65/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8243 - loss: 0.3971
# Epoch 65: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - accuracy: 0.8242 - loss: 0.3972 - val_accuracy: 0.5583 - val_loss: 0.8831
# Epoch 66/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8187 - loss: 0.4099
# Epoch 66: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8188 - loss: 0.4101 - val_accuracy: 0.5667 - val_loss: 0.8690
# Epoch 67/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8248 - loss: 0.3880
# Epoch 67: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8248 - loss: 0.3881 - val_accuracy: 0.5667 - val_loss: 0.8671
# Epoch 68/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.8394 - loss: 0.3793
# Epoch 68: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.8392 - loss: 0.3798 - val_accuracy: 0.5750 - val_loss: 0.9243
# Epoch 69/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8253 - loss: 0.4074
# Epoch 69: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8251 - loss: 0.4074 - val_accuracy: 0.5667 - val_loss: 0.8864
# Epoch 70/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8322 - loss: 0.3862
# Epoch 70: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8321 - loss: 0.3866 - val_accuracy: 0.5500 - val_loss: 0.9026
# Epoch 71/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8200 - loss: 0.4041
# Epoch 71: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8201 - loss: 0.4039 - val_accuracy: 0.5500 - val_loss: 0.9287
# Epoch 72/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8360 - loss: 0.3849
# Epoch 72: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8360 - loss: 0.3851 - val_accuracy: 0.5500 - val_loss: 0.9165
# Epoch 73/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8382 - loss: 0.3871
# Epoch 73: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8382 - loss: 0.3871 - val_accuracy: 0.5583 - val_loss: 0.9123
# Epoch 74/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8500 - loss: 0.3745
# Epoch 74: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8495 - loss: 0.3748 - val_accuracy: 0.5583 - val_loss: 0.9327
# Epoch 75/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8348 - loss: 0.3825
# Epoch 75: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8345 - loss: 0.3828 - val_accuracy: 0.5583 - val_loss: 0.9274
# Epoch 76/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8332 - loss: 0.3808
# Epoch 76: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8329 - loss: 0.3810 - val_accuracy: 0.5583 - val_loss: 0.9253
# Epoch 77/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8264 - loss: 0.3958
# Epoch 77: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8266 - loss: 0.3957 - val_accuracy: 0.5583 - val_loss: 0.9318
# Epoch 78/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8329 - loss: 0.3633
# Epoch 78: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8324 - loss: 0.3640 - val_accuracy: 0.5667 - val_loss: 0.9126
# Epoch 79/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8491 - loss: 0.3545
# Epoch 79: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8488 - loss: 0.3548 - val_accuracy: 0.5667 - val_loss: 0.9248
# Epoch 80/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8259 - loss: 0.3750
# Epoch 80: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8258 - loss: 0.3749 - val_accuracy: 0.5500 - val_loss: 0.9730
# Epoch 81/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8736 - loss: 0.3417
# Epoch 81: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8736 - loss: 0.3417 - val_accuracy: 0.5333 - val_loss: 0.9483
# Epoch 82/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.8253 - loss: 0.3764
# Epoch 82: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8259 - loss: 0.3757 - val_accuracy: 0.5417 - val_loss: 0.9973
# Epoch 83/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8577 - loss: 0.3424
# Epoch 83: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8579 - loss: 0.3421 - val_accuracy: 0.5500 - val_loss: 0.9987
# Epoch 84/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8507 - loss: 0.3449
# Epoch 84: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.8504 - loss: 0.3454 - val_accuracy: 0.5583 - val_loss: 1.0398
# Epoch 85/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8591 - loss: 0.3533
# Epoch 85: val_accuracy did not improve from 0.60000
# ...
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7151 - loss: 0.5604
# Epoch 39: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7146 - loss: 0.5609 - val_accuracy: 0.5500 - val_loss: 0.7346
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7037 - loss: 0.5951
# Epoch 40: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7035 - loss: 0.5952 - val_accuracy: 0.5500 - val_loss: 0.7428
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6923 - loss: 0.5979
# Epoch 41: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.6929 - loss: 0.5973 - val_accuracy: 0.5417 - val_loss: 0.7520
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6967 - loss: 0.5689
# Epoch 42: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.6968 - loss: 0.5690 - val_accuracy: 0.5417 - val_loss: 0.7425
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6973 - loss: 0.5826
# Epoch 43: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.6974 - loss: 0.5823 - val_accuracy: 0.5417 - val_loss: 0.7437
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7191 - loss: 0.5766
# Epoch 44: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7187 - loss: 0.5768 - val_accuracy: 0.5667 - val_loss: 0.7321
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7195 - loss: 0.5647
# Epoch 45: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7194 - loss: 0.5650 - val_accuracy: 0.5583 - val_loss: 0.7353
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7059 - loss: 0.5804
# Epoch 46: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7059 - loss: 0.5804 - val_accuracy: 0.5417 - val_loss: 0.7602
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7015 - loss: 0.5545
# Epoch 47: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7018 - loss: 0.5547 - val_accuracy: 0.5417 - val_loss: 0.7558
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.6936 - loss: 0.5794
# Epoch 48: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.6937 - loss: 0.5792 - val_accuracy: 0.5333 - val_loss: 0.7536
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7141 - loss: 0.5701
# Epoch 49: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7139 - loss: 0.5702 - val_accuracy: 0.5333 - val_loss: 0.7544
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7360 - loss: 0.5592
# Epoch 50: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7357 - loss: 0.5593 - val_accuracy: 0.5583 - val_loss: 0.7696
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7147 - loss: 0.5496
# Epoch 51: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7145 - loss: 0.5500 - val_accuracy: 0.5500 - val_loss: 0.7701
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7402 - loss: 0.5443
# Epoch 52: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7400 - loss: 0.5443 - val_accuracy: 0.5583 - val_loss: 0.7782
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7290 - loss: 0.5525
# Epoch 53: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7288 - loss: 0.5527 - val_accuracy: 0.5333 - val_loss: 0.7578
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7507 - loss: 0.5267
# Epoch 54: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7507 - loss: 0.5270 - val_accuracy: 0.5333 - val_loss: 0.7610
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7341 - loss: 0.5399
# Epoch 55: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7337 - loss: 0.5404 - val_accuracy: 0.5250 - val_loss: 0.7673
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7370 - loss: 0.5299
# Epoch 56: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7364 - loss: 0.5304 - val_accuracy: 0.5667 - val_loss: 0.7506
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7137 - loss: 0.5520
# Epoch 57: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7141 - loss: 0.5519 - val_accuracy: 0.5750 - val_loss: 0.7575
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7295 - loss: 0.5346
# Epoch 58: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7293 - loss: 0.5348 - val_accuracy: 0.5583 - val_loss: 0.7461
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7572 - loss: 0.5204
# Epoch 59: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7569 - loss: 0.5209 - val_accuracy: 0.5667 - val_loss: 0.7531
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7283 - loss: 0.5508
# Epoch 60: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7285 - loss: 0.5505 - val_accuracy: 0.5583 - val_loss: 0.7525
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7634 - loss: 0.5215
# Epoch 61: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7629 - loss: 0.5219 - val_accuracy: 0.5333 - val_loss: 0.7534
# Epoch 62/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7515 - loss: 0.5288
# Epoch 62: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7514 - loss: 0.5286 - val_accuracy: 0.5583 - val_loss: 0.7658
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7169 - loss: 0.5481
# Epoch 63: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7170 - loss: 0.5479 - val_accuracy: 0.5583 - val_loss: 0.7657
# Epoch 64/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7524 - loss: 0.5109
# Epoch 64: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7519 - loss: 0.5112 - val_accuracy: 0.5667 - val_loss: 0.7708
# Epoch 65/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7391 - loss: 0.5379
# Epoch 65: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7393 - loss: 0.5377 - val_accuracy: 0.5417 - val_loss: 0.7725
# Epoch 66/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7531 - loss: 0.5159
# Epoch 66: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7531 - loss: 0.5158 - val_accuracy: 0.5500 - val_loss: 0.7693
# Epoch 67/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7422 - loss: 0.5207
# Epoch 67: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7424 - loss: 0.5204 - val_accuracy: 0.5250 - val_loss: 0.7690
# Epoch 68/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7557 - loss: 0.5220
# Epoch 68: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7552 - loss: 0.5221 - val_accuracy: 0.5417 - val_loss: 0.7624
# Epoch 69/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7554 - loss: 0.5029
# Epoch 69: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7546 - loss: 0.5036 - val_accuracy: 0.5583 - val_loss: 0.7631
# Epoch 70/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7428 - loss: 0.5194
# Epoch 70: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7430 - loss: 0.5192 - val_accuracy: 0.5500 - val_loss: 0.7660
# Epoch 71/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7244 - loss: 0.5321
# Epoch 71: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7250 - loss: 0.5316 - val_accuracy: 0.5667 - val_loss: 0.7879
# Epoch 72/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7385 - loss: 0.5012
# Epoch 72: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7389 - loss: 0.5010 - val_accuracy: 0.5500 - val_loss: 0.7748
# Epoch 73/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7356 - loss: 0.5133
# Epoch 73: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7359 - loss: 0.5133 - val_accuracy: 0.5500 - val_loss: 0.7958
# Epoch 74/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7565 - loss: 0.5024
# Epoch 74: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7567 - loss: 0.5024 - val_accuracy: 0.5500 - val_loss: 0.7802
# Epoch 75/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7287 - loss: 0.5326
# Epoch 75: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7294 - loss: 0.5320 - val_accuracy: 0.5167 - val_loss: 0.7974
# Epoch 76/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7494 - loss: 0.4905
# Epoch 76: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7496 - loss: 0.4904 - val_accuracy: 0.5417 - val_loss: 0.7732
# Epoch 77/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7363 - loss: 0.5127
# Epoch 77: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7365 - loss: 0.5128 - val_accuracy: 0.5500 - val_loss: 0.7809
# Epoch 78/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7685 - loss: 0.5216
# Epoch 78: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7681 - loss: 0.5215 - val_accuracy: 0.5333 - val_loss: 0.7780
# Epoch 79/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7752 - loss: 0.4799
# Epoch 79: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7745 - loss: 0.4806 - val_accuracy: 0.5333 - val_loss: 0.7817
# Epoch 80/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7388 - loss: 0.5056
# Epoch 80: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7392 - loss: 0.5054 - val_accuracy: 0.5250 - val_loss: 0.7953
# Epoch 81/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7862 - loss: 0.4773
# Epoch 81: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7861 - loss: 0.4772 - val_accuracy: 0.5333 - val_loss: 0.8014
# Epoch 82/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7654 - loss: 0.4854
# Epoch 82: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7652 - loss: 0.4855 - val_accuracy: 0.5333 - val_loss: 0.8143
# Epoch 83/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7606 - loss: 0.4736
# Epoch 83: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7605 - loss: 0.4739 - val_accuracy: 0.5333 - val_loss: 0.8037
# Epoch 84/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7397 - loss: 0.5175
# Epoch 84: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7403 - loss: 0.5168 - val_accuracy: 0.5333 - val_loss: 0.8123
# Epoch 85/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7782 - loss: 0.4728
# Epoch 85: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7782 - loss: 0.4728 - val_accuracy: 0.5250 - val_loss: 0.8131
# Epoch 86/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7691 - loss: 0.4995
# Epoch 86: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7691 - loss: 0.4990 - val_accuracy: 0.5333 - val_loss: 0.8271
# Epoch 87/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7685 - loss: 0.4840
# Epoch 87: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7689 - loss: 0.4838 - val_accuracy: 0.5167 - val_loss: 0.8377
# Epoch 88/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.7756 - loss: 0.4984
# Epoch 88: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 283ms/step - accuracy: 0.7757 - loss: 0.4984 - val_accuracy: 0.5250 - val_loss: 0.8268
# Epoch 89/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7682 - loss: 0.4662
# Epoch 89: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7682 - loss: 0.4661 - val_accuracy: 0.5250 - val_loss: 0.8290
# Epoch 90/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7684 - loss: 0.4903
# Epoch 90: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7688 - loss: 0.4896 - val_accuracy: 0.5167 - val_loss: 0.8464
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7867 - loss: 0.4737
# Epoch 91: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7866 - loss: 0.4738 - val_accuracy: 0.5167 - val_loss: 0.8372
# Epoch 92/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7873 - loss: 0.4508
# Epoch 92: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7870 - loss: 0.4512 - val_accuracy: 0.5083 - val_loss: 0.8442
# Epoch 93/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7887 - loss: 0.4523
# Epoch 93: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7887 - loss: 0.4525 - val_accuracy: 0.5167 - val_loss: 0.8541
# Epoch 94/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7675 - loss: 0.4966
# Epoch 94: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7678 - loss: 0.4961 - val_accuracy: 0.5083 - val_loss: 0.8542
# Epoch 95/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7857 - loss: 0.4492
# Epoch 95: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7859 - loss: 0.4493 - val_accuracy: 0.5167 - val_loss: 0.8327
# Epoch 96/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7837 - loss: 0.4523
# Epoch 96: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7839 - loss: 0.4523 - val_accuracy: 0.5250 - val_loss: 0.8454
# Epoch 97/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7834 - loss: 0.4624
# Epoch 97: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7836 - loss: 0.4623 - val_accuracy: 0.5167 - val_loss: 0.8508
# Epoch 98/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7882 - loss: 0.4507
# Epoch 98: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.7878 - loss: 0.4512 - val_accuracy: 0.5083 - val_loss: 0.8613
# Epoch 99/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.7985 - loss: 0.4265
# Epoch 99: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 282ms/step - accuracy: 0.7982 - loss: 0.4272 - val_accuracy: 0.5167 - val_loss: 0.8548
# Epoch 100/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.8015 - loss: 0.4431
# Epoch 100: val_accuracy did not improve from 0.60000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.8009 - loss: 0.4437 - val_accuracy: 0.5250 - val_loss: 0.8425

# %%
    # Evaluate the model
    predictions_valid1 = model1.predict([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], batch_size=batch_size, verbose=1)
    score1 = log_loss(axial_mensicus_label_val, predictions_valid1)

    print(f"Log Loss Dropout-{dropout1}: {score1}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step
# Log Loss Dropout-0.2: 2.8817706325502104

# %%
    predictions_valid2 = model2.predict([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], batch_size=batch_size, verbose=1)
    score2 = log_loss(axial_mensicus_label_val, predictions_valid2)

    print(f"Log Loss Dropout -{dropout2}: {score2}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 36s 6s/step
# Log Loss Dropout -0.4: 1.798230279222065

# %%
    predictions_valid3 = model3.predict([axial_mensicus_val, coronal_mensicus_val, sagittal_mensicus_val], batch_size=batch_size, verbose=1)
    score3 = log_loss(axial_mensicus_label_val, predictions_valid3)

    print(f"Log Loss Dropout-{dropout3}: {score3}")
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e5869099480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e5869099480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 34s 6s/step
# Log Loss Dropout-0.5: 1.2000513650177822

# %%
import matplotlib.pyplot as plt

# Assuming you have `history1`, `history2`, and `history3` from different training runs

# Data from first run
acc1 = history1.history['accuracy']
val_acc1 = history1.history['val_accuracy']


# Data from second run
acc2 = history2.history['accuracy']
val_acc2 = history2.history['val_accuracy']


# Data from third run
acc3 = history3.history['accuracy']
val_acc3 = history3.history['val_accuracy']
epochs=range(len(acc1)) #No. of epochs


# Set a wider figure size
plt.figure(figsize=(10, 6))  # Adjust width and height accordingly

# Plot training and validation accuracy for all runs
plt.plot(epochs, acc1, color='blue', label=f"Training Accuracy - {dropout1}", alpha=0.8)
plt.plot(epochs, val_acc1, color='blue', linestyle='--', label=f'Validation Accuracy - {dropout1}', alpha=0.8)

plt.plot(epochs, acc2, color='green', label=f'Training Accuracy - {dropout2}', alpha=0.8)
plt.plot(epochs, val_acc2, color='green', linestyle='--', label=f'Validation Accuracy - {dropout2}', alpha=0.8)

plt.plot(epochs, acc3, color='red', label=f'Training Accuracy - {dropout3}', alpha=0.8)
plt.plot(epochs, val_acc3, color='red', linestyle='--', label=f'Validation Accuracy - {dropout3}', alpha=0.8)

# Adjust title and labels
plt.title(f'Training and Validation Accuracy - Dropout')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

# Add grid for better readability
plt.grid(True)


plt.legend()

plt.savefig(f'Train_val_acc_multiple_runs.png')
plt.show()

# %% [markdown]
# ## Model evaluation

# %%
# Data from first run
loss1 = history1.history['loss']
val_loss1 = history1.history['val_loss']
# Data from second run
loss2 = history2.history['loss']
val_loss2 = history2.history['val_loss']

# Data from third run
loss3 = history3.history['loss']
val_loss3 = history3.history['val_loss']

plt.figure(figsize=(10, 6))


plt.plot(epochs, loss1, color='blue', label=f"Training Loss - {dropout1}", alpha=0.8)
plt.plot(epochs, val_loss1, color='blue', linestyle='--', label=f'Validation Loss - {dropout1}', alpha=0.8)

plt.plot(epochs, loss2, color='green', label=f'Training Loss - {dropout2}', alpha=0.8)
plt.plot(epochs, val_loss2, color='green', linestyle='--', label=f'Validation Loss - {dropout2}', alpha=0.8)

plt.plot(epochs, loss3, color='red', label=f'Training Loss - {dropout3}', alpha=0.8)
plt.plot(epochs, val_loss3, color='red', linestyle='--', label=f'Validation Loss - {dropout3}', alpha=0.8)

# Adjust title and labels
plt.title(f'Training and Validation Loss - Dropout')
plt.xlabel('Epochs')
plt.ylabel('Loss')


plt.grid(True)

# Position legend outside the plot (to the right)
plt.legend()

# Save and display the plot
plt.tight_layout()
plt.savefig(f'Train_val_loss_multiple_runs.png')
plt.show()

# %%
# Function to calculate accuracy and misclassification
def calculate_accuracy(ypred, ytest):
    total = 0
    accurate = 0
    accurateindex = []
    wrongindex = []

    for i in range(len(ypred)):
        if np.argmax(ypred[i]) == np.argmax(ytest[i]):
            accurate += 1
            accurateindex.append(i)
        else:
            wrongindex.append(i)
        total += 1

    accuracy = round(accurate / total * 100, 3)
    return total, accurate, total - accurate, accuracy, accurateindex, wrongindex

# %%
total1, accurate1, wrong_1, accuracy_1, accurateindex_axial, wrongindex_axial = calculate_accuracy(predictions_valid1, axial_mensicus_label_val)
print(' - Total test data:', total1, '\tAccurately predicted data:', accurate1, '\tWrongly predicted data:', wrong_1)
print(f'{dropout1} learning Dropout:', accuracy_1, '%')


total2, accurate2, wrong_2, accuracy_2, accurateindex_axial, wrongindex_axial = calculate_accuracy(predictions_valid2, axial_mensicus_label_val)
print(' - Total test data:', total2, '\tAccurately predicted data:', accurate2, '\tWrongly predicted data:', wrong_2)
print(f'{dropout2} Dropout Accuracy:', accuracy_2, '%')

total3, accurate3, wrong_3, accuracy_3, accurateindex_axial, wrongindex_axial = calculate_accuracy(predictions_valid3, axial_mensicus_label_val)
print(' - Total test data:', total3, '\tAccurately predicted data:', accurate3, '\tWrongly predicted data:', wrong_3)
print(f'{dropout1} Dropout Accuracy:', accuracy_3, '%')
# Out:
#  - Total test data: 120 	Accurately predicted data: 63 	Wrongly predicted data: 57
# 0.2 learning Dropout: 52.5 %
#  - Total test data: 120 	Accurately predicted data: 65 	Wrongly predicted data: 55
# 0.4 Dropout Accuracy: 54.167 %
#  - Total test data: 120 	Accurately predicted data: 63 	Wrongly predicted data: 57
# 0.2 Dropout Accuracy: 52.5 %
