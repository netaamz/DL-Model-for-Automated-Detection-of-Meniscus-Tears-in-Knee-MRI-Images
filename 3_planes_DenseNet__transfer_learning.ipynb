# %% [markdown]
# <a href="https://colab.research.google.com/github/netaamz/DL-Model-for-Automated-Detection-of-Meniscus-Tears-in-Knee-MRI-Images/blob/main/3_planes_DenseNet__transfer_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone: Development of an algorithm for automatic detection of meniscus tears in radiographic images of the knee.

# %% [markdown]
# Important note: a pre processing is required, avilable notebook via github

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install tensorflow
# !pip install keras
# !pip install sklearn
# !pip install opencv-python
# !pip install matplotlib
# !pip install numpy
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)

# %% [markdown]
# ## Data import

# %% [markdown]
# **Data from [MRNet](https://stanfordmlgroup.github.io/competitions/mrnet/):**
# * Images of 1370 knee MRI exams performed at Stanford University Medical Center. The dataset contains 1,104 (80.6%) abnormal exams,  with 319 (23.3%) ACL tears and 508 (37.1%) meniscal tears; labels were obtained through manual extraction from clinical reports.
# * train set: consists of 1130 MRI images from coronal, sagittal and transverse planes
# * validation set: consists of 120 MRI images from coronal, sagittal and transverse planes

# %% [markdown]
# Connect google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Data generation for meniscus
# The dataset contains *s* x 256 x 256 images. Since middle images are the most useful, only 3 middle slides in the series are retained.

# %%
import numpy as np
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
def data_gen(dataset_type, plane, diagnosis):
    '''this function gets the data from the extracted datset'''

    if dataset_type == 'train':
        go = '/content/drive/My Drive/miniscus data set/MRNet-v1.0/train_transformf' # if we want without filter then:  /content/drive/My Drive/miniscus data set/MRNet-v1.0/train_transform
    else:
        go = '/content/drive/My Drive/miniscus data set/MRNet-v1.0/valid_transformf' # if we want without filter then: /content/drive/My Drive/miniscus data set/MRNet-v1.0/valid_transform

    plane_dir = f'{go}/{plane}.npy'

    data = np.load(plane_dir)
    label_path = f'/content/drive/My Drive/miniscus data set/MRNet-v1.0/{dataset_type}-{diagnosis}.csv'

    label_df = pd.read_csv(label_path, names=['nr', diagnosis])
    label_data = list(label_df[diagnosis])

    return(data, label_data)

# %% [markdown]
# Note that training data for all planes are the same. Only labels are different.

# %%
# generate training input
coronal_mensicus, coronal_mensicus_label = data_gen('train', 'coronal/extracted_images', 'meniscus')
axial_mensicus, axial_mensicus_label = data_gen('train', 'axial/extracted_images', 'meniscus')
sagittal_mensicus, sagittal_mensicus_label = data_gen('train', 'sagittal/extracted_images', 'meniscus')
print(sagittal_mensicus.shape)
# generate validation
coronal_mensicus_val, coronal_mensicus_label_val  = data_gen('valid', 'coronal/extracted_images', 'meniscus')
axial_mensicus_val, axial_mensicus_label_val  = data_gen('valid', 'axial/extracted_images', 'meniscus')
sagittal_mensicus_val, sagittal_mensicus_label_val  = data_gen('valid', 'sagittal/extracted_images', 'meniscus')
# Out:
# (1130, 256, 256, 3)

# %%
sagittal_mensicus_val.view
# Out:
# <function ndarray.view>

# %%
from keras.utils import to_categorical  # Import to_categorical
base_path = "/content/drive/My Drive/miniscus data set/MRNet-v1.0/"

num_classes =2

sagittal_mensicus_label = to_categorical(sagittal_mensicus_label, num_classes)
sagittal_mensicus_label_val = to_categorical(sagittal_mensicus_label_val, num_classes)

coronal_mensicus_label = to_categorical(coronal_mensicus_label, num_classes)
coronal_mensicus_label_val = to_categorical(coronal_mensicus_label_val, num_classes)

axial_mensicus_label = to_categorical(axial_mensicus_label, num_classes)
axial_mensicus_label_val = to_categorical(axial_mensicus_label_val, num_classes)

# %% [markdown]
# ## Model Architecture

# %% [markdown]
# The model is designed to classify grayscale MRI images for detecting normal menisci or meniscus tears. The input images, resized to 256x256x3, undergo preprocessing steps, including splicing and applying a White Top Hat filter to enhance features.
# * The preprocessed images are then fed into a pre-trained DenseNet121
# architecture, which has been modified to exclude its top classification layers.
# * The DenseNet121 model processes the input and outputs feature maps, which are subsequently passed through a Global Average Pooling layer, reducing the spatial dimensions into a 1D vector.
# * A Batch Normalization layer is applied to stabilize the network and improve learning performance.
# * The feature vector is then fed into a Dense Layer with 1024 units and ReLU activation to extract high-level features, followed by a Dropout Layer to mitigate overfitting.
# A second Dense Layer, also with 1024 units and ReLU activation, further refines the feature space.
# * Finally, the model outputs predictions through a Dense Layer with 2 units and sigmoid activation, representing the probabilities of the two classes (normal or meniscus tear).

# %% [markdown]
# ![Model Architecture -separated planes.drawio.png](data:image/png;base64,...)

# %%
import tensorflow as tf
import keras
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Input, Lambda, BatchNormalization, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint


def create_model(input_shape, num_classes, dropout):
    # Load the pre-trained DenseNet121 model
    base_model = DenseNet121(weights='imagenet', include_top=False, pooling=None,input_shape=input_shape)
    input_tensor = Input(shape=input_shape)

    x = base_model(input_tensor)
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(dropout)(x)
    x = Dense(1024, activation='relu')(x)
    output = Dense(num_classes, activation='sigmoid')(x)
    # Create the final model
    model = Model(inputs=input_tensor, outputs=output)

    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = False

    return model

# %% [markdown]
# ##  Hyperparameters
# define hyper parameters for training

# %%
    # Define your parameters
    img_rows, img_cols = 256, 256
    channel = 3
    batch_size = 32
    nb_epoch = 100
    dropout = 0.4
    lr = 5e-4  # Learning rate

# %% [markdown]
# ## Train

# %%
import tensorflow as tf
import keras

from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint


if __name__ == '__main__':
    # Create the model
    input_shape = (img_rows, img_cols, channel)
    model_axial = create_model(input_shape, num_classes, dropout)
    model_coronal = create_model(input_shape, num_classes, dropout)
    model_sagittal = create_model(input_shape, num_classes, dropout)

    # Compile the model

    model_axial.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    model_coronal.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    model_sagittal.compile(optimizer=SGD(learning_rate=lr, momentum=0.9),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Set up the checkpoint
    filepath = "bestmodel.keras"
    checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]


    # Train the model - axial
    history_axial = model_axial.fit(axial_mensicus, axial_mensicus_label,
                        batch_size=batch_size,
                        epochs=nb_epoch,
                        shuffle=True,
                        verbose=1,
                        validation_data=(axial_mensicus_val, axial_mensicus_label_val),
                        callbacks=callbacks_list)

    # Train the model - coronal
    history_coronal = model_coronal.fit(coronal_mensicus, coronal_mensicus_label,
                        batch_size=batch_size,
                        epochs=nb_epoch,
                        shuffle=True,
                        verbose=1,
                        validation_data=(coronal_mensicus_val, coronal_mensicus_label_val),
                        callbacks=callbacks_list)

    # Train the model- sagittal
    history_sagittal = model_sagittal.fit(sagittal_mensicus, sagittal_mensicus_label,
                        batch_size=batch_size,
                        epochs=nb_epoch,
                        shuffle=True,
                        verbose=1,
                        validation_data=(sagittal_mensicus_val, sagittal_mensicus_label_val),
                        callbacks=callbacks_list)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.5137 - loss: 1.3265
# Epoch 1: val_accuracy improved from -inf to 0.55000, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 57s 885ms/step - accuracy: 0.5146 - loss: 1.3219 - val_accuracy: 0.5500 - val_loss: 0.7631
# Epoch 2/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6118 - loss: 0.8154
# Epoch 2: val_accuracy did not improve from 0.55000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6119 - loss: 0.8160 - val_accuracy: 0.5250 - val_loss: 0.7296
# Epoch 3/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5881 - loss: 0.8143
# Epoch 3: val_accuracy did not improve from 0.55000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.5888 - loss: 0.8124 - val_accuracy: 0.5500 - val_loss: 0.7071
# Epoch 4/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6218 - loss: 0.7621
# Epoch 4: val_accuracy did not improve from 0.55000
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.6210 - loss: 0.7611 - val_accuracy: 0.5500 - val_loss: 0.7035
# Epoch 5/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6007 - loss: 0.7324
# Epoch 5: val_accuracy improved from 0.55000 to 0.58333, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 115ms/step - accuracy: 0.6018 - loss: 0.7315 - val_accuracy: 0.5833 - val_loss: 0.7104
# Epoch 6/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6348 - loss: 0.7024
# Epoch 6: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6334 - loss: 0.7033 - val_accuracy: 0.5667 - val_loss: 0.7066
# Epoch 7/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6408 - loss: 0.6667
# Epoch 7: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6412 - loss: 0.6665 - val_accuracy: 0.5417 - val_loss: 0.7017
# Epoch 8/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6457 - loss: 0.6720
# Epoch 8: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6449 - loss: 0.6724 - val_accuracy: 0.5583 - val_loss: 0.7285
# Epoch 9/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6388 - loss: 0.6879
# Epoch 9: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6387 - loss: 0.6874 - val_accuracy: 0.5583 - val_loss: 0.7461
# Epoch 10/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6459 - loss: 0.6556
# Epoch 10: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6455 - loss: 0.6556 - val_accuracy: 0.5583 - val_loss: 0.6980
# Epoch 11/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6673 - loss: 0.6538
# Epoch 11: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.6666 - loss: 0.6538 - val_accuracy: 0.5417 - val_loss: 0.7069
# Epoch 12/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6504 - loss: 0.6485
# Epoch 12: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6500 - loss: 0.6488 - val_accuracy: 0.5750 - val_loss: 0.7022
# Epoch 13/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6574 - loss: 0.6383
# Epoch 13: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6567 - loss: 0.6393 - val_accuracy: 0.5583 - val_loss: 0.7001
# Epoch 14/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6596 - loss: 0.6381
# Epoch 14: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6589 - loss: 0.6389 - val_accuracy: 0.5333 - val_loss: 0.7029
# Epoch 15/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6662 - loss: 0.6401
# Epoch 15: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6655 - loss: 0.6402 - val_accuracy: 0.5667 - val_loss: 0.7010
# Epoch 16/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6671 - loss: 0.6300
# Epoch 16: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6667 - loss: 0.6305 - val_accuracy: 0.5500 - val_loss: 0.7010
# Epoch 17/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6858 - loss: 0.6184
# Epoch 17: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6839 - loss: 0.6192 - val_accuracy: 0.5417 - val_loss: 0.6980
# Epoch 18/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6726 - loss: 0.6197
# Epoch 18: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6721 - loss: 0.6205 - val_accuracy: 0.5583 - val_loss: 0.7018
# Epoch 19/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6322 - loss: 0.6436
# Epoch 19: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6331 - loss: 0.6431 - val_accuracy: 0.5750 - val_loss: 0.6926
# Epoch 20/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6625 - loss: 0.6211
# Epoch 20: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6624 - loss: 0.6212 - val_accuracy: 0.5833 - val_loss: 0.6923
# Epoch 21/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6555 - loss: 0.6203
# Epoch 21: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6555 - loss: 0.6204 - val_accuracy: 0.5250 - val_loss: 0.6978
# Epoch 22/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6505 - loss: 0.6276
# Epoch 22: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6509 - loss: 0.6272 - val_accuracy: 0.5750 - val_loss: 0.6972
# Epoch 23/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6744 - loss: 0.6195
# Epoch 23: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6743 - loss: 0.6195 - val_accuracy: 0.5667 - val_loss: 0.6966
# Epoch 24/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6664 - loss: 0.6080
# Epoch 24: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6664 - loss: 0.6083 - val_accuracy: 0.5667 - val_loss: 0.6958
# Epoch 25/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6662 - loss: 0.6127
# Epoch 25: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6661 - loss: 0.6131 - val_accuracy: 0.5667 - val_loss: 0.6971
# Epoch 26/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6747 - loss: 0.6071
# Epoch 26: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6741 - loss: 0.6077 - val_accuracy: 0.5750 - val_loss: 0.6945
# Epoch 27/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6944 - loss: 0.5980
# Epoch 27: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6935 - loss: 0.5985 - val_accuracy: 0.5583 - val_loss: 0.6988
# Epoch 28/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6844 - loss: 0.6056
# Epoch 28: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6837 - loss: 0.6060 - val_accuracy: 0.5583 - val_loss: 0.7061
# Epoch 29/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6793 - loss: 0.5939
# Epoch 29: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6784 - loss: 0.5952 - val_accuracy: 0.5583 - val_loss: 0.7052
# Epoch 30/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6826 - loss: 0.6050
# Epoch 30: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6823 - loss: 0.6050 - val_accuracy: 0.5250 - val_loss: 0.7033
# Epoch 31/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6501 - loss: 0.6188
# Epoch 31: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6507 - loss: 0.6187 - val_accuracy: 0.5250 - val_loss: 0.7086
# Epoch 32/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6655 - loss: 0.6177
# Epoch 32: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6662 - loss: 0.6168 - val_accuracy: 0.5500 - val_loss: 0.7018
# Epoch 33/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6675 - loss: 0.6018
# Epoch 33: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6673 - loss: 0.6021 - val_accuracy: 0.5583 - val_loss: 0.7114
# Epoch 34/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6846 - loss: 0.5991
# Epoch 34: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6839 - loss: 0.6001 - val_accuracy: 0.5583 - val_loss: 0.7105
# Epoch 35/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6805 - loss: 0.6139
# Epoch 35: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6809 - loss: 0.6133 - val_accuracy: 0.5583 - val_loss: 0.7206
# Epoch 36/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6623 - loss: 0.6055
# Epoch 36: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6629 - loss: 0.6051 - val_accuracy: 0.5083 - val_loss: 0.7068
# Epoch 37/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7187 - loss: 0.5796
# Epoch 37: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7175 - loss: 0.5800 - val_accuracy: 0.5083 - val_loss: 0.7112
# Epoch 38/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6743 - loss: 0.6043
# Epoch 38: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6732 - loss: 0.6049 - val_accuracy: 0.5167 - val_loss: 0.7149
# Epoch 39/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6946 - loss: 0.5811
# Epoch 39: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6942 - loss: 0.5812 - val_accuracy: 0.5167 - val_loss: 0.7078
# Epoch 40/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6919 - loss: 0.5890
# Epoch 40: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6921 - loss: 0.5890 - val_accuracy: 0.5417 - val_loss: 0.7132
# Epoch 41/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6909 - loss: 0.5838
# Epoch 41: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6909 - loss: 0.5841 - val_accuracy: 0.5417 - val_loss: 0.7149
# Epoch 42/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6933 - loss: 0.5790
# Epoch 42: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6924 - loss: 0.5798 - val_accuracy: 0.5083 - val_loss: 0.7168
# Epoch 43/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6879 - loss: 0.5837
# Epoch 43: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6877 - loss: 0.5838 - val_accuracy: 0.5500 - val_loss: 0.7184
# Epoch 44/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6952 - loss: 0.5907
# Epoch 44: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6951 - loss: 0.5909 - val_accuracy: 0.5333 - val_loss: 0.7172
# Epoch 45/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6952 - loss: 0.5683
# Epoch 45: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6950 - loss: 0.5690 - val_accuracy: 0.5250 - val_loss: 0.7225
# Epoch 46/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6913 - loss: 0.5962
# Epoch 46: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6917 - loss: 0.5956 - val_accuracy: 0.5333 - val_loss: 0.7148
# Epoch 47/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7301 - loss: 0.5512
# Epoch 47: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7291 - loss: 0.5522 - val_accuracy: 0.5333 - val_loss: 0.7215
# Epoch 48/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7143 - loss: 0.5528
# Epoch 48: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7141 - loss: 0.5535 - val_accuracy: 0.5083 - val_loss: 0.7397
# Epoch 49/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7074 - loss: 0.5774
# Epoch 49: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7064 - loss: 0.5775 - val_accuracy: 0.5167 - val_loss: 0.7325
# Epoch 50/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6926 - loss: 0.5821
# Epoch 50: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6923 - loss: 0.5823 - val_accuracy: 0.5333 - val_loss: 0.7234
# Epoch 51/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7353 - loss: 0.5788
# Epoch 51: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7342 - loss: 0.5786 - val_accuracy: 0.5250 - val_loss: 0.7306
# Epoch 52/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7024 - loss: 0.5808
# Epoch 52: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7025 - loss: 0.5806 - val_accuracy: 0.5417 - val_loss: 0.7331
# Epoch 53/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6708 - loss: 0.5837
# Epoch 53: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6716 - loss: 0.5834 - val_accuracy: 0.5333 - val_loss: 0.7368
# Epoch 54/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6992 - loss: 0.5608
# Epoch 54: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6993 - loss: 0.5612 - val_accuracy: 0.5083 - val_loss: 0.7453
# Epoch 55/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7027 - loss: 0.5697
# Epoch 55: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7029 - loss: 0.5697 - val_accuracy: 0.5167 - val_loss: 0.7449
# Epoch 56/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7435 - loss: 0.5425
# Epoch 56: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7416 - loss: 0.5438 - val_accuracy: 0.5250 - val_loss: 0.7345
# Epoch 57/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7355 - loss: 0.5535
# Epoch 57: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7341 - loss: 0.5543 - val_accuracy: 0.4917 - val_loss: 0.7429
# Epoch 58/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7134 - loss: 0.5628
# Epoch 58: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7132 - loss: 0.5630 - val_accuracy: 0.5250 - val_loss: 0.7399
# Epoch 59/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6870 - loss: 0.5854
# Epoch 59: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6883 - loss: 0.5840 - val_accuracy: 0.5083 - val_loss: 0.7479
# Epoch 60/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7328 - loss: 0.5459
# Epoch 60: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7329 - loss: 0.5459 - val_accuracy: 0.5250 - val_loss: 0.7348
# Epoch 61/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7246 - loss: 0.5389
# Epoch 61: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7241 - loss: 0.5397 - val_accuracy: 0.5250 - val_loss: 0.7490
# Epoch 62/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7063 - loss: 0.5441
# Epoch 62: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7061 - loss: 0.5451 - val_accuracy: 0.5167 - val_loss: 0.7395
# Epoch 63/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7295 - loss: 0.5399
# Epoch 63: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7293 - loss: 0.5403 - val_accuracy: 0.5083 - val_loss: 0.7609
# Epoch 64/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7390 - loss: 0.5252
# Epoch 64: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7389 - loss: 0.5257 - val_accuracy: 0.5167 - val_loss: 0.7657
# Epoch 65/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7277 - loss: 0.5338
# Epoch 65: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7274 - loss: 0.5344 - val_accuracy: 0.4917 - val_loss: 0.7762
# Epoch 66/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7321 - loss: 0.5404
# Epoch 66: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7314 - loss: 0.5406 - val_accuracy: 0.4917 - val_loss: 0.7754
# Epoch 67/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7406 - loss: 0.5212
# Epoch 67: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7399 - loss: 0.5224 - val_accuracy: 0.4750 - val_loss: 0.7799
# Epoch 68/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7574 - loss: 0.5296
# Epoch 68: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7565 - loss: 0.5301 - val_accuracy: 0.4917 - val_loss: 0.8061
# Epoch 69/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7246 - loss: 0.5424
# Epoch 69: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.7245 - loss: 0.5426 - val_accuracy: 0.5083 - val_loss: 0.7599
# Epoch 70/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7337 - loss: 0.5407
# Epoch 70: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7344 - loss: 0.5401 - val_accuracy: 0.5083 - val_loss: 0.7665
# Epoch 71/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7060 - loss: 0.5583
# Epoch 71: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7073 - loss: 0.5570 - val_accuracy: 0.4917 - val_loss: 0.7750
# Epoch 72/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7549 - loss: 0.5180
# Epoch 72: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7541 - loss: 0.5185 - val_accuracy: 0.5083 - val_loss: 0.7781
# Epoch 73/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7599 - loss: 0.5043
# Epoch 73: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7591 - loss: 0.5050 - val_accuracy: 0.4917 - val_loss: 0.7769
# Epoch 74/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7478 - loss: 0.5175
# Epoch 74: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7472 - loss: 0.5177 - val_accuracy: 0.4917 - val_loss: 0.8155
# Epoch 75/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7102 - loss: 0.5611
# Epoch 75: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7105 - loss: 0.5602 - val_accuracy: 0.5250 - val_loss: 0.7842
# Epoch 76/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7461 - loss: 0.5245
# Epoch 76: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7457 - loss: 0.5247 - val_accuracy: 0.5000 - val_loss: 0.8179
# Epoch 77/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7663 - loss: 0.5159
# Epoch 77: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7659 - loss: 0.5161 - val_accuracy: 0.5000 - val_loss: 0.7790
# Epoch 78/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7337 - loss: 0.5278
# Epoch 78: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7336 - loss: 0.5282 - val_accuracy: 0.4833 - val_loss: 0.7839
# Epoch 79/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7269 - loss: 0.5141
# Epoch 79: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7279 - loss: 0.5146 - val_accuracy: 0.5083 - val_loss: 0.8232
# Epoch 80/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7429 - loss: 0.5193
# Epoch 80: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7436 - loss: 0.5190 - val_accuracy: 0.5083 - val_loss: 0.7795
# Epoch 81/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7445 - loss: 0.5003
# Epoch 81: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7436 - loss: 0.5017 - val_accuracy: 0.5000 - val_loss: 0.7782
# Epoch 82/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7608 - loss: 0.5027
# Epoch 82: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7608 - loss: 0.5030 - val_accuracy: 0.5167 - val_loss: 0.7978
# Epoch 83/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7478 - loss: 0.5151
# Epoch 83: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7477 - loss: 0.5152 - val_accuracy: 0.5000 - val_loss: 0.8187
# Epoch 84/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7514 - loss: 0.5092
# Epoch 84: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7513 - loss: 0.5093 - val_accuracy: 0.4917 - val_loss: 0.8528
# Epoch 85/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7856 - loss: 0.4915
# Epoch 85: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7847 - loss: 0.4924 - val_accuracy: 0.4833 - val_loss: 0.8308
# Epoch 86/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7643 - loss: 0.5156
# Epoch 86: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7637 - loss: 0.5156 - val_accuracy: 0.4750 - val_loss: 0.8230
# Epoch 87/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7888 - loss: 0.4869
# Epoch 87: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7872 - loss: 0.4873 - val_accuracy: 0.5000 - val_loss: 0.8311
# Epoch 88/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7661 - loss: 0.4916
# Epoch 88: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7657 - loss: 0.4921 - val_accuracy: 0.4750 - val_loss: 0.8605
# Epoch 89/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7702 - loss: 0.4888
# Epoch 89: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7699 - loss: 0.4889 - val_accuracy: 0.4750 - val_loss: 0.8949
# Epoch 90/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7420 - loss: 0.5027
# Epoch 90: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7427 - loss: 0.5023 - val_accuracy: 0.4833 - val_loss: 0.8918
# Epoch 91/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7772 - loss: 0.4873
# Epoch 91: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7769 - loss: 0.4872 - val_accuracy: 0.5000 - val_loss: 0.8553
# Epoch 92/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7862 - loss: 0.4749
# Epoch 92: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7853 - loss: 0.4761 - val_accuracy: 0.5000 - val_loss: 0.8458
# Epoch 93/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7629 - loss: 0.4803
# Epoch 93: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7635 - loss: 0.4806 - val_accuracy: 0.4750 - val_loss: 0.8489
# Epoch 94/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7837 - loss: 0.4647
# Epoch 94: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7826 - loss: 0.4660 - val_accuracy: 0.4917 - val_loss: 0.8430
# Epoch 95/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7785 - loss: 0.4759
# Epoch 95: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7782 - loss: 0.4764 - val_accuracy: 0.4833 - val_loss: 0.8592
# Epoch 96/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7442 - loss: 0.5183
# Epoch 96: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7446 - loss: 0.5175 - val_accuracy: 0.4750 - val_loss: 0.8481
# Epoch 97/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7610 - loss: 0.4834
# Epoch 97: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7619 - loss: 0.4828 - val_accuracy: 0.4583 - val_loss: 0.8815
# Epoch 98/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7868 - loss: 0.4786
# Epoch 98: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7863 - loss: 0.4784 - val_accuracy: 0.4833 - val_loss: 0.8606
# Epoch 99/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7661 - loss: 0.4763
# Epoch 99: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7656 - loss: 0.4772 - val_accuracy: 0.4917 - val_loss: 0.8444
# Epoch 100/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7788 - loss: 0.4846
# Epoch 100: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7785 - loss: 0.4845 - val_accuracy: 0.4750 - val_loss: 0.8944
# Epoch 1/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.6259 - loss: 1.1935
# Epoch 1: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 35s 519ms/step - accuracy: 0.6251 - loss: 1.1898 - val_accuracy: 0.5667 - val_loss: 0.8564
# Epoch 2/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5583 - loss: 0.8954
# Epoch 2: val_accuracy did not improve from 0.58333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.5590 - loss: 0.8946 - val_accuracy: 0.4250 - val_loss: 0.8354
# Epoch 3/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5418 - loss: 0.7972
# Epoch 3: val_accuracy improved from 0.58333 to 0.63333, saving model to bestmodel.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.5448 - loss: 0.7948 - val_accuracy: 0.6333 - val_loss: 0.7096
# Epoch 4/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6022 - loss: 0.7244
# Epoch 4: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6024 - loss: 0.7249 - val_accuracy: 0.4500 - val_loss: 0.7999
# Epoch 5/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6117 - loss: 0.7277
# Epoch 5: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6117 - loss: 0.7276 - val_accuracy: 0.5750 - val_loss: 0.7332
# Epoch 6/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6467 - loss: 0.6683
# Epoch 6: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6461 - loss: 0.6691 - val_accuracy: 0.5667 - val_loss: 0.7110
# Epoch 7/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6382 - loss: 0.6729
# Epoch 7: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6381 - loss: 0.6735 - val_accuracy: 0.5667 - val_loss: 0.7163
# Epoch 8/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6164 - loss: 0.7054
# Epoch 8: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6171 - loss: 0.7042 - val_accuracy: 0.5750 - val_loss: 0.6980
# Epoch 9/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6538 - loss: 0.6633
# Epoch 9: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6533 - loss: 0.6637 - val_accuracy: 0.5750 - val_loss: 0.6998
# Epoch 10/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6269 - loss: 0.6757
# Epoch 10: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.6265 - loss: 0.6758 - val_accuracy: 0.5750 - val_loss: 0.6870
# Epoch 11/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6440 - loss: 0.6672
# Epoch 11: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.6436 - loss: 0.6674 - val_accuracy: 0.5750 - val_loss: 0.7054
# Epoch 12/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6487 - loss: 0.6637
# Epoch 12: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6482 - loss: 0.6636 - val_accuracy: 0.6000 - val_loss: 0.6805
# Epoch 13/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6194 - loss: 0.6546
# Epoch 13: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6201 - loss: 0.6546 - val_accuracy: 0.6000 - val_loss: 0.6873
# Epoch 14/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6491 - loss: 0.6479
# Epoch 14: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6495 - loss: 0.6481 - val_accuracy: 0.5667 - val_loss: 0.6799
# Epoch 15/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6546 - loss: 0.6316
# Epoch 15: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6541 - loss: 0.6324 - val_accuracy: 0.5833 - val_loss: 0.6846
# Epoch 16/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6672 - loss: 0.6374
# Epoch 16: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6673 - loss: 0.6377 - val_accuracy: 0.5750 - val_loss: 0.7054
# Epoch 17/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6470 - loss: 0.6461
# Epoch 17: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6474 - loss: 0.6456 - val_accuracy: 0.5583 - val_loss: 0.6975
# Epoch 18/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6805 - loss: 0.6188
# Epoch 18: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6792 - loss: 0.6200 - val_accuracy: 0.5833 - val_loss: 0.7109
# Epoch 19/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6471 - loss: 0.6329
# Epoch 19: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6474 - loss: 0.6331 - val_accuracy: 0.5667 - val_loss: 0.6887
# Epoch 20/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6695 - loss: 0.6429
# Epoch 20: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6703 - loss: 0.6420 - val_accuracy: 0.5750 - val_loss: 0.7280
# Epoch 21/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6876 - loss: 0.6112
# Epoch 21: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6862 - loss: 0.6119 - val_accuracy: 0.5583 - val_loss: 0.6900
# Epoch 22/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6817 - loss: 0.6147
# Epoch 22: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6807 - loss: 0.6152 - val_accuracy: 0.5750 - val_loss: 0.7130
# Epoch 23/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6721 - loss: 0.6183
# Epoch 23: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6715 - loss: 0.6195 - val_accuracy: 0.5917 - val_loss: 0.6978
# Epoch 24/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6680 - loss: 0.6215
# Epoch 24: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6674 - loss: 0.6225 - val_accuracy: 0.5750 - val_loss: 0.6949
# Epoch 25/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6737 - loss: 0.6284
# Epoch 25: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6731 - loss: 0.6288 - val_accuracy: 0.5583 - val_loss: 0.6925
# Epoch 26/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6576 - loss: 0.6302
# Epoch 26: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6572 - loss: 0.6307 - val_accuracy: 0.5750 - val_loss: 0.7263
# Epoch 27/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6477 - loss: 0.6246
# Epoch 27: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6483 - loss: 0.6242 - val_accuracy: 0.5083 - val_loss: 0.7045
# Epoch 28/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6970 - loss: 0.6030
# Epoch 28: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6956 - loss: 0.6038 - val_accuracy: 0.5167 - val_loss: 0.6986
# Epoch 29/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6617 - loss: 0.6163
# Epoch 29: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6618 - loss: 0.6161 - val_accuracy: 0.5500 - val_loss: 0.7069
# Epoch 30/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6719 - loss: 0.6116
# Epoch 30: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6722 - loss: 0.6114 - val_accuracy: 0.5833 - val_loss: 0.7230
# Epoch 31/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6655 - loss: 0.6187
# Epoch 31: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6654 - loss: 0.6184 - val_accuracy: 0.5750 - val_loss: 0.7214
# Epoch 32/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6563 - loss: 0.6101
# Epoch 32: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6568 - loss: 0.6095 - val_accuracy: 0.5750 - val_loss: 0.7203
# Epoch 33/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6970 - loss: 0.5844
# Epoch 33: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6960 - loss: 0.5853 - val_accuracy: 0.5417 - val_loss: 0.6968
# Epoch 34/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6810 - loss: 0.6031
# Epoch 34: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6808 - loss: 0.6033 - val_accuracy: 0.5667 - val_loss: 0.7236
# Epoch 35/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6907 - loss: 0.5879
# Epoch 35: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6902 - loss: 0.5887 - val_accuracy: 0.5500 - val_loss: 0.7146
# Epoch 36/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6811 - loss: 0.6065
# Epoch 36: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6801 - loss: 0.6072 - val_accuracy: 0.5583 - val_loss: 0.7268
# Epoch 37/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6989 - loss: 0.6018
# Epoch 37: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6988 - loss: 0.6019 - val_accuracy: 0.5583 - val_loss: 0.7107
# Epoch 38/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7011 - loss: 0.5888
# Epoch 38: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7011 - loss: 0.5890 - val_accuracy: 0.5583 - val_loss: 0.7339
# Epoch 39/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6732 - loss: 0.5939
# Epoch 39: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6735 - loss: 0.5939 - val_accuracy: 0.5750 - val_loss: 0.7371
# Epoch 40/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6780 - loss: 0.5961
# Epoch 40: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6785 - loss: 0.5959 - val_accuracy: 0.5667 - val_loss: 0.7276
# Epoch 41/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6883 - loss: 0.6023
# Epoch 41: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6881 - loss: 0.6019 - val_accuracy: 0.5333 - val_loss: 0.7031
# Epoch 42/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7119 - loss: 0.5839
# Epoch 42: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7110 - loss: 0.5841 - val_accuracy: 0.5333 - val_loss: 0.7138
# Epoch 43/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7183 - loss: 0.5678
# Epoch 43: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7171 - loss: 0.5687 - val_accuracy: 0.5333 - val_loss: 0.7116
# Epoch 44/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7105 - loss: 0.5843
# Epoch 44: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7101 - loss: 0.5843 - val_accuracy: 0.5417 - val_loss: 0.7061
# Epoch 45/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7184 - loss: 0.5761
# Epoch 45: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7176 - loss: 0.5767 - val_accuracy: 0.5500 - val_loss: 0.7345
# Epoch 46/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6876 - loss: 0.5780
# Epoch 46: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6880 - loss: 0.5781 - val_accuracy: 0.5333 - val_loss: 0.7086
# Epoch 47/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7129 - loss: 0.5849
# Epoch 47: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7123 - loss: 0.5849 - val_accuracy: 0.5417 - val_loss: 0.7144
# Epoch 48/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6942 - loss: 0.5931
# Epoch 48: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6943 - loss: 0.5935 - val_accuracy: 0.5250 - val_loss: 0.7126
# Epoch 49/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7055 - loss: 0.5754
# Epoch 49: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7053 - loss: 0.5757 - val_accuracy: 0.5500 - val_loss: 0.7009
# Epoch 50/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7132 - loss: 0.5551
# Epoch 50: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7123 - loss: 0.5562 - val_accuracy: 0.5250 - val_loss: 0.7061
# Epoch 51/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6898 - loss: 0.5886
# Epoch 51: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6905 - loss: 0.5880 - val_accuracy: 0.5500 - val_loss: 0.7404
# Epoch 52/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7357 - loss: 0.5611
# Epoch 52: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7349 - loss: 0.5615 - val_accuracy: 0.5500 - val_loss: 0.7433
# Epoch 53/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6859 - loss: 0.5954
# Epoch 53: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6865 - loss: 0.5946 - val_accuracy: 0.5417 - val_loss: 0.7175
# Epoch 54/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7509 - loss: 0.5504
# Epoch 54: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7506 - loss: 0.5507 - val_accuracy: 0.5583 - val_loss: 0.7918
# Epoch 55/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7217 - loss: 0.5642
# Epoch 55: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7217 - loss: 0.5642 - val_accuracy: 0.5167 - val_loss: 0.7151
# Epoch 56/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7186 - loss: 0.5666
# Epoch 56: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7188 - loss: 0.5662 - val_accuracy: 0.5583 - val_loss: 0.7880
# Epoch 57/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6965 - loss: 0.5627
# Epoch 57: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6972 - loss: 0.5629 - val_accuracy: 0.5500 - val_loss: 0.7182
# Epoch 58/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6859 - loss: 0.5686
# Epoch 58: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6869 - loss: 0.5684 - val_accuracy: 0.5583 - val_loss: 0.7475
# Epoch 59/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7421 - loss: 0.5385
# Epoch 59: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7413 - loss: 0.5394 - val_accuracy: 0.5417 - val_loss: 0.7236
# Epoch 60/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7226 - loss: 0.5587
# Epoch 60: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7232 - loss: 0.5580 - val_accuracy: 0.5583 - val_loss: 0.7348
# Epoch 61/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7150 - loss: 0.5655
# Epoch 61: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7149 - loss: 0.5659 - val_accuracy: 0.5417 - val_loss: 0.7328
# Epoch 62/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7172 - loss: 0.5502
# Epoch 62: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7180 - loss: 0.5499 - val_accuracy: 0.5500 - val_loss: 0.7449
# Epoch 63/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6959 - loss: 0.5676
# Epoch 63: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6961 - loss: 0.5675 - val_accuracy: 0.5250 - val_loss: 0.7248
# Epoch 64/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7475 - loss: 0.5489
# Epoch 64: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7461 - loss: 0.5494 - val_accuracy: 0.5333 - val_loss: 0.7190
# Epoch 65/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7354 - loss: 0.5318
# Epoch 65: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7349 - loss: 0.5326 - val_accuracy: 0.5500 - val_loss: 0.7316
# Epoch 66/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7521 - loss: 0.5250
# Epoch 66: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7521 - loss: 0.5254 - val_accuracy: 0.5167 - val_loss: 0.7431
# Epoch 67/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7381 - loss: 0.5367
# Epoch 67: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7377 - loss: 0.5370 - val_accuracy: 0.5667 - val_loss: 0.7637
# Epoch 68/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7374 - loss: 0.5449
# Epoch 68: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7372 - loss: 0.5449 - val_accuracy: 0.5167 - val_loss: 0.7337
# Epoch 69/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7445 - loss: 0.5267
# Epoch 69: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7436 - loss: 0.5274 - val_accuracy: 0.5167 - val_loss: 0.7235
# Epoch 70/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7228 - loss: 0.5317
# Epoch 70: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7235 - loss: 0.5316 - val_accuracy: 0.5250 - val_loss: 0.7399
# Epoch 71/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7480 - loss: 0.5374
# Epoch 71: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7483 - loss: 0.5368 - val_accuracy: 0.5750 - val_loss: 0.7865
# Epoch 72/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7475 - loss: 0.5386
# Epoch 72: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7478 - loss: 0.5382 - val_accuracy: 0.5000 - val_loss: 0.7214
# Epoch 73/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7492 - loss: 0.5379
# Epoch 73: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7488 - loss: 0.5379 - val_accuracy: 0.5417 - val_loss: 0.7674
# Epoch 74/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7333 - loss: 0.5399
# Epoch 74: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7340 - loss: 0.5392 - val_accuracy: 0.5333 - val_loss: 0.7449
# Epoch 75/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7298 - loss: 0.5285
# Epoch 75: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7303 - loss: 0.5284 - val_accuracy: 0.5333 - val_loss: 0.7370
# Epoch 76/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7418 - loss: 0.5255
# Epoch 76: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step - accuracy: 0.7421 - loss: 0.5255 - val_accuracy: 0.5250 - val_loss: 0.7817
# Epoch 77/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7616 - loss: 0.4975
# Epoch 77: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7618 - loss: 0.4986 - val_accuracy: 0.5167 - val_loss: 0.7312
# Epoch 78/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7682 - loss: 0.5127
# Epoch 78: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7677 - loss: 0.5128 - val_accuracy: 0.5500 - val_loss: 0.7909
# Epoch 79/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7326 - loss: 0.5350
# Epoch 79: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7334 - loss: 0.5346 - val_accuracy: 0.5500 - val_loss: 0.7429
# Epoch 80/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7613 - loss: 0.5063
# Epoch 80: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7609 - loss: 0.5069 - val_accuracy: 0.5250 - val_loss: 0.7406
# Epoch 81/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7682 - loss: 0.5033
# Epoch 81: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7675 - loss: 0.5038 - val_accuracy: 0.5250 - val_loss: 0.7649
# Epoch 82/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7711 - loss: 0.5052
# Epoch 82: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7699 - loss: 0.5061 - val_accuracy: 0.5333 - val_loss: 0.7610
# Epoch 83/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7852 - loss: 0.4990
# Epoch 83: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7848 - loss: 0.4992 - val_accuracy: 0.5417 - val_loss: 0.7626
# Epoch 84/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7560 - loss: 0.4980
# Epoch 84: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7556 - loss: 0.4985 - val_accuracy: 0.5250 - val_loss: 0.7299
# Epoch 85/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7885 - loss: 0.4984
# Epoch 85: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7867 - loss: 0.4990 - val_accuracy: 0.5417 - val_loss: 0.7907
# Epoch 86/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7727 - loss: 0.4780
# Epoch 86: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7727 - loss: 0.4788 - val_accuracy: 0.5333 - val_loss: 0.7916
# Epoch 87/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7813 - loss: 0.4870
# Epoch 87: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7811 - loss: 0.4875 - val_accuracy: 0.5000 - val_loss: 0.7473
# Epoch 88/100
# ...
# Epoch 38: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7204 - loss: 0.5744 - val_accuracy: 0.5667 - val_loss: 0.8246
# Epoch 39/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6578 - loss: 0.5996
# Epoch 39: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6588 - loss: 0.5992 - val_accuracy: 0.5417 - val_loss: 0.7780
# Epoch 40/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7095 - loss: 0.5663
# Epoch 40: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7086 - loss: 0.5674 - val_accuracy: 0.5417 - val_loss: 0.7756
# Epoch 41/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6821 - loss: 0.5934
# Epoch 41: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6832 - loss: 0.5927 - val_accuracy: 0.5167 - val_loss: 0.7520
# Epoch 42/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6833 - loss: 0.5994
# Epoch 42: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6831 - loss: 0.5992 - val_accuracy: 0.5500 - val_loss: 0.7882
# Epoch 43/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7013 - loss: 0.5832
# Epoch 43: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7014 - loss: 0.5831 - val_accuracy: 0.5417 - val_loss: 0.7775
# Epoch 44/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6880 - loss: 0.5804
# Epoch 44: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6880 - loss: 0.5806 - val_accuracy: 0.5167 - val_loss: 0.7612
# Epoch 45/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7252 - loss: 0.5833
# Epoch 45: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7247 - loss: 0.5832 - val_accuracy: 0.5083 - val_loss: 0.7899
# Epoch 46/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7133 - loss: 0.5817
# Epoch 46: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7132 - loss: 0.5814 - val_accuracy: 0.5417 - val_loss: 0.7677
# Epoch 47/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7013 - loss: 0.5765
# Epoch 47: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7014 - loss: 0.5764 - val_accuracy: 0.5333 - val_loss: 0.7909
# Epoch 48/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6963 - loss: 0.5758
# Epoch 48: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.6961 - loss: 0.5760 - val_accuracy: 0.5333 - val_loss: 0.7795
# Epoch 49/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7268 - loss: 0.5638
# Epoch 49: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7265 - loss: 0.5640 - val_accuracy: 0.5083 - val_loss: 0.7649
# Epoch 50/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7043 - loss: 0.5724
# Epoch 50: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7040 - loss: 0.5726 - val_accuracy: 0.5333 - val_loss: 0.7734
# Epoch 51/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7168 - loss: 0.5677
# Epoch 51: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7162 - loss: 0.5682 - val_accuracy: 0.5417 - val_loss: 0.7797
# Epoch 52/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7141 - loss: 0.5544
# Epoch 52: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7134 - loss: 0.5546 - val_accuracy: 0.5333 - val_loss: 0.7759
# Epoch 53/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7401 - loss: 0.5497
# Epoch 53: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7392 - loss: 0.5504 - val_accuracy: 0.5250 - val_loss: 0.7705
# Epoch 54/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7306 - loss: 0.5576
# Epoch 54: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7293 - loss: 0.5583 - val_accuracy: 0.5417 - val_loss: 0.7870
# Epoch 55/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7145 - loss: 0.5576
# Epoch 55: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7145 - loss: 0.5582 - val_accuracy: 0.5500 - val_loss: 0.7923
# Epoch 56/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7145 - loss: 0.5637
# Epoch 56: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7152 - loss: 0.5633 - val_accuracy: 0.5000 - val_loss: 0.7646
# Epoch 57/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7303 - loss: 0.5525
# Epoch 57: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7302 - loss: 0.5522 - val_accuracy: 0.5583 - val_loss: 0.8128
# Epoch 58/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7296 - loss: 0.5464
# Epoch 58: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7290 - loss: 0.5469 - val_accuracy: 0.5083 - val_loss: 0.7711
# Epoch 59/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7208 - loss: 0.5653
# Epoch 59: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7208 - loss: 0.5650 - val_accuracy: 0.5583 - val_loss: 0.8578
# Epoch 60/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6922 - loss: 0.5752
# Epoch 60: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.6927 - loss: 0.5748 - val_accuracy: 0.5417 - val_loss: 0.8383
# Epoch 61/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7181 - loss: 0.5722
# Epoch 61: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7183 - loss: 0.5713 - val_accuracy: 0.4750 - val_loss: 0.7790
# Epoch 62/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7607 - loss: 0.5317
# Epoch 62: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7594 - loss: 0.5325 - val_accuracy: 0.5333 - val_loss: 0.7918
# Epoch 63/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7466 - loss: 0.5471
# Epoch 63: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7460 - loss: 0.5474 - val_accuracy: 0.5333 - val_loss: 0.8191
# Epoch 64/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7095 - loss: 0.5636
# Epoch 64: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7104 - loss: 0.5629 - val_accuracy: 0.5583 - val_loss: 0.8746
# Epoch 65/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7179 - loss: 0.5595
# Epoch 65: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7185 - loss: 0.5592 - val_accuracy: 0.5333 - val_loss: 0.8043
# Epoch 66/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7182 - loss: 0.5488
# Epoch 66: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7186 - loss: 0.5488 - val_accuracy: 0.5333 - val_loss: 0.7980
# Epoch 67/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7432 - loss: 0.5500
# Epoch 67: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7428 - loss: 0.5493 - val_accuracy: 0.5167 - val_loss: 0.7995
# Epoch 68/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7285 - loss: 0.5382
# Epoch 68: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7288 - loss: 0.5386 - val_accuracy: 0.5583 - val_loss: 0.8218
# Epoch 69/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7457 - loss: 0.5299
# Epoch 69: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7455 - loss: 0.5301 - val_accuracy: 0.5333 - val_loss: 0.8133
# Epoch 70/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7454 - loss: 0.5139
# Epoch 70: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7453 - loss: 0.5145 - val_accuracy: 0.5333 - val_loss: 0.8173
# Epoch 71/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7218 - loss: 0.5475
# Epoch 71: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7222 - loss: 0.5474 - val_accuracy: 0.5500 - val_loss: 0.8794
# Epoch 72/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7280 - loss: 0.5327
# Epoch 72: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7275 - loss: 0.5330 - val_accuracy: 0.4750 - val_loss: 0.7910
# Epoch 73/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7403 - loss: 0.5372
# Epoch 73: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7401 - loss: 0.5371 - val_accuracy: 0.5333 - val_loss: 0.8337
# Epoch 74/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7527 - loss: 0.5077
# Epoch 74: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7527 - loss: 0.5083 - val_accuracy: 0.5083 - val_loss: 0.7946
# Epoch 75/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7879 - loss: 0.5138
# Epoch 75: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7865 - loss: 0.5143 - val_accuracy: 0.5417 - val_loss: 0.8661
# Epoch 76/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7320 - loss: 0.5360
# Epoch 76: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7323 - loss: 0.5359 - val_accuracy: 0.5250 - val_loss: 0.8470
# Epoch 77/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7475 - loss: 0.5116
# Epoch 77: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7481 - loss: 0.5119 - val_accuracy: 0.5333 - val_loss: 0.8598
# Epoch 78/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7317 - loss: 0.5309
# Epoch 78: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7315 - loss: 0.5310 - val_accuracy: 0.5500 - val_loss: 0.8545
# Epoch 79/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7368 - loss: 0.5358
# Epoch 79: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7364 - loss: 0.5356 - val_accuracy: 0.5083 - val_loss: 0.8173
# Epoch 80/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7505 - loss: 0.5025
# Epoch 80: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7508 - loss: 0.5028 - val_accuracy: 0.5250 - val_loss: 0.8200
# Epoch 81/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7544 - loss: 0.5196
# Epoch 81: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7546 - loss: 0.5197 - val_accuracy: 0.5167 - val_loss: 0.8275
# Epoch 82/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7699 - loss: 0.4945
# Epoch 82: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7691 - loss: 0.4950 - val_accuracy: 0.5500 - val_loss: 0.8677
# Epoch 83/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7328 - loss: 0.5306
# Epoch 83: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7335 - loss: 0.5303 - val_accuracy: 0.5417 - val_loss: 0.8466
# Epoch 84/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7787 - loss: 0.4826
# Epoch 84: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7777 - loss: 0.4838 - val_accuracy: 0.5417 - val_loss: 0.8836
# Epoch 85/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7295 - loss: 0.5196
# Epoch 85: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7302 - loss: 0.5192 - val_accuracy: 0.4917 - val_loss: 0.8142
# Epoch 86/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7773 - loss: 0.5062
# Epoch 86: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7766 - loss: 0.5068 - val_accuracy: 0.5083 - val_loss: 0.8216
# Epoch 87/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7472 - loss: 0.5064
# Epoch 87: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7474 - loss: 0.5062 - val_accuracy: 0.5167 - val_loss: 0.8318
# Epoch 88/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7650 - loss: 0.4893
# Epoch 88: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7649 - loss: 0.4896 - val_accuracy: 0.5250 - val_loss: 0.8437
# Epoch 89/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7654 - loss: 0.4876
# Epoch 89: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7648 - loss: 0.4883 - val_accuracy: 0.5250 - val_loss: 0.8112
# Epoch 90/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7763 - loss: 0.4831
# Epoch 90: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7758 - loss: 0.4839 - val_accuracy: 0.5333 - val_loss: 0.8484
# Epoch 91/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7642 - loss: 0.4862
# Epoch 91: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7643 - loss: 0.4863 - val_accuracy: 0.4750 - val_loss: 0.8285
# Epoch 92/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7734 - loss: 0.4984
# Epoch 92: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7723 - loss: 0.4989 - val_accuracy: 0.4833 - val_loss: 0.8171
# Epoch 93/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7680 - loss: 0.4959
# Epoch 93: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7680 - loss: 0.4960 - val_accuracy: 0.5417 - val_loss: 0.8563
# Epoch 94/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7678 - loss: 0.4886
# Epoch 94: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7678 - loss: 0.4886 - val_accuracy: 0.5250 - val_loss: 0.8169
# Epoch 95/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7498 - loss: 0.4983
# Epoch 95: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.7507 - loss: 0.4975 - val_accuracy: 0.5083 - val_loss: 0.8534
# Epoch 96/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7692 - loss: 0.4974
# Epoch 96: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7692 - loss: 0.4970 - val_accuracy: 0.5000 - val_loss: 0.8577
# Epoch 97/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7846 - loss: 0.4835
# Epoch 97: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7839 - loss: 0.4837 - val_accuracy: 0.5167 - val_loss: 0.8253
# Epoch 98/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7556 - loss: 0.4990
# Epoch 98: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7562 - loss: 0.4985 - val_accuracy: 0.5083 - val_loss: 0.8340
# Epoch 99/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7639 - loss: 0.4863
# Epoch 99: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7639 - loss: 0.4866 - val_accuracy: 0.5083 - val_loss: 0.8346
# Epoch 100/100
# 35/36 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7851 - loss: 0.4585
# Epoch 100: val_accuracy did not improve from 0.63333
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7849 - loss: 0.4592 - val_accuracy: 0.4917 - val_loss: 0.8297

# %% [markdown]
# ## Predict

# %%
# Make predictions for each plane
predictions_valid_axial = model_axial.predict(axial_mensicus_val, batch_size=batch_size, verbose=1)
predictions_valid_coronal = model_coronal.predict(coronal_mensicus_val, batch_size=batch_size, verbose=1)
predictions_valid_sagittal = model_sagittal.predict(sagittal_mensicus_val, batch_size=batch_size, verbose=1)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d871a8e25f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/4 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# WARNING:tensorflow:6 out of the last 12 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d871a8e25f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step

# %% [markdown]
# ## Evaluate

# %%
import numpy as np
def calculate_accuracy(ypred, ytest):
    '''calculate accuracy and misclassification'''
    total = 0
    accurate = 0
    accurateindex = []
    wrongindex = []

    for i in range(len(ypred)):
        if np.argmax(ypred[i]) == np.argmax(ytest[i]):
            accurate += 1
            accurateindex.append(i)
        else:
            wrongindex.append(i)
        total += 1

    accuracy = round(accurate / total * 100, 3)
    return total, accurate, total - accurate, accuracy, accurateindex, wrongindex

# %%
from sklearn.metrics import log_loss

score_axial = log_loss(axial_mensicus_label_val, predictions_valid_axial)
score_coronal = log_loss(coronal_mensicus_label_val, predictions_valid_coronal)
score_sagittal = log_loss(sagittal_mensicus_label_val, predictions_valid_sagittal)

print(f"Log Loss: {score_axial}")
print(f"Log Loss: {score_coronal}")
print(f"Log Loss: {score_sagittal}")

# Axial plane accuracy
total_axial, accurate_axial, wrong_axial, accuracy_axial, accurateindex_axial, wrongindex_axial = calculate_accuracy(predictions_valid_axial, axial_mensicus_label_val)
print('Axial - Total test data:', total_axial, '\tAccurately predicted data:', accurate_axial, '\tWrongly predicted data:', wrong_axial)
print('Axial Accuracy:', accuracy_axial, '%')

# Coronal plane accuracy
total_coronal, accurate_coronal, wrong_coronal, accuracy_coronal, accurateindex_coronal, wrongindex_coronal = calculate_accuracy(predictions_valid_coronal, coronal_mensicus_label_val)
print('Coronal - Total test data:', total_coronal, '\tAccurately predicted data:', accurate_coronal, '\tWrongly predicted data:', wrong_coronal)
print('Coronal Accuracy:', accuracy_coronal, '%')

# Sagittal plane accuracy
total_sagittal, accurate_sagittal, wrong_sagittal, accuracy_sagittal, accurateindex_sagittal, wrongindex_sagittal = calculate_accuracy(predictions_valid_sagittal, sagittal_mensicus_label_val)
print('Sagittal - Total test data:', total_sagittal, '\tAccurately predicted data:', accurate_sagittal, '\tWrongly predicted data:', wrong_sagittal)
print('Sagittal Accuracy:', accuracy_sagittal, '%')
# Out:
# Log Loss: 0.8895216944929882
# Log Loss: 0.767637481789478
# Log Loss: 0.8281068155253453
# Axial - Total test data: 120 	Accurately predicted data: 57 	Wrongly predicted data: 63
# Axial Accuracy: 47.5 %
# Coronal - Total test data: 120 	Accurately predicted data: 60 	Wrongly predicted data: 60
# Coronal Accuracy: 50.0 %
# Sagittal - Total test data: 120 	Accurately predicted data: 59 	Wrongly predicted data: 61
# Sagittal Accuracy: 49.167 %

# %%
# Evaluating Accuracy and Loss for the three planes: axial, coronal, and sagittal
# %matplotlib inline
import matplotlib.pyplot as plt

# Axial metrics
acc_axial = history_axial.history['accuracy']
val_acc_axial = history_axial.history['val_accuracy']
loss_axial = history_axial.history['loss']
val_loss_axial = history_axial.history['val_loss']

# Coronal metrics
acc_coronal = history_coronal.history['accuracy']
val_acc_coronal = history_coronal.history['val_accuracy']
loss_coronal = history_coronal.history['loss']
val_loss_coronal = history_coronal.history['val_loss']

# Sagittal metrics
acc_sagittal = history_sagittal.history['accuracy']
val_acc_sagittal = history_sagittal.history['val_accuracy']
loss_sagittal = history_sagittal.history['loss']
val_loss_sagittal = history_sagittal.history['val_loss']
epochs = range(1, len(acc_axial) + 1)
# Plot training and validation accuracy for each plane
plt.figure(figsize=(12, 6))
plt.plot(epochs, acc_axial, 'b', label='Training Accuracy - Axial')
plt.plot(epochs, val_acc_axial, 'b--', label='Validation Accuracy - Axial')
plt.plot(epochs, acc_coronal, 'g', label='Training Accuracy - Coronal')
plt.plot(epochs, val_acc_coronal, 'g--', label='Validation Accuracy - Coronal')
plt.plot(epochs, acc_sagittal, 'r', label='Training Accuracy - Sagittal')
plt.plot(epochs, val_acc_sagittal, 'r--', label='Validation Accuracy - Sagittal')

plt.title(f'Training and Validation Accuracy (Epochs={nb_epoch}, Dropout={dropout}, Learning Rate={lr}, Batch Size={batch_size})')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.savefig(f'Train_val_acc_all_planes_Ep={nb_epoch}_Do={dropout}_Lr={lr}_Bs={batch_size}.png')

plt.figure()

# Plot training and validation loss for each plane
plt.figure(figsize=(12, 6))
plt.plot(epochs, loss_axial, 'b', label='Training Loss - Axial')
plt.plot(epochs, val_loss_axial, 'b--', label='Validation Loss - Axial')
plt.plot(epochs, loss_coronal, 'g', label='Training Loss - Coronal')
plt.plot(epochs, val_loss_coronal, 'g--', label='Validation Loss - Coronal')
plt.plot(epochs, loss_sagittal, 'r', label='Training Loss - Sagittal')
plt.plot(epochs, val_loss_sagittal, 'r--', label='Validation Loss - Sagittal')

plt.title(f'Training and Validation Loss (Epochs={nb_epoch}, Dropout={dropout}, Learning Rate={lr}, Batch Size={batch_size})')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.savefig(f'Train_val_loss_all_planes_Ep={nb_epoch}_Do={dropout}_Lr={lr}_Bs={batch_size}.png')

plt.show()

# %% [markdown]
# save the models in a keras file

# %%
model_axial.save("model_axial.keras")
model_coronal.save("model_coronal.keras")
model_sagittal.save("model_sagittal.keras")

# %%
from google.colab import files
files.download('model_coronal.keras')
files.download("model_sagittal.keras")
files.download("model_axial.keras")

# %%
files.download("Train_val_acc_all_planes_Ep=100_Do=0.4_Lr=0.0005_Bs=32.png")
files.download("Train_val_loss_all_planes_Ep=100_Do=0.4_Lr=0.0005_Bs=32.png")
